# %% [markdown]
# # Training with all representations

# %%
# !python -m pip list
# Out:
# Package                Version
# ---------------------- ---------
# absl-py                0.12.0
# anyio                  2.2.0
# argon2-cffi            20.1.0
# astunparse             1.6.3
# async-generator        1.10
# attrs                  20.3.0
# Babel                  2.9.0
# backcall               0.2.0
# bleach                 3.3.0
# cachetools             4.2.1
# certifi                2020.12.5
# cffi                   1.14.5
# chardet                4.0.0
# cycler                 0.10.0
# dask                   2021.3.0
# decorator              4.4.2
# defusedxml             0.7.1
# entrypoints            0.3
# flatbuffers            1.12
# gast                   0.3.3
# google-auth            1.27.1
# google-auth-oauthlib   0.4.3
# google-pasta           0.2.0
# grpcio                 1.32.0
# h5py                   2.10.0
# idna                   2.10
# ipykernel              5.5.0
# ipython                7.21.0
# ipython-genutils       0.2.0
# ipywidgets             7.6.3
# jedi                   0.18.0
# Jinja2                 2.11.3
# joblib                 1.0.1
# json5                  0.9.5
# jsonschema             3.2.0
# jupyter                1.0.0
# jupyter-client         6.1.12
# jupyter-console        6.2.0
# jupyter-core           4.7.1
# jupyter-packaging      0.7.12
# jupyter-server         1.4.1
# jupyterlab             3.0.10
# jupyterlab-pygments    0.1.2
# jupyterlab-server      2.3.0
# jupyterlab-widgets     1.0.0
# Keras-Preprocessing    1.1.2
# kiwisolver             1.3.1
# lxml                   4.6.2
# Markdown               3.3.4
# MarkupSafe             1.1.1
# matplotlib             3.3.4
# mistune                0.8.4
# nbclassic              0.2.6
# nbclient               0.5.3
# nbconvert              6.0.7
# nbformat               5.1.2
# nest-asyncio           1.5.1
# networkx               2.5
# notebook               6.2.0
# numpy                  1.20.1
# oauthlib               3.1.0
# opt-einsum             3.3.0
# packaging              20.9
# pandas                 1.2.3
# pandocfilters          1.4.3
# parso                  0.8.1
# pexpect                4.8.0
# pickleshare            0.7.5
# Pillow                 8.1.2
# pip                    20.0.2
# pkg-resources          0.0.0
# prometheus-client      0.9.0
# prompt-toolkit         3.0.17
# protobuf               3.15.6
# ptyprocess             0.7.0
# pyasn1                 0.4.8
# pyasn1-modules         0.2.8
# pycparser              2.20
# Pygments               2.8.1
# pyparsing              2.4.7
# pyrsistent             0.17.3
# python-dateutil        2.8.1
# pytz                   2021.1
# PyYAML                 5.4.1
# pyzmq                  22.0.3
# qtconsole              5.0.2
# QtPy                   1.9.0
# requests               2.25.1
# requests-oauthlib      1.3.0
# rsa                    4.7.2
# scikit-learn           0.24.1
# scipy                  1.6.1
# seaborn                0.11.1
# Send2Trash             1.5.0
# setuptools             44.0.0
# six                    1.15.0
# sklearn                0.0
# sniffio                1.2.0
# spektral               0.6.2
# tensorboard            2.4.1
# tensorboard-plugin-wit 1.8.0
# tensorflow             2.4.1
# tensorflow-estimator   2.4.0
# tensorflow-gpu         2.4.1
# termcolor              1.1.0
# terminado              0.9.2
# testpath               0.4.4
# threadpoolctl          2.1.0
# tornado                6.1
# tqdm                   4.59.0
# traitlets              5.0.5
# typing-extensions      3.7.4.3
# urllib3                1.26.4
# wcwidth                0.2.5
# webencodings           0.5.1
# Werkzeug               1.0.1
# wheel                  0.36.2
# widgetsnbextension     3.5.1
# wrapt                  1.12.1

# %%
# !nvidia-smi
# Out:
# Thu Apr 22 17:09:18 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 450.102.04   Driver Version: 450.102.04   CUDA Version: 11.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  GeForce GTX 1070    On   | 00000000:01:00.0 Off |                  N/A |
# | 10%   52C    P0    30W / 151W |    223MiB /  8118MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A      1005      G   /usr/lib/xorg/Xorg                205MiB |
# |    0   N/A  N/A   1658410      G   xfwm4                               3MiB |
# |    0   N/A  N/A   1658436      G   ...mviewer/tv_bin/TeamViewer       11MiB |
# +-----------------------------------------------------------------------------+

# %%
import gc
import os
import sys
import yaml
import glob
import numpy as np
import pickle
import tensorflow as tf
import random
import tqdm
import seaborn as sn
import numpy as np
import time

from collections import defaultdict

from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import plot_confusion_matrix
from sklearn.metrics import confusion_matrix
from spektral.layers import *
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.layers import Input, Dense, Concatenate, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l2
from tensorflow import keras
from tqdm.contrib.concurrent import process_map, thread_map

from utils import yaml_load, yaml_write, get_section

# %matplotlib inline

# %% [markdown]
# # General functions
#
# Here we are going to define some general functions, for different purposes, used along the whole notebook.

# %%
def create_model(n_nodes, n_features, n_classes, learning_rate):
    N = n_nodes
    F = n_features
    
    # Model definition
    conv   = GraphConv(45,activation='relu',use_bias=False)
    mincut = MinCutPool(N // 2)
    conv2  = GraphConv(55,activation='relu',use_bias=False)
    pool   = GlobalAttnSumPool()

    # First Graph Layers
    X1_in = Input(shape=(N, F))
    A1_in = Input((N, N))
    gc2_1 = conv([X1_in, A1_in])
    gc2_1, A1 = mincut([gc2_1,A1_in])
    gc2_1 = conv2([gc2_1, A1])
    pool_1 =  pool(gc2_1)
    d1 = Dense(200,activation='relu')(pool_1)

    # Second Graph Layers
    X2_in = Input(shape=(N, F))
    A2_in = Input((N, N))
    gc2_2 = conv([X2_in, A2_in]) # Notice that both graphs shares layers (shared weights)
    gc2_2, A2 = mincut([gc2_2,A2_in])
    gc2_2 = conv2([gc2_2, A2])
    pool_2 = pool(gc2_2)
    d2 = Dense(200,activation='relu')(pool_2)

    # Dense final layers
    merged = Concatenate()([d1, d2])

    merged1 = Dense(800,activation='relu')(merged)
    merged2 = Dense(32,activation='relu')(merged1)

    classe = Dense(n_classes, name="class",activation="softmax")(merged2)
    speedup = Dense(1, name="speddup")(merged2)

    # Build model
    model = Model(inputs=[X1_in, A1_in,X2_in, A2_in], outputs=[classe,speedup])
    optimizer = Adam(lr=learning_rate)
    model.compile(optimizer=optimizer, loss=['categorical_crossentropy', 'mse'], loss_weights=[1, 0.00005], weighted_metrics=['acc'])
    return model

# %%
# Load and prepare inputs, in the .npz file, to train by the model
def get_inputs(input_data_file: str, test_size: float) -> tuple:
    """Load and prepare samples to be used by the model. Also, splits the samples in train and test sets. 
    
    Parameters:
        input_data_file (str): Numpy file containing the graphs, features and speedups from all samples
        test_size (float): Number of samples to used as test
        
    Returns:
        A tuple with 6 elements (in order), being:
        * The graphs used to train
        * The graphs used to test
        * The graph features used to train
        * The graph features used to test
        * The speedup used to train
        * The speedup used to test
    """
    # Read all data
    with np.load(input_data_file, allow_pickle=True) as all_data:
        graphs = all_data['graphs']        # Graphs matrices
        features = all_data['features']    # Features matrices
        speedups = all_data['speedups']    # Speedup matrices (targets)

    print(f'Data loaded from {input_data_file}')
    
    # Generate classed based on speedup [0-4]
    y_c = np.zeros(shape=(speedups.shape[0],5))

    for i in range(0, speedups.shape[0]):
        if speedups[i] < 0.45:
            y_c[i,0]=1
        elif (speedups[i] <= 0.80 and speedups[i] >= 0.45):
            y_c[i,1]=1
        elif (speedups[i] <= 1.33 and speedups[i] > 0.80):
            y_c[i,2]=1
        elif speedups[i] > 1.33:
            y_c[i,3]= 1
        y_c[i,4] =speedups[i]
    speedups = y_c

    print(f"""Speedup classes generated from data. Number of elements 
        Class A: {int(sum(speedups[:,0]))},
        Class B: {int(sum(speedups[:,1]))},
        Class C: {int(sum(speedups[:,2]))},
        Class D: {int(sum(speedups[:,3]))},
    """)
    
    # Remove 0 columns in nodes features
    #idx = np.argwhere(np.all(X[..., :] == 0, axis=(0,1,2)))
    #X = np.delete(X, idx, axis=3)

    print(f"""Datas:
        Graphs shape:   {graphs.shape}
        Features shape: {features.shape}
        Speedups shape: {speedups.shape} 
    """)

    # Preprocess all graphs with Spektral package
    graphs[:,0,:,:] = GraphConv.preprocess(graphs[:,0,:,:]).astype('f4')
    graphs[:,1,:,:] = GraphConv.preprocess(graphs[:,1,:,:]).astype('f4')
    print("Graphs preprocessed!")
    
    # Split train and test sets
    graphs_train, graphs_test, features_train, features_test, speedups_train, speedups_test = train_test_split(graphs, features, speedups, shuffle=True, test_size=test_size)
    print("Dataset splitted!")
    
    return graphs_train, graphs_test, features_train, features_test, speedups_train, speedups_test

# %%
# Function used to store information about training
def dump_info(data_dir: str, filename: str, values: dict):
    """Create directories and store informations about training
    
    Parameters:
        data_dir (str): Directory to store information about training (model, weights, results, etc.)
        filename (str): Name of the file to save information about
        values (dict): Dictionary with information
    
    Returns:
        None
    """
    # Create the directories to store information about training
    os.makedirs(data_dir, exist_ok=True)
    output_file = os.path.join(data_dir, filename)
    yaml_write(output_file, values)    
    print(f'Information saved to {output_file}')

# %%
# Save model topology and weights
def save_model(data_dir: str, model: Model):
    """Save model topology and weights to files (model.yaml and weights.h5, respectively) in data_dir
    
    Parameters:
        data_dir (str): Directory to store model topology and weights
        model: Model to save
    
    Returns:
        None
    """
    # Saving model and weights
    output_model_file = os.path.join(data_dir, 'model.yaml')
    yaml_write(output_model_file, model.to_yaml())
    print(f'Model saved to {output_model_file}')

    output_weights_file = os.path.join(data_dir, 'weights.h5')
    model.save_weights(output_weights_file)
    print(f"Weights saved to file {output_weights_file}")

# %%
llvm_codes = {
  "ret": 1,
  "br": 2,
  "switch": 3,
  "indirectbr": 4,
  "invoke": 5,
  "resume": 6,
  "unreachable": 7,
  "cleanupret": 8,
  "catchret": 9,
  "catchswitch": 10,
  "callbr": 11,
  "fneg": 12,
  "add": 13,
  "fadd": 14,
  "sub": 15,
  "fsub": 16,
  "mul": 17,
  "fmul": 18,
  "udiv": 19,
  "sdiv": 20,
  "fdiv": 21,
  "urem": 22,
  "srem": 23,
  "frem": 24,
  "shl": 25,
  "lshr": 26,
  "ashr": 27,
  "and": 28,
  "or": 29,
  "xor": 30,
  "alloca": 31,
  "load": 32,
  "store": 33,
  "getelementptr": 34,
  "fence": 35,
  "atomiccmpxchg": 36,
  "atomicrmw": 37,
  "trunc": 38,
  "zext": 39,
  "sext": 40,
  "fptoui": 41,
  "fptosi": 42,
  "uitofp": 43,
  "sitofp": 44,
  "fptrunc": 45,
  "fpext": 46,
  "ptrtoint": 47,
  "inttoptr": 48,
  "bitcast": 49,
  "addrspacecast": 50,
  "cleanuppad": 51,
  "catchpad": 52,
  "icmp": 53,
  "fcmp": 54,
  "phi": 55,
  "call": 56,
  "select": 57,
  "userop1": 58,
  "userop2": 59,
  "vaarg": 60,
  "extractelement": 61,
  "insertelement": 62,
  "shufflevector": 63,
  "extractvalue": 64,
  "insertvalue": 65,
  "landingpad": 66,
  "freeze": 67
}

terminator_insts = [
  "ret", "br", "switch", "indirectbr", "invoke", "resume", "unreachable",
  "cleanupret", "catchret", "catchswitch", "callbr"
]

unary_insts = [
    "fneg"
]

binary_insts = [
    "add", "fadd", "sub", "fsub", "mul", "fmul", "udiv", "sdiv", "fdiv", "urem",
    "srem", "frem", "shl", "lshr", "ashr", "and", "or", "xor"
]

memory_insts = [
    "alloca", "load", "store", "getelementptr", "fence", "atomiccmpxchg",
    "atomicrmw"
]

cast_insts = [
    "trunc", "zext", "sext", "fptoui", "fptosi", "uitofp", "sitofp", "fptrunc", 
    "fpext", "ptrtoint", "inttoptr", "bitcast", "addrspacecast", "cleanuppad", "catchpad"
]

other_insts = [
    "icmp", "fcmp", "phi", "call", "select", "userop1", "userop2", "vaarg", "extractelement",
    "insertelement", "shufflevector", "extractvalue", "insertvalue", "landingpad", "freeze" 
]

def zero_features(features, columns):
    for c in columns:
        features[:, :, :, c] = 0
    return features
    
def get_terminators():
    return [llvm_codes[i]-1 for i in terminator_insts]
def get_unary():
    return [llvm_codes[i]-1 for i in unary_insts]
def get_binary():
    return [llvm_codes[i]-1 for i in binary_insts]
def get_memory():
    return [llvm_codes[i]-1 for i in memory_insts]
def get_casts():
    return [llvm_codes[i]-1 for i in cast_insts]
def get_others():
    return [llvm_codes[i]-1 for i in other_insts]

def eval_results_zeroing_llvm(model, columns_to_zero, features, graphs, targets, description: str = ''):
    features_ = features.copy()
    features_ = zero_features(features_, columns_to_zero)
    eval_results = model.evaluate([features_[:,0,:,:], graphs[:,0,:,:], features_[:,1,:,:], graphs[:,1,:,:]], [targets[:,0:4], targets[:,4]],
                                  batch_size=config['batch_size'], verbose=0)
    print(f"{description}. loss: {eval_results[0]}, class_acc: {eval_results[3]}")
    return eval_results

def eval_results_zeroing_llvm_random(model, n_samples, features, graphs, targets):
    columns = random.sample(range(len(llvm_codes)), k=n_samples)
    desc = f'Zeroing columns {", ".join([str(c) for c in sorted(columns)])}'
    return eval_results_zeroing_llvm(model, columns, features, graphs, targets, desc)

# %% [markdown]
# # Training with CFG graphs

# %%
# Configuration information about training
config = {
    'input_data': './data/generated2.cfgs_20000samples_150x150.npz',   # Name of the file with samples
    'data_dir_tag': 'generated2.control',    # Tag for directory name
    'n_nodes': 150,       # Number of nodes in graphs
    'n_features': 67,     # Original feature dimensionality
    'n_classes': 4,       # Number of output classes
    'epochs': 200,        # Number of training epochs
    'batch_size': 16,     # Number of samples per batch
    'learning_rate': 1e-2,# Training learning rate
    'test_size': 0.10,    # Percentage of samples to be used in test set (in relation to total number of samples)
    'validation_size': 0.10,    # Percentage of samples to be used in validation set (in relation to number of training samples)
    'samples': 20000,     # Number of samples in dataset (OPTIONAL)
}

# Create directory and write configuration information
data_dir = f"./model_data/GNN_{config['data_dir_tag']}_{config['n_nodes']}x{config['n_nodes']}_{time.time()}"
dump_info(data_dir, 'info.yaml', config)

print('Loading inputs and split into train and test sets')
# Load inputs and create train and and test sets
graphs_train, graphs_test, features_train, features_test, y_train, y_test = get_inputs(config['input_data'], test_size=config['test_size'])
print("Inputs loaded!")

# Create GNN model
model = create_model(config['n_nodes'], config['n_features'], config['n_classes'], config['learning_rate'])
print('Model created!')
model.summary()

# -----------------------------------------------
# ----------------- Train model -----------------
# -----------------------------------------------
print('Start training')
start_time = time.time()
history = model.fit([features_train[:,0,:,:], graphs_train[:,0,:,:], features_train[:,1,:,:], graphs_train[:,1,:,:]], [y_train[:,0:4], y_train[:,4]],
          batch_size=config['batch_size'], validation_split=config['validation_size'], epochs=config['epochs'], verbose=1)
end_time = time.time()
print(f'Training took {end_time-start_time} seconds..')

# Dump training information to files
dump_info(data_dir, 'training_history.yaml', history.history)
dump_info(data_dir, 'training_time.yaml', {'time': end_time-start_time})
# Save model and weights to files
save_model(data_dir, model)

# Plot accuracy per epoch in train and validation sets
plt.plot(np.array(history.history['class_acc']))
plt.plot(np.array(history.history['val_class_acc']))
plt.title('model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
figure_file = os.path.join(data_dir, "model_accuracy.pdf")
plt.savefig(figure_file)
print(f"Accuracy per epoch figure saved to {figure_file}")


# --------------------------------------------------
# ----------------- Evaluate model -----------------
# --------------------------------------------------
print('Evaluating model.')
eval_results = model.evaluate([features_test[:,0,:,:], graphs_test[:,0,:,:], features_test[:,1,:,:], graphs_test[:,1,:,:]], [y_test[:,0:4],y_test[:,4]],
                              batch_size=config['batch_size'])
print('Done. Test loss: {:.4f}. Test acc: {:.2f}'.format(*eval_results))

# Dump evaluation information to files
dump_info(data_dir, 'evaluation.yaml', {'test_loss': eval_results[0], 'test_accuracy': eval_results[1]})

# Printing confusion matrix
print("Confusion matrix:")
pred_vals = model.predict([features_test[:,0,:,:], graphs_test[:,0,:,:], features_test[:,1,:,:], graphs_test[:,1,:,:]])
pred_vals = np.argmax(pred_vals[0], axis=-1)
test_vals = np.argmax(y_test[:,0:4], axis=-1)
cm=confusion_matrix(pred_vals,test_vals)
print(cm)

# Plot confusion matrix
labels = ['High Slowdown', 'Low Slowdown', 'Not Significant', 'High Speedup']
plt.figure(figsize = (10,7))
sn.set(font_scale=1.4)
ax = sn.heatmap(cm, cmap="Blues", annot=True, annot_kws={"size": 16}, xticklabels=labels, yticklabels=labels)
for label in ax.get_xticklabels():
    label.set_ha("right")
    label.set_rotation(45)

ax.set_xlabel('Truth Category')
ax.set_ylabel('Predicted Category')

# Save confusion matrix
figure_file = os.path.join(data_dir, "confusion_matrix.pdf")
plt.savefig(figure_file)
print(f"Confusion matrix figure saved to {figure_file}")

# Cleanup
gc.collect()
# Out:
# Information saved to ./model_data/GNN_generated2.control_150x150_1619122164.3685732/info.yaml
# Loading inputs and split into train and test sets
# Data loaded from ./data/generated2.cfgs_20000samples_150x150.npz
# Speedup classes generated from data. Number of elements
#         Class A: 5004,
#         Class B: 4998,
#         Class C: 4999,
#         Class D: 4999,
#
# Datas:
#         Graphs shape:   (20000, 2, 150, 150)
#         Features shape: (20000, 2, 150, 67)
#         Speedups shape: (20000, 5)
#
# Graphs preprocessed!
# Dataset splitted!
# Inputs loaded!
# Model created!
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 150, 67)]    0
# __________________________________________________________________________________________________
# input_2 (InputLayer)            [(None, 150, 150)]   0
# __________________________________________________________________________________________________
# input_3 (InputLayer)            [(None, 150, 67)]    0
# __________________________________________________________________________________________________
# input_4 (InputLayer)            [(None, 150, 150)]   0
# __________________________________________________________________________________________________
# graph_conv (GraphConv)          (None, 150, 45)      3015        input_1[0][0]
#                                                                  input_2[0][0]
#                                                                  input_3[0][0]
#                                                                  input_4[0][0]
# __________________________________________________________________________________________________
# min_cut_pool (MinCutPool)       [(None, 75, 45), (No 3450        graph_conv[0][0]
#                                                                  input_2[0][0]
#                                                                  graph_conv[1][0]
#                                                                  input_4[0][0]
# __________________________________________________________________________________________________
# graph_conv_1 (GraphConv)        (None, 75, 55)       2475        min_cut_pool[0][0]
#                                                                  min_cut_pool[0][1]
#                                                                  min_cut_pool[1][0]
#                                                                  min_cut_pool[1][1]
# __________________________________________________________________________________________________
# global_attn_sum_pool (GlobalAtt (None, 55)           55          graph_conv_1[0][0]
#                                                                  graph_conv_1[1][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 200)          11200       global_attn_sum_pool[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 200)          11200       global_attn_sum_pool[1][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 400)          0           dense[0][0]
#                                                                  dense_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 800)          320800      concatenate[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 32)           25632       dense_2[0][0]
# __________________________________________________________________________________________________
# class (Dense)                   (None, 4)            132         dense_3[0][0]
# __________________________________________________________________________________________________
# speddup (Dense)                 (None, 1)            33          dense_3[0][0]
# ==================================================================================================
# Total params: 377,992
# Trainable params: 377,992
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Start training
# Epoch 1/200
# 1013/1013 [==============================] - 8s 6ms/step - loss: 2.9567 - class_loss: 1.2323 - speddup_loss: 24306.6710 - class_acc: 0.4156 - speddup_acc: 0.0000e+00 - val_loss: 3.4194 - val_class_loss: 0.9958 - val_speddup_loss: 40648.5430 - val_class_acc: 0.5589 - val_speddup_acc: 0.0000e+00
# Epoch 2/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 2.2797 - class_loss: 0.9763 - speddup_loss: 18164.9853 - class_acc: 0.5669 - speddup_acc: 0.0000e+00 - val_loss: 3.3567 - val_class_loss: 0.9373 - val_speddup_loss: 40621.1211 - val_class_acc: 0.5800 - val_speddup_acc: 0.0000e+00
# Epoch 3/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.9729 - class_loss: 0.9123 - speddup_loss: 13387.9850 - class_acc: 0.6048 - speddup_acc: 0.0000e+00 - val_loss: 3.3742 - val_class_loss: 0.9538 - val_speddup_loss: 40601.0898 - val_class_acc: 0.5517 - val_speddup_acc: 0.0000e+00
# Epoch 4/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.9283 - class_loss: 0.8567 - speddup_loss: 13567.6112 - class_acc: 0.6263 - speddup_acc: 0.0000e+00 - val_loss: 3.2739 - val_class_loss: 0.8527 - val_speddup_loss: 40604.8672 - val_class_acc: 0.6167 - val_speddup_acc: 0.0000e+00
# Epoch 5/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 2.0068 - class_loss: 0.8467 - speddup_loss: 15265.0786 - class_acc: 0.6269 - speddup_acc: 0.0000e+00 - val_loss: 3.2550 - val_class_loss: 0.8509 - val_speddup_loss: 40145.2383 - val_class_acc: 0.6078 - val_speddup_acc: 0.0000e+00
# Epoch 6/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.4146 - class_loss: 0.8144 - speddup_loss: 4111.3282 - class_acc: 0.6411 - speddup_acc: 6.7137e-05 - val_loss: 3.7505 - val_class_loss: 1.0483 - val_speddup_loss: 45495.7969 - val_class_acc: 0.5933 - val_speddup_acc: 0.0000e+00
# Epoch 7/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.6165 - class_loss: 0.8582 - speddup_loss: 6820.5024 - class_acc: 0.6285 - speddup_acc: 0.0000e+00 - val_loss: 3.3264 - val_class_loss: 0.8909 - val_speddup_loss: 40591.0195 - val_class_acc: 0.6117 - val_speddup_acc: 0.0000e+00
# Epoch 8/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.5573 - class_loss: 0.7935 - speddup_loss: 7206.7144 - class_acc: 0.6463 - speddup_acc: 0.0000e+00 - val_loss: 3.4371 - val_class_loss: 0.8742 - val_speddup_loss: 41666.4766 - val_class_acc: 0.6356 - val_speddup_acc: 0.0000e+00
# Epoch 9/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.6326 - class_loss: 0.7975 - speddup_loss: 8245.4056 - class_acc: 0.6569 - speddup_acc: 1.1232e-05 - val_loss: 3.2411 - val_class_loss: 0.8226 - val_speddup_loss: 40313.2344 - val_class_acc: 0.6356 - val_speddup_acc: 0.0000e+00
# Epoch 10/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.5555 - class_loss: 0.7596 - speddup_loss: 7766.0325 - class_acc: 0.6658 - speddup_acc: 0.0000e+00 - val_loss: 3.2492 - val_class_loss: 0.8050 - val_speddup_loss: 40616.1602 - val_class_acc: 0.6389 - val_speddup_acc: 0.0000e+00
# Epoch 11/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.3547 - class_loss: 0.7675 - speddup_loss: 3458.1241 - class_acc: 0.6579 - speddup_acc: 7.7940e-05 - val_loss: 3.2518 - val_class_loss: 0.8278 - val_speddup_loss: 40609.5078 - val_class_acc: 0.6372 - val_speddup_acc: 0.0000e+00
# Epoch 12/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 2.1726 - class_loss: 0.7294 - speddup_loss: 20733.7736 - class_acc: 0.6746 - speddup_acc: 0.0000e+00 - val_loss: 3.2638 - val_class_loss: 0.8219 - val_speddup_loss: 40621.3984 - val_class_acc: 0.6294 - val_speddup_acc: 0.0000e+00
# Epoch 13/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.6309 - class_loss: 0.7440 - speddup_loss: 9560.3012 - class_acc: 0.6700 - speddup_acc: 0.0000e+00 - val_loss: 3.2387 - val_class_loss: 0.7995 - val_speddup_loss: 40620.6211 - val_class_acc: 0.6283 - val_speddup_acc: 0.0000e+00
# Epoch 14/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.9549 - class_loss: 0.7407 - speddup_loss: 16070.9809 - class_acc: 0.6699 - speddup_acc: 6.3773e-05 - val_loss: 3.1965 - val_class_loss: 0.7641 - val_speddup_loss: 40616.6016 - val_class_acc: 0.6528 - val_speddup_acc: 0.0000e+00
# Epoch 15/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 2.1756 - class_loss: 0.7159 - speddup_loss: 20953.8965 - class_acc: 0.6887 - speddup_acc: 0.0000e+00 - val_loss: 3.2058 - val_class_loss: 0.7659 - val_speddup_loss: 40598.9883 - val_class_acc: 0.6583 - val_speddup_acc: 0.0000e+00
# Epoch 16/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.8355 - class_loss: 0.7131 - speddup_loss: 14214.7875 - class_acc: 0.6817 - speddup_acc: 0.0000e+00 - val_loss: 3.1999 - val_class_loss: 0.7689 - val_speddup_loss: 40627.3945 - val_class_acc: 0.6700 - val_speddup_acc: 0.0000e+00
# Epoch 17/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.2753 - class_loss: 0.7105 - speddup_loss: 3174.9348 - class_acc: 0.6834 - speddup_acc: 0.0000e+00 - val_loss: 3.1859 - val_class_loss: 0.7520 - val_speddup_loss: 40624.1289 - val_class_acc: 0.6722 - val_speddup_acc: 0.0000e+00
# Epoch 18/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.4013 - class_loss: 0.6934 - speddup_loss: 5833.3996 - class_acc: 0.6909 - speddup_acc: 0.0000e+00 - val_loss: 3.2259 - val_class_loss: 0.7820 - val_speddup_loss: 40684.9453 - val_class_acc: 0.6489 - val_speddup_acc: 0.0000e+00
# Epoch 19/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.4438 - class_loss: 0.6957 - speddup_loss: 6780.2079 - class_acc: 0.6883 - speddup_acc: 1.8087e-05 - val_loss: 3.1803 - val_class_loss: 0.7530 - val_speddup_loss: 40620.9766 - val_class_acc: 0.6572 - val_speddup_acc: 0.0000e+00
# Epoch 20/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.5702 - class_loss: 0.6809 - speddup_loss: 9643.3015 - class_acc: 0.6970 - speddup_acc: 0.0000e+00 - val_loss: 3.1994 - val_class_loss: 0.7732 - val_speddup_loss: 40638.6250 - val_class_acc: 0.6506 - val_speddup_acc: 0.0000e+00
# Epoch 21/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.4783 - class_loss: 0.6857 - speddup_loss: 7744.3896 - class_acc: 0.7000 - speddup_acc: 4.1729e-05 - val_loss: 3.4869 - val_class_loss: 0.9803 - val_speddup_loss: 40607.2461 - val_class_acc: 0.5839 - val_speddup_acc: 0.0000e+00
# Epoch 22/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.3873 - class_loss: 0.7455 - speddup_loss: 4135.5667 - class_acc: 0.6685 - speddup_acc: 7.9681e-05 - val_loss: 3.1649 - val_class_loss: 0.8072 - val_speddup_loss: 38832.1406 - val_class_acc: 0.6433 - val_speddup_acc: 0.0000e+00
# Epoch 23/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.8386 - class_loss: 0.7061 - speddup_loss: 14357.9996 - class_acc: 0.6831 - speddup_acc: 2.2264e-04 - val_loss: 3.1647 - val_class_loss: 0.7418 - val_speddup_loss: 40610.9453 - val_class_acc: 0.6706 - val_speddup_acc: 0.0000e+00
# Epoch 24/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 2.3072 - class_loss: 0.6820 - speddup_loss: 24098.3950 - class_acc: 0.7008 - speddup_acc: 0.0000e+00 - val_loss: 3.1645 - val_class_loss: 0.7241 - val_speddup_loss: 40591.7422 - val_class_acc: 0.6628 - val_speddup_acc: 0.0000e+00
# Epoch 25/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.2474 - class_loss: 0.6692 - speddup_loss: 3288.3289 - class_acc: 0.7015 - speddup_acc: 8.6452e-05 - val_loss: 3.1761 - val_class_loss: 0.7354 - val_speddup_loss: 40603.7734 - val_class_acc: 0.6633 - val_speddup_acc: 0.0000e+00
# Epoch 26/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.5899 - class_loss: 0.6626 - speddup_loss: 10242.0749 - class_acc: 0.7014 - speddup_acc: 0.0000e+00 - val_loss: 3.1878 - val_class_loss: 0.7564 - val_speddup_loss: 40619.8711 - val_class_acc: 0.6550 - val_speddup_acc: 0.0000e+00
# Epoch 27/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.8986 - class_loss: 0.6867 - speddup_loss: 15986.3983 - class_acc: 0.6899 - speddup_acc: 0.0000e+00 - val_loss: 3.1993 - val_class_loss: 0.7490 - val_speddup_loss: 40650.0117 - val_class_acc: 0.6628 - val_speddup_acc: 0.0000e+00
# Epoch 28/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.3893 - class_loss: 0.6752 - speddup_loss: 5639.5440 - class_acc: 0.6997 - speddup_acc: 0.0000e+00 - val_loss: 3.2588 - val_class_loss: 0.7649 - val_speddup_loss: 41879.3906 - val_class_acc: 0.6406 - val_speddup_acc: 0.0000e+00
# Epoch 29/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.4517 - class_loss: 0.6853 - speddup_loss: 7067.3584 - class_acc: 0.6973 - speddup_acc: 1.7117e-05 - val_loss: 3.1636 - val_class_loss: 0.7194 - val_speddup_loss: 40848.4375 - val_class_acc: 0.6772 - val_speddup_acc: 0.0000e+00
# Epoch 30/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.1830 - class_loss: 0.6556 - speddup_loss: 2510.0589 - class_acc: 0.7034 - speddup_acc: 6.0950e-05 - val_loss: 3.1495 - val_class_loss: 0.7096 - val_speddup_loss: 40683.4883 - val_class_acc: 0.6733 - val_speddup_acc: 0.0000e+00
# Epoch 31/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.7528 - class_loss: 0.6415 - speddup_loss: 14232.4673 - class_acc: 0.7107 - speddup_acc: 0.0000e+00 - val_loss: 3.1299 - val_class_loss: 0.6985 - val_speddup_loss: 40481.0273 - val_class_acc: 0.6911 - val_speddup_acc: 0.0000e+00
# Epoch 32/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.7234 - class_loss: 0.6496 - speddup_loss: 13328.9283 - class_acc: 0.7157 - speddup_acc: 0.0000e+00 - val_loss: 3.1615 - val_class_loss: 0.7098 - val_speddup_loss: 41005.9297 - val_class_acc: 0.6789 - val_speddup_acc: 0.0000e+00
# Epoch 33/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 2.0815 - class_loss: 0.6462 - speddup_loss: 20538.8663 - class_acc: 0.7128 - speddup_acc: 4.2693e-05 - val_loss: 3.1891 - val_class_loss: 0.7450 - val_speddup_loss: 40637.7969 - val_class_acc: 0.6606 - val_speddup_acc: 0.0000e+00
# Epoch 34/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.4565 - class_loss: 0.6672 - speddup_loss: 7569.5728 - class_acc: 0.7036 - speddup_acc: 3.4158e-04 - val_loss: 3.2241 - val_class_loss: 0.7600 - val_speddup_loss: 41324.6055 - val_class_acc: 0.6761 - val_speddup_acc: 0.0000e+00
# Epoch 35/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.4132 - class_loss: 0.6410 - speddup_loss: 7224.3119 - class_acc: 0.7115 - speddup_acc: 3.0138e-06 - val_loss: 3.3743 - val_class_loss: 0.9005 - val_speddup_loss: 40623.4258 - val_class_acc: 0.6383 - val_speddup_acc: 0.0000e+00
# Epoch 36/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.4950 - class_loss: 0.6836 - speddup_loss: 7730.3478 - class_acc: 0.6969 - speddup_acc: 1.0962e-04 - val_loss: 3.1285 - val_class_loss: 0.7159 - val_speddup_loss: 40395.7031 - val_class_acc: 0.6772 - val_speddup_acc: 0.0000e+00
# Epoch 37/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.3945 - class_loss: 0.6418 - speddup_loss: 6884.7839 - class_acc: 0.7121 - speddup_acc: 0.0000e+00 - val_loss: 3.1311 - val_class_loss: 0.6981 - val_speddup_loss: 40627.3867 - val_class_acc: 0.6922 - val_speddup_acc: 0.0000e+00
# Epoch 38/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.7575 - class_loss: 0.6497 - speddup_loss: 14003.6166 - class_acc: 0.7091 - speddup_acc: 0.0000e+00 - val_loss: 3.1338 - val_class_loss: 0.7034 - val_speddup_loss: 40624.0508 - val_class_acc: 0.6906 - val_speddup_acc: 0.0000e+00
# Epoch 39/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 2.1158 - class_loss: 0.6456 - speddup_loss: 21196.6660 - class_acc: 0.7125 - speddup_acc: 0.0000e+00 - val_loss: 3.1319 - val_class_loss: 0.7066 - val_speddup_loss: 40622.6758 - val_class_acc: 0.6850 - val_speddup_acc: 0.0000e+00
# Epoch 40/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.4882 - class_loss: 0.6318 - speddup_loss: 9050.9044 - class_acc: 0.7196 - speddup_acc: 0.0000e+00 - val_loss: 3.1396 - val_class_loss: 0.7096 - val_speddup_loss: 40623.6562 - val_class_acc: 0.6911 - val_speddup_acc: 0.0000e+00
# Epoch 41/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.1671 - class_loss: 0.6224 - speddup_loss: 2854.6084 - class_acc: 0.7245 - speddup_acc: 0.0000e+00 - val_loss: 3.1882 - val_class_loss: 0.7448 - val_speddup_loss: 40618.1562 - val_class_acc: 0.6739 - val_speddup_acc: 0.0000e+00
# Epoch 42/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.5904 - class_loss: 0.6266 - speddup_loss: 11165.1597 - class_acc: 0.7185 - speddup_acc: 0.0000e+00 - val_loss: 3.1447 - val_class_loss: 0.7098 - val_speddup_loss: 40601.5781 - val_class_acc: 0.6833 - val_speddup_acc: 0.0000e+00
# Epoch 43/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.7033 - class_loss: 0.6768 - speddup_loss: 12146.5335 - class_acc: 0.7005 - speddup_acc: 0.0000e+00 - val_loss: 3.1085 - val_class_loss: 0.6800 - val_speddup_loss: 40612.3125 - val_class_acc: 0.7028 - val_speddup_acc: 0.0000e+00
# Epoch 44/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.2171 - class_loss: 0.6082 - speddup_loss: 4035.9564 - class_acc: 0.7268 - speddup_acc: 3.3733e-04 - val_loss: 3.1785 - val_class_loss: 0.7378 - val_speddup_loss: 40588.1953 - val_class_acc: 0.6850 - val_speddup_acc: 0.0000e+00
# Epoch 45/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.4471 - class_loss: 0.6373 - speddup_loss: 7913.1577 - class_acc: 0.7216 - speddup_acc: 0.0000e+00 - val_loss: 3.1533 - val_class_loss: 0.7290 - val_speddup_loss: 40591.8516 - val_class_acc: 0.6678 - val_speddup_acc: 0.0000e+00
# Epoch 46/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.6626 - class_loss: 0.6242 - speddup_loss: 12741.8499 - class_acc: 0.7196 - speddup_acc: 4.4031e-04 - val_loss: 3.2653 - val_class_loss: 0.7488 - val_speddup_loss: 42530.6055 - val_class_acc: 0.6678 - val_speddup_acc: 0.0000e+00
# Epoch 47/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.4141 - class_loss: 0.6432 - speddup_loss: 7313.7455 - class_acc: 0.7175 - speddup_acc: 4.4334e-05 - val_loss: 3.1865 - val_class_loss: 0.7579 - val_speddup_loss: 40646.1875 - val_class_acc: 0.6711 - val_speddup_acc: 0.0000e+00
# Epoch 48/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.3881 - class_loss: 0.6160 - speddup_loss: 7266.5005 - class_acc: 0.7257 - speddup_acc: 0.0000e+00 - val_loss: 3.1207 - val_class_loss: 0.7017 - val_speddup_loss: 40619.3281 - val_class_acc: 0.6989 - val_speddup_acc: 0.0000e+00
# Epoch 49/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.4130 - class_loss: 0.6082 - speddup_loss: 8081.5398 - class_acc: 0.7278 - speddup_acc: 4.8415e-04 - val_loss: 3.1387 - val_class_loss: 0.6914 - val_speddup_loss: 40604.8438 - val_class_acc: 0.6922 - val_speddup_acc: 0.0000e+00
# Epoch 50/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.9664 - class_loss: 0.6293 - speddup_loss: 18444.3433 - class_acc: 0.7172 - speddup_acc: 5.9118e-05 - val_loss: 3.1684 - val_class_loss: 0.6996 - val_speddup_loss: 41053.2266 - val_class_acc: 0.6861 - val_speddup_acc: 0.0000e+00
# Epoch 51/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 2.0630 - class_loss: 0.6017 - speddup_loss: 20990.1016 - class_acc: 0.7326 - speddup_acc: 2.2705e-04 - val_loss: 3.1993 - val_class_loss: 0.7430 - val_speddup_loss: 40818.4141 - val_class_acc: 0.6833 - val_speddup_acc: 0.0000e+00
# Epoch 52/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.6320 - class_loss: 0.6301 - speddup_loss: 11855.7383 - class_acc: 0.7221 - speddup_acc: 1.6811e-04 - val_loss: 3.1005 - val_class_loss: 0.6815 - val_speddup_loss: 40605.4766 - val_class_acc: 0.6972 - val_speddup_acc: 0.0000e+00
# Epoch 53/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.7691 - class_loss: 0.6054 - speddup_loss: 15334.1900 - class_acc: 0.7288 - speddup_acc: 7.3783e-05 - val_loss: 3.1790 - val_class_loss: 0.7490 - val_speddup_loss: 40861.7422 - val_class_acc: 0.6756 - val_speddup_acc: 0.0000e+00
# Epoch 54/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.8258 - class_loss: 0.6123 - speddup_loss: 15805.4839 - class_acc: 0.7278 - speddup_acc: 1.3701e-04 - val_loss: 3.1265 - val_class_loss: 0.6898 - val_speddup_loss: 40747.9648 - val_class_acc: 0.7000 - val_speddup_acc: 0.0000e+00
# Epoch 55/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.1933 - class_loss: 0.5924 - speddup_loss: 3957.3264 - class_acc: 0.7380 - speddup_acc: 1.7231e-04 - val_loss: 3.1637 - val_class_loss: 0.7112 - val_speddup_loss: 40866.7500 - val_class_acc: 0.6867 - val_speddup_acc: 0.0000e+00
# Epoch 56/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.8560 - class_loss: 0.5893 - speddup_loss: 16964.9069 - class_acc: 0.7336 - speddup_acc: 2.5386e-04 - val_loss: 3.0854 - val_class_loss: 0.6653 - val_speddup_loss: 40676.5742 - val_class_acc: 0.7072 - val_speddup_acc: 0.0000e+00
# Epoch 57/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.2605 - class_loss: 0.5792 - speddup_loss: 5740.7422 - class_acc: 0.7361 - speddup_acc: 0.0000e+00 - val_loss: 3.0601 - val_class_loss: 0.7132 - val_speddup_loss: 39147.1367 - val_class_acc: 0.7039 - val_speddup_acc: 0.0000e+00
# Epoch 58/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.4186 - class_loss: 0.5927 - speddup_loss: 8618.3075 - class_acc: 0.7361 - speddup_acc: 2.0677e-04 - val_loss: 3.0756 - val_class_loss: 0.6654 - val_speddup_loss: 40593.0039 - val_class_acc: 0.7089 - val_speddup_acc: 0.0000e+00
# Epoch 59/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.2601 - class_loss: 0.5768 - speddup_loss: 5851.4949 - class_acc: 0.7453 - speddup_acc: 0.0000e+00 - val_loss: 3.1404 - val_class_loss: 0.7246 - val_speddup_loss: 40639.7773 - val_class_acc: 0.6950 - val_speddup_acc: 0.0000e+00
# Epoch 60/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.5433 - class_loss: 0.5789 - speddup_loss: 11354.7577 - class_acc: 0.7402 - speddup_acc: 0.0000e+00 - val_loss: 3.1594 - val_class_loss: 0.6954 - val_speddup_loss: 40948.1172 - val_class_acc: 0.7028 - val_speddup_acc: 0.0000e+00
# Epoch 61/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.2673 - class_loss: 0.6016 - speddup_loss: 4681.9515 - class_acc: 0.7313 - speddup_acc: 2.0238e-04 - val_loss: 3.1017 - val_class_loss: 0.6534 - val_speddup_loss: 40780.5625 - val_class_acc: 0.7089 - val_speddup_acc: 0.0000e+00
# Epoch 62/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.2577 - class_loss: 0.5894 - speddup_loss: 5359.2996 - class_acc: 0.7377 - speddup_acc: 2.4959e-04 - val_loss: 3.0982 - val_class_loss: 0.6729 - val_speddup_loss: 40620.5117 - val_class_acc: 0.7122 - val_speddup_acc: 0.0000e+00
# Epoch 63/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.9584 - class_loss: 0.5867 - speddup_loss: 19514.2158 - class_acc: 0.7394 - speddup_acc: 1.8251e-05 - val_loss: 3.1252 - val_class_loss: 0.6960 - val_speddup_loss: 40631.0547 - val_class_acc: 0.6878 - val_speddup_acc: 0.0000e+00
# Epoch 64/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.7486 - class_loss: 0.5827 - speddup_loss: 15259.1004 - class_acc: 0.7402 - speddup_acc: 2.0412e-05 - val_loss: 3.1188 - val_class_loss: 0.6833 - val_speddup_loss: 40611.5469 - val_class_acc: 0.7078 - val_speddup_acc: 0.0000e+00
# Epoch 65/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.4628 - class_loss: 0.6085 - speddup_loss: 8745.5073 - class_acc: 0.7280 - speddup_acc: 1.6139e-04 - val_loss: 3.1295 - val_class_loss: 0.6775 - val_speddup_loss: 40845.9023 - val_class_acc: 0.7078 - val_speddup_acc: 0.0000e+00
# Epoch 66/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.1250 - class_loss: 0.5826 - speddup_loss: 2702.4688 - class_acc: 0.7381 - speddup_acc: 2.1300e-04 - val_loss: 3.4002 - val_class_loss: 0.7426 - val_speddup_loss: 44767.2539 - val_class_acc: 0.6917 - val_speddup_acc: 0.0000e+00
# Epoch 67/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.6801 - class_loss: 0.6224 - speddup_loss: 12909.8047 - class_acc: 0.7261 - speddup_acc: 6.1921e-05 - val_loss: 3.1093 - val_class_loss: 0.6900 - val_speddup_loss: 40687.6367 - val_class_acc: 0.6922 - val_speddup_acc: 0.0000e+00
# Epoch 68/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.2870 - class_loss: 0.5730 - speddup_loss: 6330.9842 - class_acc: 0.7434 - speddup_acc: 1.7877e-06 - val_loss: 3.1027 - val_class_loss: 0.6737 - val_speddup_loss: 40714.3008 - val_class_acc: 0.7150 - val_speddup_acc: 0.0000e+00
# Epoch 69/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.9271 - class_loss: 0.6023 - speddup_loss: 18520.9490 - class_acc: 0.7420 - speddup_acc: 4.2689e-07 - val_loss: 3.0821 - val_class_loss: 0.6672 - val_speddup_loss: 40669.2148 - val_class_acc: 0.7028 - val_speddup_acc: 0.0000e+00
# Epoch 70/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.6451 - class_loss: 0.5804 - speddup_loss: 13457.9299 - class_acc: 0.7428 - speddup_acc: 2.0076e-04 - val_loss: 3.0999 - val_class_loss: 0.6779 - val_speddup_loss: 40697.8594 - val_class_acc: 0.6917 - val_speddup_acc: 0.0000e+00
# Epoch 71/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.7656 - class_loss: 0.5928 - speddup_loss: 15248.9290 - class_acc: 0.7335 - speddup_acc: 5.5389e-04 - val_loss: 3.1172 - val_class_loss: 0.6882 - val_speddup_loss: 40667.5703 - val_class_acc: 0.7044 - val_speddup_acc: 0.0000e+00
# Epoch 72/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.9292 - class_loss: 0.5784 - speddup_loss: 18968.0322 - class_acc: 0.7435 - speddup_acc: 1.9503e-04 - val_loss: 3.1055 - val_class_loss: 0.6784 - val_speddup_loss: 40634.0273 - val_class_acc: 0.7000 - val_speddup_acc: 0.0000e+00
# Epoch 73/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.3277 - class_loss: 0.5887 - speddup_loss: 6730.8307 - class_acc: 0.7469 - speddup_acc: 2.2287e-04 - val_loss: 3.3899 - val_class_loss: 0.7721 - val_speddup_loss: 40669.3125 - val_class_acc: 0.6717 - val_speddup_acc: 0.0000e+00
# Epoch 74/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.4084 - class_loss: 0.6205 - speddup_loss: 5103.6979 - class_acc: 0.7290 - speddup_acc: 0.0000e+00 - val_loss: 3.1421 - val_class_loss: 0.6765 - val_speddup_loss: 40809.7930 - val_class_acc: 0.7028 - val_speddup_acc: 0.0000e+00
# Epoch 75/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.2457 - class_loss: 0.5843 - speddup_loss: 4861.6822 - class_acc: 0.7413 - speddup_acc: 0.0000e+00 - val_loss: 2.9879 - val_class_loss: 0.6875 - val_speddup_loss: 37742.3555 - val_class_acc: 0.7083 - val_speddup_acc: 0.0000e+00
# Epoch 76/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.1894 - class_loss: 0.5682 - speddup_loss: 4183.1756 - class_acc: 0.7463 - speddup_acc: 0.0000e+00 - val_loss: 3.1265 - val_class_loss: 0.6913 - val_speddup_loss: 40563.6016 - val_class_acc: 0.6911 - val_speddup_acc: 0.0000e+00
# Epoch 77/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.4906 - class_loss: 0.5635 - speddup_loss: 10407.6963 - class_acc: 0.7469 - speddup_acc: 0.0000e+00 - val_loss: 3.1369 - val_class_loss: 0.7032 - val_speddup_loss: 40732.9102 - val_class_acc: 0.7028 - val_speddup_acc: 0.0000e+00
# Epoch 78/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.2185 - class_loss: 0.5610 - speddup_loss: 5092.0089 - class_acc: 0.7485 - speddup_acc: 0.0000e+00 - val_loss: 3.0891 - val_class_loss: 0.6541 - val_speddup_loss: 40648.2383 - val_class_acc: 0.7194 - val_speddup_acc: 0.0000e+00
# Epoch 79/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.8296 - class_loss: 0.5695 - speddup_loss: 17153.0393 - class_acc: 0.7469 - speddup_acc: 0.0000e+00 - val_loss: 3.1414 - val_class_loss: 0.6866 - val_speddup_loss: 41140.6211 - val_class_acc: 0.7011 - val_speddup_acc: 0.0000e+00
# Epoch 80/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.2059 - class_loss: 0.5511 - speddup_loss: 5037.2468 - class_acc: 0.7550 - speddup_acc: 3.8733e-05 - val_loss: 3.1763 - val_class_loss: 0.7304 - val_speddup_loss: 40807.0117 - val_class_acc: 0.7050 - val_speddup_acc: 0.0000e+00
# Epoch 81/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.5466 - class_loss: 0.5570 - speddup_loss: 11732.5164 - class_acc: 0.7603 - speddup_acc: 6.2966e-05 - val_loss: 3.2180 - val_class_loss: 0.6884 - val_speddup_loss: 42524.0117 - val_class_acc: 0.7078 - val_speddup_acc: 0.0000e+00
# Epoch 82/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.8855 - class_loss: 0.5712 - speddup_loss: 18096.4555 - class_acc: 0.7501 - speddup_acc: 2.3193e-04 - val_loss: 3.1789 - val_class_loss: 0.7331 - val_speddup_loss: 40671.8477 - val_class_acc: 0.7044 - val_speddup_acc: 0.0000e+00
# Epoch 83/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.8854 - class_loss: 0.5499 - speddup_loss: 18418.2356 - class_acc: 0.7596 - speddup_acc: 1.7975e-04 - val_loss: 3.1341 - val_class_loss: 0.6600 - val_speddup_loss: 41082.7930 - val_class_acc: 0.7056 - val_speddup_acc: 0.0000e+00
# Epoch 84/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.1373 - class_loss: 0.5567 - speddup_loss: 3163.1357 - class_acc: 0.7527 - speddup_acc: 5.0410e-05 - val_loss: 3.0992 - val_class_loss: 0.6646 - val_speddup_loss: 40695.9805 - val_class_acc: 0.7106 - val_speddup_acc: 0.0000e+00
# Epoch 85/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.4641 - class_loss: 0.5507 - speddup_loss: 10079.1698 - class_acc: 0.7540 - speddup_acc: 4.1561e-05 - val_loss: 3.1161 - val_class_loss: 0.6874 - val_speddup_loss: 40629.3125 - val_class_acc: 0.7022 - val_speddup_acc: 0.0000e+00
# Epoch 86/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.3042 - class_loss: 0.5528 - speddup_loss: 6966.9711 - class_acc: 0.7563 - speddup_acc: 8.1180e-05 - val_loss: 3.1236 - val_class_loss: 0.6863 - val_speddup_loss: 40753.7070 - val_class_acc: 0.7094 - val_speddup_acc: 0.0000e+00
# Epoch 87/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.4739 - class_loss: 0.5678 - speddup_loss: 9738.2403 - class_acc: 0.7505 - speddup_acc: 4.7910e-04 - val_loss: 3.0744 - val_class_loss: 0.6357 - val_speddup_loss: 40803.8672 - val_class_acc: 0.7194 - val_speddup_acc: 0.0000e+00
# Epoch 88/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.5219 - class_loss: 0.5465 - speddup_loss: 11443.0432 - class_acc: 0.7552 - speddup_acc: 2.5046e-04 - val_loss: 3.1402 - val_class_loss: 0.6758 - val_speddup_loss: 40780.4258 - val_class_acc: 0.7072 - val_speddup_acc: 0.0000e+00
# Epoch 89/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.0860 - class_loss: 0.5521 - speddup_loss: 2451.7041 - class_acc: 0.7497 - speddup_acc: 2.8618e-04 - val_loss: 3.0906 - val_class_loss: 0.6555 - val_speddup_loss: 40632.9102 - val_class_acc: 0.7094 - val_speddup_acc: 0.0000e+00
# Epoch 90/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.6805 - class_loss: 0.5688 - speddup_loss: 14123.1485 - class_acc: 0.7467 - speddup_acc: 2.8808e-04 - val_loss: 3.0974 - val_class_loss: 0.6501 - val_speddup_loss: 41079.5469 - val_class_acc: 0.7078 - val_speddup_acc: 0.0000e+00
# Epoch 91/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.4672 - class_loss: 0.5585 - speddup_loss: 10100.1057 - class_acc: 0.7532 - speddup_acc: 2.6611e-04 - val_loss: 3.1166 - val_class_loss: 0.6799 - val_speddup_loss: 40890.0781 - val_class_acc: 0.7172 - val_speddup_acc: 0.0000e+00
# Epoch 92/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.4719 - class_loss: 0.5473 - speddup_loss: 10532.2197 - class_acc: 0.7610 - speddup_acc: 6.5413e-05 - val_loss: 3.1762 - val_class_loss: 0.6855 - val_speddup_loss: 42064.5195 - val_class_acc: 0.7161 - val_speddup_acc: 0.0000e+00
# Epoch 93/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.2396 - class_loss: 0.5420 - speddup_loss: 5885.6941 - class_acc: 0.7611 - speddup_acc: 3.9470e-04 - val_loss: 3.1019 - val_class_loss: 0.6737 - val_speddup_loss: 40768.4492 - val_class_acc: 0.7094 - val_speddup_acc: 0.0000e+00
# Epoch 94/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.3822 - class_loss: 0.5299 - speddup_loss: 9056.4777 - class_acc: 0.7671 - speddup_acc: 2.1541e-04 - val_loss: 3.0980 - val_class_loss: 0.6612 - val_speddup_loss: 40920.5195 - val_class_acc: 0.7061 - val_speddup_acc: 0.0000e+00
# Epoch 95/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.4265 - class_loss: 0.5270 - speddup_loss: 10134.1509 - class_acc: 0.7672 - speddup_acc: 5.7075e-05 - val_loss: 3.1388 - val_class_loss: 0.6935 - val_speddup_loss: 40821.4766 - val_class_acc: 0.7089 - val_speddup_acc: 0.0000e+00
# Epoch 96/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.2644 - class_loss: 0.5347 - speddup_loss: 6609.2574 - class_acc: 0.7607 - speddup_acc: 8.0572e-05 - val_loss: 3.0877 - val_class_loss: 0.6514 - val_speddup_loss: 40960.5625 - val_class_acc: 0.7200 - val_speddup_acc: 0.0000e+00
# Epoch 97/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.1302 - class_loss: 0.5231 - speddup_loss: 4204.2506 - class_acc: 0.7691 - speddup_acc: 0.0000e+00 - val_loss: 3.0791 - val_class_loss: 0.6657 - val_speddup_loss: 40674.5938 - val_class_acc: 0.7150 - val_speddup_acc: 0.0000e+00
# Epoch 98/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 2.2453 - class_loss: 0.5368 - speddup_loss: 26199.6153 - class_acc: 0.7691 - speddup_acc: 7.9739e-05 - val_loss: 3.1080 - val_class_loss: 0.6703 - val_speddup_loss: 40742.4258 - val_class_acc: 0.7139 - val_speddup_acc: 0.0000e+00
# Epoch 99/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.2700 - class_loss: 0.5478 - speddup_loss: 6262.7452 - class_acc: 0.7604 - speddup_acc: 1.0622e-04 - val_loss: 3.1141 - val_class_loss: 0.6725 - val_speddup_loss: 40613.6250 - val_class_acc: 0.7194 - val_speddup_acc: 0.0000e+00
# Epoch 100/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.6905 - class_loss: 0.5448 - speddup_loss: 14624.8359 - class_acc: 0.7638 - speddup_acc: 1.6127e-04 - val_loss: 3.1303 - val_class_loss: 0.6853 - val_speddup_loss: 40773.7930 - val_class_acc: 0.6933 - val_speddup_acc: 0.0000e+00
# Epoch 101/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.9431 - class_loss: 0.5541 - speddup_loss: 19464.5779 - class_acc: 0.7535 - speddup_acc: 1.0378e-04 - val_loss: 3.0949 - val_class_loss: 0.6641 - val_speddup_loss: 40676.3750 - val_class_acc: 0.7267 - val_speddup_acc: 0.0000e+00
# Epoch 102/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.4776 - class_loss: 0.5237 - speddup_loss: 11071.3587 - class_acc: 0.7703 - speddup_acc: 1.7456e-04 - val_loss: 3.1099 - val_class_loss: 0.6697 - val_speddup_loss: 40827.7031 - val_class_acc: 0.7239 - val_speddup_acc: 0.0000e+00
# Epoch 103/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.5511 - class_loss: 0.5297 - speddup_loss: 12342.0741 - class_acc: 0.7679 - speddup_acc: 2.8807e-04 - val_loss: 3.1121 - val_class_loss: 0.6684 - val_speddup_loss: 40711.8008 - val_class_acc: 0.7139 - val_speddup_acc: 0.0000e+00
# Epoch 104/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.5066 - class_loss: 0.5290 - speddup_loss: 11438.3066 - class_acc: 0.7640 - speddup_acc: 6.4676e-04 - val_loss: 3.1360 - val_class_loss: 0.6798 - val_speddup_loss: 40707.9961 - val_class_acc: 0.7122 - val_speddup_acc: 0.0000e+00
# Epoch 105/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.6466 - class_loss: 0.5367 - speddup_loss: 13945.2014 - class_acc: 0.7656 - speddup_acc: 2.5665e-04 - val_loss: 3.0791 - val_class_loss: 0.6493 - val_speddup_loss: 40695.2930 - val_class_acc: 0.7172 - val_speddup_acc: 0.0000e+00
# Epoch 106/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.7417 - class_loss: 0.5355 - speddup_loss: 16213.4738 - class_acc: 0.7607 - speddup_acc: 7.2402e-05 - val_loss: 3.1278 - val_class_loss: 0.6923 - val_speddup_loss: 40736.7969 - val_class_acc: 0.6972 - val_speddup_acc: 0.0000e+00
# Epoch 107/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.1021 - class_loss: 0.5315 - speddup_loss: 3384.4694 - class_acc: 0.7668 - speddup_acc: 7.1366e-05 - val_loss: 3.0945 - val_class_loss: 0.6606 - val_speddup_loss: 40707.9062 - val_class_acc: 0.7244 - val_speddup_acc: 0.0000e+00
# Epoch 108/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.4315 - class_loss: 0.5105 - speddup_loss: 10425.6991 - class_acc: 0.7736 - speddup_acc: 4.3436e-04 - val_loss: 3.1163 - val_class_loss: 0.6873 - val_speddup_loss: 40755.9297 - val_class_acc: 0.7056 - val_speddup_acc: 0.0000e+00
# Epoch 109/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.0864 - class_loss: 0.5213 - speddup_loss: 3298.5056 - class_acc: 0.7694 - speddup_acc: 1.8340e-04 - val_loss: 3.1540 - val_class_loss: 0.6839 - val_speddup_loss: 40932.6758 - val_class_acc: 0.7067 - val_speddup_acc: 0.0000e+00
# Epoch 110/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.0589 - class_loss: 0.5259 - speddup_loss: 2565.4483 - class_acc: 0.7672 - speddup_acc: 1.5110e-04 - val_loss: 3.1099 - val_class_loss: 0.6735 - val_speddup_loss: 41112.0742 - val_class_acc: 0.7161 - val_speddup_acc: 0.0000e+00
# Epoch 111/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.3545 - class_loss: 0.5135 - speddup_loss: 8863.5794 - class_acc: 0.7772 - speddup_acc: 1.7923e-04 - val_loss: 3.0875 - val_class_loss: 0.6568 - val_speddup_loss: 40658.3164 - val_class_acc: 0.7189 - val_speddup_acc: 0.0000e+00
# Epoch 112/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.4911 - class_loss: 0.5190 - speddup_loss: 11309.4415 - class_acc: 0.7695 - speddup_acc: 2.4034e-04 - val_loss: 3.1383 - val_class_loss: 0.6848 - val_speddup_loss: 40781.7461 - val_class_acc: 0.7072 - val_speddup_acc: 0.0000e+00
# Epoch 113/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.2851 - class_loss: 0.5172 - speddup_loss: 7101.1289 - class_acc: 0.7691 - speddup_acc: 2.8384e-04 - val_loss: 3.1426 - val_class_loss: 0.6758 - val_speddup_loss: 41362.8516 - val_class_acc: 0.7267 - val_speddup_acc: 0.0000e+00
# Epoch 114/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.3056 - class_loss: 0.5113 - speddup_loss: 7792.9532 - class_acc: 0.7719 - speddup_acc: 1.6718e-04 - val_loss: 3.0921 - val_class_loss: 0.6551 - val_speddup_loss: 40630.6914 - val_class_acc: 0.7133 - val_speddup_acc: 0.0000e+00
# Epoch 115/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.3321 - class_loss: 0.5182 - speddup_loss: 8127.7157 - class_acc: 0.7701 - speddup_acc: 6.5470e-04 - val_loss: 3.1100 - val_class_loss: 0.6769 - val_speddup_loss: 40856.6016 - val_class_acc: 0.7106 - val_speddup_acc: 0.0000e+00
# Epoch 116/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.2863 - class_loss: 0.5098 - speddup_loss: 7714.3558 - class_acc: 0.7708 - speddup_acc: 3.0777e-04 - val_loss: 3.1368 - val_class_loss: 0.6875 - val_speddup_loss: 40773.1875 - val_class_acc: 0.7017 - val_speddup_acc: 0.0000e+00
# Epoch 117/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.3706 - class_loss: 0.5191 - speddup_loss: 8865.1367 - class_acc: 0.7668 - speddup_acc: 1.8437e-04 - val_loss: 3.0832 - val_class_loss: 0.6551 - val_speddup_loss: 40710.0391 - val_class_acc: 0.7250 - val_speddup_acc: 0.0000e+00
# Epoch 118/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.8191 - class_loss: 0.5116 - speddup_loss: 18128.5013 - class_acc: 0.7726 - speddup_acc: 1.6888e-04 - val_loss: 3.1659 - val_class_loss: 0.7038 - val_speddup_loss: 40981.5195 - val_class_acc: 0.7022 - val_speddup_acc: 0.0000e+00
# Epoch 119/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.3402 - class_loss: 0.5270 - speddup_loss: 8061.2241 - class_acc: 0.7667 - speddup_acc: 2.7566e-04 - val_loss: 3.1557 - val_class_loss: 0.6718 - val_speddup_loss: 40649.4648 - val_class_acc: 0.7067 - val_speddup_acc: 0.0000e+00
# Epoch 120/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.4026 - class_loss: 0.5289 - speddup_loss: 8860.7261 - class_acc: 0.7632 - speddup_acc: 3.6625e-04 - val_loss: 3.1229 - val_class_loss: 0.6770 - val_speddup_loss: 41032.4648 - val_class_acc: 0.7261 - val_speddup_acc: 0.0000e+00
# Epoch 121/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.6041 - class_loss: 0.5183 - speddup_loss: 13525.8716 - class_acc: 0.7689 - speddup_acc: 3.4377e-04 - val_loss: 3.0960 - val_class_loss: 0.6652 - val_speddup_loss: 40679.5859 - val_class_acc: 0.7217 - val_speddup_acc: 0.0000e+00
# Epoch 122/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.2303 - class_loss: 0.5022 - speddup_loss: 6567.1197 - class_acc: 0.7743 - speddup_acc: 9.6944e-05 - val_loss: 3.0632 - val_class_loss: 0.6366 - val_speddup_loss: 40785.2305 - val_class_acc: 0.7261 - val_speddup_acc: 0.0000e+00
# Epoch 123/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.3257 - class_loss: 0.5096 - speddup_loss: 8338.9694 - class_acc: 0.7730 - speddup_acc: 1.1669e-04 - val_loss: 3.0673 - val_class_loss: 0.6385 - val_speddup_loss: 40859.1211 - val_class_acc: 0.7183 - val_speddup_acc: 0.0000e+00
# Epoch 124/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.1301 - class_loss: 0.5101 - speddup_loss: 4470.2689 - class_acc: 0.7725 - speddup_acc: 2.9222e-04 - val_loss: 3.1196 - val_class_loss: 0.6780 - val_speddup_loss: 41114.8125 - val_class_acc: 0.6994 - val_speddup_acc: 0.0000e+00
# Epoch 125/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.2768 - class_loss: 0.5163 - speddup_loss: 7282.0499 - class_acc: 0.7732 - speddup_acc: 2.8262e-04 - val_loss: 3.1533 - val_class_loss: 0.6622 - val_speddup_loss: 41600.3828 - val_class_acc: 0.7161 - val_speddup_acc: 0.0000e+00
# Epoch 126/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.2984 - class_loss: 0.5093 - speddup_loss: 7615.3449 - class_acc: 0.7736 - speddup_acc: 2.0717e-04 - val_loss: 3.1253 - val_class_loss: 0.6790 - val_speddup_loss: 41058.0039 - val_class_acc: 0.7094 - val_speddup_acc: 0.0000e+00
# Epoch 127/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.2355 - class_loss: 0.5142 - speddup_loss: 6379.8079 - class_acc: 0.7738 - speddup_acc: 3.8511e-04 - val_loss: 3.1125 - val_class_loss: 0.6651 - val_speddup_loss: 40641.4844 - val_class_acc: 0.7167 - val_speddup_acc: 0.0000e+00
# Epoch 128/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.6076 - class_loss: 0.5480 - speddup_loss: 12610.7879 - class_acc: 0.7565 - speddup_acc: 2.1033e-04 - val_loss: 3.0970 - val_class_loss: 0.6507 - val_speddup_loss: 40868.1641 - val_class_acc: 0.7233 - val_speddup_acc: 0.0000e+00
# Epoch 129/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.6383 - class_loss: 0.5081 - speddup_loss: 14593.3967 - class_acc: 0.7742 - speddup_acc: 1.0058e-04 - val_loss: 3.1715 - val_class_loss: 0.6392 - val_speddup_loss: 42525.1875 - val_class_acc: 0.7200 - val_speddup_acc: 0.0000e+00
# Epoch 130/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.6989 - class_loss: 0.5152 - speddup_loss: 15662.4637 - class_acc: 0.7699 - speddup_acc: 1.8352e-04 - val_loss: 3.1108 - val_class_loss: 0.6546 - val_speddup_loss: 41256.6562 - val_class_acc: 0.7311 - val_speddup_acc: 0.0000e+00
# Epoch 131/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.2331 - class_loss: 0.5112 - speddup_loss: 6266.9344 - class_acc: 0.7683 - speddup_acc: 3.3596e-04 - val_loss: 3.0771 - val_class_loss: 0.6450 - val_speddup_loss: 40635.4648 - val_class_acc: 0.7150 - val_speddup_acc: 0.0000e+00
# Epoch 132/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.1064 - class_loss: 0.5149 - speddup_loss: 3583.7704 - class_acc: 0.7738 - speddup_acc: 2.2456e-04 - val_loss: 3.1419 - val_class_loss: 0.6697 - val_speddup_loss: 41122.0938 - val_class_acc: 0.7178 - val_speddup_acc: 0.0000e+00
# Epoch 133/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 2.0267 - class_loss: 0.5109 - speddup_loss: 21910.6320 - class_acc: 0.7768 - speddup_acc: 5.6727e-04 - val_loss: 3.1182 - val_class_loss: 0.6783 - val_speddup_loss: 40826.7344 - val_class_acc: 0.7144 - val_speddup_acc: 0.0000e+00
# Epoch 134/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.3970 - class_loss: 0.4963 - speddup_loss: 10003.2175 - class_acc: 0.7829 - speddup_acc: 1.3111e-04 - val_loss: 3.1164 - val_class_loss: 0.6470 - val_speddup_loss: 40897.0195 - val_class_acc: 0.6994 - val_speddup_acc: 0.0000e+00
# Epoch 135/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.1920 - class_loss: 0.5081 - speddup_loss: 5446.9952 - class_acc: 0.7770 - speddup_acc: 9.2892e-05 - val_loss: 3.0813 - val_class_loss: 0.6621 - val_speddup_loss: 40693.7227 - val_class_acc: 0.7200 - val_speddup_acc: 0.0000e+00
# Epoch 136/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 2.0973 - class_loss: 0.4911 - speddup_loss: 24044.7311 - class_acc: 0.7854 - speddup_acc: 2.3267e-04 - val_loss: 3.1084 - val_class_loss: 0.6689 - val_speddup_loss: 40663.8164 - val_class_acc: 0.7194 - val_speddup_acc: 0.0000e+00
# Epoch 137/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.8983 - class_loss: 0.5130 - speddup_loss: 19683.8248 - class_acc: 0.7765 - speddup_acc: 1.4695e-04 - val_loss: 3.0777 - val_class_loss: 0.6428 - val_speddup_loss: 40736.5195 - val_class_acc: 0.7256 - val_speddup_acc: 0.0000e+00
# Epoch 138/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.7451 - class_loss: 0.4878 - speddup_loss: 17075.3476 - class_acc: 0.7837 - speddup_acc: 2.0950e-04 - val_loss: 3.0903 - val_class_loss: 0.6630 - val_speddup_loss: 40725.1836 - val_class_acc: 0.7328 - val_speddup_acc: 0.0000e+00
# Epoch 139/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.0781 - class_loss: 0.5089 - speddup_loss: 3335.7920 - class_acc: 0.7759 - speddup_acc: 2.9932e-04 - val_loss: 3.1426 - val_class_loss: 0.6890 - val_speddup_loss: 40615.0508 - val_class_acc: 0.7133 - val_speddup_acc: 0.0000e+00
# Epoch 140/200
# ...
# Epoch 153/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.1476 - class_loss: 0.4891 - speddup_loss: 4917.9880 - class_acc: 0.7793 - speddup_acc: 9.6201e-05 - val_loss: 3.1143 - val_class_loss: 0.6419 - val_speddup_loss: 40913.9375 - val_class_acc: 0.7239 - val_speddup_acc: 0.0000e+00
# Epoch 154/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.1827 - class_loss: 0.4870 - speddup_loss: 5764.0763 - class_acc: 0.7836 - speddup_acc: 1.6479e-04 - val_loss: 3.1119 - val_class_loss: 0.6503 - val_speddup_loss: 40927.5469 - val_class_acc: 0.7289 - val_speddup_acc: 0.0000e+00
# Epoch 155/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.2785 - class_loss: 0.5055 - speddup_loss: 7006.7530 - class_acc: 0.7803 - speddup_acc: 1.3864e-04 - val_loss: 3.0899 - val_class_loss: 0.6520 - val_speddup_loss: 40761.4414 - val_class_acc: 0.7289 - val_speddup_acc: 0.0000e+00
# Epoch 156/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.1159 - class_loss: 0.4906 - speddup_loss: 4360.1393 - class_acc: 0.7797 - speddup_acc: 1.6155e-04 - val_loss: 3.1329 - val_class_loss: 0.6891 - val_speddup_loss: 40866.6914 - val_class_acc: 0.7178 - val_speddup_acc: 0.0000e+00
# Epoch 157/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.9816 - class_loss: 0.4801 - speddup_loss: 21863.4802 - class_acc: 0.7877 - speddup_acc: 1.1462e-04 - val_loss: 3.1673 - val_class_loss: 0.7060 - val_speddup_loss: 41067.0898 - val_class_acc: 0.7161 - val_speddup_acc: 0.0000e+00
# Epoch 158/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.3185 - class_loss: 0.4911 - speddup_loss: 8249.3987 - class_acc: 0.7776 - speddup_acc: 6.0405e-05 - val_loss: 3.1080 - val_class_loss: 0.6637 - val_speddup_loss: 40719.4648 - val_class_acc: 0.7261 - val_speddup_acc: 0.0000e+00
# Epoch 159/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.2993 - class_loss: 0.4792 - speddup_loss: 8317.5983 - class_acc: 0.7843 - speddup_acc: 2.1267e-04 - val_loss: 3.1063 - val_class_loss: 0.6552 - val_speddup_loss: 40831.5039 - val_class_acc: 0.7294 - val_speddup_acc: 0.0000e+00
# Epoch 160/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.3645 - class_loss: 0.4849 - speddup_loss: 9286.9351 - class_acc: 0.7893 - speddup_acc: 3.3433e-04 - val_loss: 3.1126 - val_class_loss: 0.6744 - val_speddup_loss: 40790.7539 - val_class_acc: 0.7178 - val_speddup_acc: 0.0000e+00
# Epoch 161/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.6328 - class_loss: 0.4874 - speddup_loss: 14748.7440 - class_acc: 0.7822 - speddup_acc: 7.2206e-05 - val_loss: 3.1128 - val_class_loss: 0.6840 - val_speddup_loss: 40583.8047 - val_class_acc: 0.7017 - val_speddup_acc: 0.0000e+00
# Epoch 162/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.1755 - class_loss: 0.4887 - speddup_loss: 5617.3739 - class_acc: 0.7820 - speddup_acc: 4.6630e-04 - val_loss: 3.1036 - val_class_loss: 0.6559 - val_speddup_loss: 40815.3867 - val_class_acc: 0.7272 - val_speddup_acc: 0.0000e+00
# Epoch 163/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.2137 - class_loss: 0.4959 - speddup_loss: 6004.3751 - class_acc: 0.7805 - speddup_acc: 1.8606e-04 - val_loss: 3.1212 - val_class_loss: 0.6813 - val_speddup_loss: 40815.4414 - val_class_acc: 0.7328 - val_speddup_acc: 0.0000e+00
# Epoch 164/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.7598 - class_loss: 0.4872 - speddup_loss: 17076.2670 - class_acc: 0.7772 - speddup_acc: 4.8864e-05 - val_loss: 3.1087 - val_class_loss: 0.6535 - val_speddup_loss: 40888.4219 - val_class_acc: 0.7300 - val_speddup_acc: 0.0000e+00
# Epoch 165/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.1337 - class_loss: 0.4896 - speddup_loss: 4631.9020 - class_acc: 0.7862 - speddup_acc: 1.6043e-04 - val_loss: 3.1262 - val_class_loss: 0.6907 - val_speddup_loss: 40651.9414 - val_class_acc: 0.7267 - val_speddup_acc: 0.0000e+00
# Epoch 166/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.2125 - class_loss: 0.4864 - speddup_loss: 6303.9074 - class_acc: 0.7893 - speddup_acc: 1.8219e-04 - val_loss: 3.1531 - val_class_loss: 0.7122 - val_speddup_loss: 40719.4414 - val_class_acc: 0.7083 - val_speddup_acc: 0.0000e+00
# Epoch 167/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.5081 - class_loss: 0.5008 - speddup_loss: 11894.2260 - class_acc: 0.7818 - speddup_acc: 1.2998e-04 - val_loss: 3.1059 - val_class_loss: 0.6639 - val_speddup_loss: 40796.3359 - val_class_acc: 0.7106 - val_speddup_acc: 0.0000e+00
# Epoch 168/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.4874 - class_loss: 0.4875 - speddup_loss: 11843.8482 - class_acc: 0.7885 - speddup_acc: 1.0243e-04 - val_loss: 3.1591 - val_class_loss: 0.6916 - val_speddup_loss: 40778.9688 - val_class_acc: 0.7072 - val_speddup_acc: 0.0000e+00
# Epoch 169/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.6061 - class_loss: 0.4905 - speddup_loss: 13657.7463 - class_acc: 0.7862 - speddup_acc: 5.4937e-07 - val_loss: 3.1310 - val_class_loss: 0.6743 - val_speddup_loss: 40613.3945 - val_class_acc: 0.7250 - val_speddup_acc: 0.0000e+00
# Epoch 170/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.6579 - class_loss: 0.4816 - speddup_loss: 14950.0512 - class_acc: 0.7852 - speddup_acc: 1.3851e-04 - val_loss: 3.1127 - val_class_loss: 0.6502 - val_speddup_loss: 40725.1094 - val_class_acc: 0.7261 - val_speddup_acc: 0.0000e+00
# Epoch 171/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.6273 - class_loss: 0.4910 - speddup_loss: 14129.4019 - class_acc: 0.7840 - speddup_acc: 3.4500e-05 - val_loss: 3.1116 - val_class_loss: 0.6631 - val_speddup_loss: 40617.7500 - val_class_acc: 0.7239 - val_speddup_acc: 0.0000e+00
# Epoch 172/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 2.1931 - class_loss: 0.5247 - speddup_loss: 24466.4337 - class_acc: 0.7747 - speddup_acc: 4.0246e-05 - val_loss: 3.1681 - val_class_loss: 0.7004 - val_speddup_loss: 40901.0352 - val_class_acc: 0.7183 - val_speddup_acc: 0.0000e+00
# Epoch 173/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.6956 - class_loss: 0.4822 - speddup_loss: 15754.3072 - class_acc: 0.7860 - speddup_acc: 3.8841e-05 - val_loss: 3.0993 - val_class_loss: 0.6630 - val_speddup_loss: 40615.2070 - val_class_acc: 0.7217 - val_speddup_acc: 0.0000e+00
# Epoch 174/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.3371 - class_loss: 0.4850 - speddup_loss: 8576.6564 - class_acc: 0.7880 - speddup_acc: 2.4518e-04 - val_loss: 3.1242 - val_class_loss: 0.6791 - val_speddup_loss: 40556.3945 - val_class_acc: 0.7272 - val_speddup_acc: 0.0000e+00
# Epoch 175/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.1023 - class_loss: 0.4846 - speddup_loss: 3846.8125 - class_acc: 0.7883 - speddup_acc: 2.6334e-04 - val_loss: 3.1859 - val_class_loss: 0.7299 - val_speddup_loss: 40576.4844 - val_class_acc: 0.7189 - val_speddup_acc: 0.0000e+00
# Epoch 176/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.2610 - class_loss: 0.4898 - speddup_loss: 6733.9037 - class_acc: 0.7808 - speddup_acc: 1.8933e-04 - val_loss: 3.1798 - val_class_loss: 0.7229 - val_speddup_loss: 40702.3320 - val_class_acc: 0.7267 - val_speddup_acc: 0.0000e+00
# Epoch 177/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.6646 - class_loss: 0.4890 - speddup_loss: 15079.0406 - class_acc: 0.7815 - speddup_acc: 7.0961e-05 - val_loss: 3.1886 - val_class_loss: 0.7154 - val_speddup_loss: 40823.3359 - val_class_acc: 0.7239 - val_speddup_acc: 0.0000e+00
# Epoch 178/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.3780 - class_loss: 0.4831 - speddup_loss: 9076.4040 - class_acc: 0.7824 - speddup_acc: 3.1405e-05 - val_loss: 3.1459 - val_class_loss: 0.7155 - val_speddup_loss: 40666.9102 - val_class_acc: 0.7006 - val_speddup_acc: 0.0000e+00
# Epoch 179/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.0904 - class_loss: 0.4997 - speddup_loss: 3544.2847 - class_acc: 0.7778 - speddup_acc: 8.6631e-05 - val_loss: 3.1053 - val_class_loss: 0.6653 - val_speddup_loss: 40761.4453 - val_class_acc: 0.7322 - val_speddup_acc: 0.0000e+00
# Epoch 180/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.0859 - class_loss: 0.4742 - speddup_loss: 4201.8447 - class_acc: 0.7877 - speddup_acc: 2.2859e-04 - val_loss: 3.1517 - val_class_loss: 0.7150 - val_speddup_loss: 40778.4141 - val_class_acc: 0.7144 - val_speddup_acc: 0.0000e+00
# Epoch 181/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.1478 - class_loss: 0.4785 - speddup_loss: 5219.7320 - class_acc: 0.7897 - speddup_acc: 3.6287e-06 - val_loss: 3.1530 - val_class_loss: 0.6968 - val_speddup_loss: 40729.6172 - val_class_acc: 0.7311 - val_speddup_acc: 0.0000e+00
# Epoch 182/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.3718 - class_loss: 0.5335 - speddup_loss: 8165.8244 - class_acc: 0.7674 - speddup_acc: 2.0729e-04 - val_loss: 3.1250 - val_class_loss: 0.6634 - val_speddup_loss: 40654.5703 - val_class_acc: 0.7228 - val_speddup_acc: 0.0000e+00
# Epoch 183/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.4166 - class_loss: 0.4868 - speddup_loss: 10104.6195 - class_acc: 0.7879 - speddup_acc: 2.1537e-04 - val_loss: 3.1429 - val_class_loss: 0.6727 - val_speddup_loss: 40888.2891 - val_class_acc: 0.7217 - val_speddup_acc: 0.0000e+00
# Epoch 184/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.9896 - class_loss: 0.5039 - speddup_loss: 21053.4955 - class_acc: 0.7770 - speddup_acc: 9.0921e-05 - val_loss: 3.1389 - val_class_loss: 0.6734 - val_speddup_loss: 41121.0664 - val_class_acc: 0.7256 - val_speddup_acc: 0.0000e+00
# Epoch 185/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.1007 - class_loss: 0.4777 - speddup_loss: 4077.2208 - class_acc: 0.7867 - speddup_acc: 4.6102e-05 - val_loss: 3.1009 - val_class_loss: 0.6556 - val_speddup_loss: 40451.9336 - val_class_acc: 0.7311 - val_speddup_acc: 0.0000e+00
# Epoch 186/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.4272 - class_loss: 0.4761 - speddup_loss: 10859.7269 - class_acc: 0.7894 - speddup_acc: 1.5300e-05 - val_loss: 3.0912 - val_class_loss: 0.6532 - val_speddup_loss: 40683.6133 - val_class_acc: 0.7389 - val_speddup_acc: 0.0000e+00
# Epoch 187/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 0.9720 - class_loss: 0.4777 - speddup_loss: 1705.4862 - class_acc: 0.7951 - speddup_acc: 3.9075e-04 - val_loss: 3.0789 - val_class_loss: 0.6451 - val_speddup_loss: 40643.8281 - val_class_acc: 0.7411 - val_speddup_acc: 0.0000e+00
# Epoch 188/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 2.0536 - class_loss: 0.4946 - speddup_loss: 22723.8805 - class_acc: 0.7832 - speddup_acc: 9.7365e-05 - val_loss: 3.1338 - val_class_loss: 0.6944 - val_speddup_loss: 40596.3320 - val_class_acc: 0.7261 - val_speddup_acc: 0.0000e+00
# Epoch 189/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.5170 - class_loss: 0.4843 - speddup_loss: 12505.4827 - class_acc: 0.7849 - speddup_acc: 5.1281e-05 - val_loss: 3.0828 - val_class_loss: 0.6503 - val_speddup_loss: 40482.7461 - val_class_acc: 0.7294 - val_speddup_acc: 0.0000e+00
# Epoch 190/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.1846 - class_loss: 0.4843 - speddup_loss: 5819.8004 - class_acc: 0.7831 - speddup_acc: 8.1816e-05 - val_loss: 3.0763 - val_class_loss: 0.6382 - val_speddup_loss: 40771.4648 - val_class_acc: 0.7283 - val_speddup_acc: 0.0000e+00
# Epoch 191/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.4243 - class_loss: 0.4663 - speddup_loss: 11121.8289 - class_acc: 0.7858 - speddup_acc: 1.0841e-04 - val_loss: 3.0647 - val_class_loss: 0.6181 - val_speddup_loss: 40863.7070 - val_class_acc: 0.7428 - val_speddup_acc: 0.0000e+00
# Epoch 192/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 0.9825 - class_loss: 0.4772 - speddup_loss: 1987.5978 - class_acc: 0.7835 - speddup_acc: 1.3513e-04 - val_loss: 3.0981 - val_class_loss: 0.6660 - val_speddup_loss: 40568.7812 - val_class_acc: 0.7289 - val_speddup_acc: 0.0000e+00
# Epoch 193/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.3322 - class_loss: 0.4842 - speddup_loss: 8776.7388 - class_acc: 0.7822 - speddup_acc: 4.4542e-04 - val_loss: 3.1588 - val_class_loss: 0.6917 - val_speddup_loss: 41222.5625 - val_class_acc: 0.7278 - val_speddup_acc: 0.0000e+00
# Epoch 194/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.6684 - class_loss: 0.4747 - speddup_loss: 15662.6538 - class_acc: 0.7919 - speddup_acc: 1.8256e-04 - val_loss: 3.1001 - val_class_loss: 0.6554 - val_speddup_loss: 40560.8711 - val_class_acc: 0.7239 - val_speddup_acc: 0.0000e+00
# Epoch 195/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.2333 - class_loss: 0.4804 - speddup_loss: 6421.8403 - class_acc: 0.7898 - speddup_acc: 1.2281e-04 - val_loss: 3.0931 - val_class_loss: 0.6401 - val_speddup_loss: 40839.9453 - val_class_acc: 0.7361 - val_speddup_acc: 0.0000e+00
# Epoch 196/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.2112 - class_loss: 0.4909 - speddup_loss: 6092.8706 - class_acc: 0.7816 - speddup_acc: 5.5106e-04 - val_loss: 3.0622 - val_class_loss: 0.6400 - val_speddup_loss: 40441.4102 - val_class_acc: 0.7294 - val_speddup_acc: 0.0000e+00
# Epoch 197/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.3910 - class_loss: 0.4735 - speddup_loss: 10192.3128 - class_acc: 0.7915 - speddup_acc: 2.1737e-04 - val_loss: 3.0965 - val_class_loss: 0.6716 - val_speddup_loss: 40460.6445 - val_class_acc: 0.7206 - val_speddup_acc: 0.0000e+00
# Epoch 198/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.2095 - class_loss: 0.4585 - speddup_loss: 6769.8586 - class_acc: 0.7957 - speddup_acc: 3.6255e-04 - val_loss: 3.1572 - val_class_loss: 0.7011 - val_speddup_loss: 40518.3477 - val_class_acc: 0.7311 - val_speddup_acc: 0.0000e+00
# Epoch 199/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.1618 - class_loss: 0.4818 - speddup_loss: 5132.4723 - class_acc: 0.7852 - speddup_acc: 9.6138e-05 - val_loss: 3.1570 - val_class_loss: 0.7052 - val_speddup_loss: 40469.4453 - val_class_acc: 0.7194 - val_speddup_acc: 0.0000e+00
# Epoch 200/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.2600 - class_loss: 0.5580 - speddup_loss: 5084.2051 - class_acc: 0.7693 - speddup_acc: 1.2311e-04 - val_loss: 3.1028 - val_class_loss: 0.6518 - val_speddup_loss: 40422.8789 - val_class_acc: 0.7272 - val_speddup_acc: 0.0000e+00
# Training took 1060.7744948863983 seconds..
# Information saved to ./model_data/GNN_generated2.control_150x150_1619122164.3685732/training_history.yaml
# Information saved to ./model_data/GNN_generated2.control_150x150_1619122164.3685732/training_time.yaml
# Model saved to ./model_data/GNN_generated2.control_150x150_1619122164.3685732/model.yaml
# Weights saved to file ./model_data/GNN_generated2.control_150x150_1619122164.3685732/weights.h5
# Accuracy per epoch figure saved to ./model_data/GNN_generated2.control_150x150_1619122164.3685732/model_accuracy.pdf
# Evaluating model.
# 125/125 [==============================] - 1s 3ms/step - loss: 1.1489 - class_loss: 0.6896 - speddup_loss: 503.4553 - class_acc: 0.7175 - speddup_acc: 0.0000e+00
# Done. Test loss: 1.1489. Test acc: 0.69
# Information saved to ./model_data/GNN_generated2.control_150x150_1619122164.3685732/evaluation.yaml
# Confusion matrix:
# [[424  38  15  14]
#  [ 41 276  42  22]
#  [  0  63 325  52]
#  [ 16 135 127 410]]
# Confusion matrix figure saved to ./model_data/GNN_generated2.control_150x150_1619122164.3685732/confusion_matrix.pdf
# 3602

# %%
results = []
results += eval_results_zeroing_llvm(model, [], features_test, graphs_test, y_test, description='Zeroing Nothing')
results += eval_results_zeroing_llvm(model, get_terminators(), features_test, graphs_test, y_test, description='Zeroing terminators')
results += eval_results_zeroing_llvm(model, get_unary(), features_test, graphs_test, y_test, description='Zeroing unaries')
results += eval_results_zeroing_llvm(model, get_binary(), features_test, graphs_test, y_test, description='Zeroing binaries')
results += eval_results_zeroing_llvm(model, get_memory(), features_test, graphs_test, y_test, description='Zeroing memories')
results += eval_results_zeroing_llvm(model, get_casts(), features_test, graphs_test, y_test, description='Zeroing casts')
results += eval_results_zeroing_llvm(model, get_others(), features_test, graphs_test, y_test, description='Zeroing others')
for i in range (0, 50):
    results += eval_results_zeroing_llvm_random(model, 2, features_test, graphs_test, y_test)
for i in range (0, 50):
    results += eval_results_zeroing_llvm_random(model, 3, features_test, graphs_test, y_test)
for i in range (0, 50):
    results += eval_results_zeroing_llvm_random(model, 4, features_test, graphs_test, y_test)
# Out:
# Zeroing Nothing. loss: 1.1489206552505493, class_acc: 0.7174999713897705
# Zeroing terminators. loss: 5.411090850830078, class_acc: 0.35499998927116394
# Zeroing unaries. loss: 1.1861777305603027, class_acc: 0.7095000147819519
# Zeroing binaries. loss: 2.728630781173706, class_acc: 0.4749999940395355
# Zeroing memories. loss: 7.822737216949463, class_acc: 0.4415000081062317
# Zeroing casts. loss: 1.6619634628295898, class_acc: 0.612500011920929
# Zeroing others. loss: 2.551645040512085, class_acc: 0.47200000286102295
# Zeroing columns 21, 65. loss: 1.1886026859283447, class_acc: 0.7110000252723694
# Zeroing columns 7, 37. loss: 1.2408006191253662, class_acc: 0.7039999961853027
# Zeroing columns 12, 19. loss: 1.6987969875335693, class_acc: 0.6215000152587891
# Zeroing columns 12, 23. loss: 1.681929111480713, class_acc: 0.6205000281333923
# Zeroing columns 19, 26. loss: 1.282292127609253, class_acc: 0.7049999833106995
# Zeroing columns 17, 41. loss: 1.4176084995269775, class_acc: 0.6804999709129333
# Zeroing columns 29, 40. loss: 1.2106664180755615, class_acc: 0.6995000243186951
# Zeroing columns 2, 17. loss: 1.4224046468734741, class_acc: 0.6830000281333923
# Zeroing columns 25, 51. loss: 1.2101813554763794, class_acc: 0.699999988079071
# Zeroing columns 37, 55. loss: 2.2719695568084717, class_acc: 0.5515000224113464
# Zeroing columns 24, 37. loss: 1.270494818687439, class_acc: 0.6945000290870667
# Zeroing columns 0, 27. loss: 2.5776424407958984, class_acc: 0.5299999713897705
# Zeroing columns 17, 47. loss: 1.4220540523529053, class_acc: 0.6809999942779541
# Zeroing columns 28, 34. loss: 1.1968556642532349, class_acc: 0.6980000138282776
# Zeroing columns 46, 47. loss: 1.1489691734313965, class_acc: 0.7195000052452087
# Zeroing columns 48, 51. loss: 1.2341722249984741, class_acc: 0.6919999718666077
# Zeroing columns 11, 57. loss: 1.1861777305603027, class_acc: 0.7095000147819519
# Zeroing columns 5, 24. loss: 1.202545166015625, class_acc: 0.7045000195503235
# Zeroing columns 1, 51. loss: 4.1387810707092285, class_acc: 0.4235000014305115
# Zeroing columns 44, 64. loss: 1.1669927835464478, class_acc: 0.7139999866485596
# Zeroing columns 31, 41. loss: 2.2116942405700684, class_acc: 0.6079999804496765
# Zeroing columns 3, 7. loss: 1.1537452936172485, class_acc: 0.7164999842643738
# Zeroing columns 17, 54. loss: 1.6707866191864014, class_acc: 0.590499997138977
# Zeroing columns 41, 65. loss: 1.1521142721176147, class_acc: 0.7149999737739563
# Zeroing columns 11, 24. loss: 1.2401952743530273, class_acc: 0.6949999928474426
# Zeroing columns 24, 33. loss: 1.84544837474823, class_acc: 0.6365000009536743
# Zeroing columns 5, 35. loss: 1.1489206552505493, class_acc: 0.7174999713897705
# Zeroing columns 33, 53. loss: 1.548545479774475, class_acc: 0.6380000114440918
# Zeroing columns 8, 41. loss: 1.1521142721176147, class_acc: 0.7149999737739563
# Zeroing columns 18, 55. loss: 2.0542125701904297, class_acc: 0.5644999742507935
# Zeroing columns 7, 17. loss: 1.4215091466903687, class_acc: 0.6815000176429749
# Zeroing columns 24, 39. loss: 1.2941832542419434, class_acc: 0.6934999823570251
# Zeroing columns 4, 5. loss: 1.1489206552505493, class_acc: 0.7174999713897705
# Zeroing columns 3, 52. loss: 1.545533299446106, class_acc: 0.6514999866485596
# Zeroing columns 1, 40. loss: 4.138619899749756, class_acc: 0.4235000014305115
# Zeroing columns 2, 31. loss: 2.2321689128875732, class_acc: 0.6075000166893005
# Zeroing columns 2, 11. loss: 1.1877814531326294, class_acc: 0.7095000147819519
# Zeroing columns 15, 22. loss: 1.3622111082077026, class_acc: 0.6890000104904175
# Zeroing columns 7, 25. loss: 1.2101813554763794, class_acc: 0.699999988079071
# Zeroing columns 12, 30. loss: 1.878987431526184, class_acc: 0.5809999704360962
# Zeroing columns 9, 42. loss: 1.1735849380493164, class_acc: 0.7160000205039978
# Zeroing columns 12, 35. loss: 1.681929111480713, class_acc: 0.6205000281333923
# Zeroing columns 15, 64. loss: 1.2270073890686035, class_acc: 0.6980000138282776
# Zeroing columns 37, 63. loss: 1.2444243431091309, class_acc: 0.7024999856948853
# Zeroing columns 30, 31. loss: 2.3658251762390137, class_acc: 0.5770000219345093
# Zeroing columns 42, 47. loss: 1.1743806600570679, class_acc: 0.7170000076293945
# Zeroing columns 37, 58. loss: 1.2408006191253662, class_acc: 0.7039999961853027
# Zeroing columns 37, 47. loss: 1.2402708530426025, class_acc: 0.7045000195503235
# Zeroing columns 9, 53. loss: 1.205602765083313, class_acc: 0.7020000219345093
# Zeroing columns 51, 54. loss: 1.4043668508529663, class_acc: 0.6349999904632568
# Zeroing columns 17, 22, 25. loss: 1.6508994102478027, class_acc: 0.6449999809265137
# Zeroing columns 16, 46, 48. loss: 1.3288942575454712, class_acc: 0.671999990940094
# Zeroing columns 2, 28, 63. loss: 1.2034823894500732, class_acc: 0.6980000138282776
# Zeroing columns 29, 33, 40. loss: 1.594231367111206, class_acc: 0.6414999961853027
# Zeroing columns 0, 16, 21. loss: 2.803868055343628, class_acc: 0.5195000171661377
# Zeroing columns 10, 43, 48. loss: 1.3285260200500488, class_acc: 0.6700000166893005
# Zeroing columns 1, 5, 15. loss: 4.165353775024414, class_acc: 0.4255000054836273
# Zeroing columns 38, 55, 66. loss: 2.1245763301849365, class_acc: 0.5485000014305115
# Zeroing columns 17, 27, 38. loss: 1.5638327598571777, class_acc: 0.6510000228881836
# Zeroing columns 6, 23, 40. loss: 1.2676384449005127, class_acc: 0.6974999904632568
# Zeroing columns 2, 3, 47. loss: 1.158110499382019, class_acc: 0.718500018119812
# Zeroing columns 4, 47, 65. loss: 1.1494545936584473, class_acc: 0.718500018119812
# Zeroing columns 13, 21, 32. loss: 2.030559539794922, class_acc: 0.5454999804496765
# Zeroing columns 32, 53, 59. loss: 1.7712205648422241, class_acc: 0.5764999985694885
# Zeroing columns 10, 40, 57. loss: 1.1482170820236206, class_acc: 0.7174999713897705
# Zeroing columns 1, 42, 49. loss: 4.167726039886475, class_acc: 0.41999998688697815
# Zeroing columns 23, 28, 47. loss: 1.197183609008789, class_acc: 0.6990000009536743
# Zeroing columns 26, 41, 47. loss: 1.2963309288024902, class_acc: 0.7049999833106995
# Zeroing columns 37, 48, 57. loss: 1.312881350517273, class_acc: 0.6675000190734863
# Zeroing columns 17, 55, 66. loss: 2.2942581176757812, class_acc: 0.5325000286102295
# Zeroing columns 24, 28, 34. loss: 1.243692398071289, class_acc: 0.6894999742507935
# Zeroing columns 8, 31, 32. loss: 3.05499267578125, class_acc: 0.48399999737739563
# Zeroing columns 20, 33, 66. loss: 1.6901105642318726, class_acc: 0.6179999709129333
# Zeroing columns 44, 51, 63. loss: 1.16815185546875, class_acc: 0.7139999866485596
# Zeroing columns 10, 25, 34. loss: 1.2101813554763794, class_acc: 0.699999988079071
# Zeroing columns 2, 4, 37. loss: 1.24399995803833, class_acc: 0.7049999833106995
# Zeroing columns 44, 49, 55. loss: 2.0524561405181885, class_acc: 0.5644999742507935
# Zeroing columns 14, 16, 24. loss: 1.353129267692566, class_acc: 0.6765000224113464
# Zeroing columns 7, 18, 60. loss: 1.3767285346984863, class_acc: 0.7005000114440918
# Zeroing columns 1, 39, 62. loss: 4.351966381072998, class_acc: 0.42399999499320984
# Zeroing columns 6, 33, 48. loss: 1.7301031351089478, class_acc: 0.6255000233650208
# Zeroing columns 40, 41, 58. loss: 1.1514110565185547, class_acc: 0.7149999737739563
# Zeroing columns 21, 27, 32. loss: 1.8019574880599976, class_acc: 0.5795000195503235
# Zeroing columns 18, 55, 63. loss: 2.0491347312927246, class_acc: 0.5640000104904175
# Zeroing columns 0, 14, 35. loss: 2.7055482864379883, class_acc: 0.5295000076293945
# Zeroing columns 31, 48, 50. loss: 2.286726236343384, class_acc: 0.5849999785423279
# Zeroing columns 7, 37, 52. loss: 1.6391785144805908, class_acc: 0.6399999856948853
# Zeroing columns 2, 30, 35. loss: 1.243674397468567, class_acc: 0.6890000104904175
# Zeroing columns 8, 18, 51. loss: 1.1587095260620117, class_acc: 0.715499997138977
# Zeroing columns 32, 59, 66. loss: 1.7764694690704346, class_acc: 0.5789999961853027
# Zeroing columns 2, 8, 24. loss: 1.2067296504974365, class_acc: 0.703000009059906
# Zeroing columns 7, 47, 64. loss: 1.1520485877990723, class_acc: 0.7170000076293945
# Zeroing columns 17, 22, 46. loss: 1.5901720523834229, class_acc: 0.6620000004768372
# Zeroing columns 33, 34, 40. loss: 1.5011086463928223, class_acc: 0.6554999947547913
# Zeroing columns 28, 45, 46. loss: 1.2013591527938843, class_acc: 0.6959999799728394
# Zeroing columns 4, 10, 47. loss: 1.1494545936584473, class_acc: 0.718500018119812
# Zeroing columns 27, 37, 50. loss: 1.264891505241394, class_acc: 0.6959999799728394
# Zeroing columns 15, 22, 58. loss: 1.3622111082077026, class_acc: 0.6890000104904175
# Zeroing columns 6, 57, 63. loss: 1.2701808214187622, class_acc: 0.6970000267028809
# Zeroing columns 1, 43, 56. loss: 4.375802040100098, class_acc: 0.4104999899864197
# Zeroing columns 13, 37, 41, 47. loss: 1.5111790895462036, class_acc: 0.6694999933242798
# Zeroing columns 6, 28, 57, 61. loss: 1.5342252254486084, class_acc: 0.6535000205039978
# Zeroing columns 23, 40, 50, 53. loss: 1.2049119472503662, class_acc: 0.7020000219345093
# Zeroing columns 1, 5, 62, 64. loss: 4.1949591636657715, class_acc: 0.41749998927116394
# Zeroing columns 17, 41, 45, 59. loss: 1.4088549613952637, class_acc: 0.6825000047683716
# Zeroing columns 25, 41, 47, 62. loss: 1.2189717292785645, class_acc: 0.6980000138282776
# Zeroing columns 25, 27, 47, 59. loss: 1.2143126726150513, class_acc: 0.6955000162124634
# Zeroing columns 11, 22, 36, 39. loss: 1.4590134620666504, class_acc: 0.6754999756813049
# Zeroing columns 19, 26, 49, 57. loss: 1.282292127609253, class_acc: 0.7049999833106995
# Zeroing columns 6, 15, 40, 43. loss: 1.5002267360687256, class_acc: 0.6380000114440918
# Zeroing columns 10, 21, 41, 62. loss: 1.188570499420166, class_acc: 0.7070000171661377
# Zeroing columns 1, 35, 52, 60. loss: 5.024029731750488, class_acc: 0.41449999809265137
# Zeroing columns 5, 10, 27, 55. loss: 2.132054090499878, class_acc: 0.5515000224113464
# Zeroing columns 29, 46, 50, 51. loss: 1.2120281457901, class_acc: 0.6984999775886536
# Zeroing columns 17, 32, 57, 62. loss: 1.9966013431549072, class_acc: 0.5414999723434448
# Zeroing columns 9, 31, 34, 46. loss: 2.2095210552215576, class_acc: 0.6075000166893005
# Zeroing columns 5, 9, 27, 37. loss: 1.264891505241394, class_acc: 0.6959999799728394
# Zeroing columns 8, 14, 33, 64. loss: 1.5804544687271118, class_acc: 0.6389999985694885
# Zeroing columns 4, 13, 38, 47. loss: 1.603507399559021, class_acc: 0.671500027179718
# Zeroing columns 0, 3, 38, 59. loss: 2.7724599838256836, class_acc: 0.5174999833106995
# Zeroing columns 15, 33, 39, 44. loss: 1.7194688320159912, class_acc: 0.6205000281333923
# Zeroing columns 17, 38, 51, 65. loss: 1.6075907945632935, class_acc: 0.6614999771118164
# Zeroing columns 1, 23, 26, 57. loss: 4.396788120269775, class_acc: 0.41850000619888306
# Zeroing columns 7, 22, 28, 61. loss: 1.5356085300445557, class_acc: 0.6524999737739563
# Zeroing columns 18, 39, 44, 61. loss: 1.4078691005706787, class_acc: 0.671500027179718
# Zeroing columns 1, 19, 22, 28. loss: 4.174837112426758, class_acc: 0.42250001430511475
# Zeroing columns 7, 57, 58, 59. loss: 1.1489206552505493, class_acc: 0.7174999713897705
# Zeroing columns 2, 13, 50, 53. loss: 1.4567854404449463, class_acc: 0.6779999732971191
# Zeroing columns 22, 38, 58, 59. loss: 1.4716311693191528, class_acc: 0.6815000176429749
# Zeroing columns 0, 36, 39, 51. loss: 2.7180676460266113, class_acc: 0.5199999809265137
# Zeroing columns 27, 34, 40, 63. loss: 1.1715149879455566, class_acc: 0.7074999809265137
# Zeroing columns 0, 11, 31, 50. loss: 3.731995105743408, class_acc: 0.45399999618530273
# Zeroing columns 19, 20, 25, 35. loss: 1.372973918914795, class_acc: 0.6704999804496765
# Zeroing columns 15, 42, 46, 52. loss: 1.6868678331375122, class_acc: 0.6259999871253967
# Zeroing columns 11, 23, 28, 65. loss: 1.2329556941986084, class_acc: 0.6919999718666077
# Zeroing columns 7, 20, 46, 57. loss: 1.2784923315048218, class_acc: 0.6930000185966492
# Zeroing columns 2, 19, 21, 22. loss: 1.2915008068084717, class_acc: 0.6934999823570251
# Zeroing columns 19, 25, 59, 62. loss: 1.2145293951034546, class_acc: 0.6984999775886536
# Zeroing columns 0, 41, 55, 63. loss: 2.9330434799194336, class_acc: 0.47200000286102295
# Zeroing columns 1, 12, 33, 65. loss: 6.1911396980285645, class_acc: 0.3555000126361847
# Zeroing columns 13, 21, 37, 53. loss: 1.5559836626052856, class_acc: 0.6554999947547913
# Zeroing columns 20, 43, 49, 64. loss: 1.3459073305130005, class_acc: 0.6700000166893005
# Zeroing columns 30, 35, 43, 56. loss: 1.4187273979187012, class_acc: 0.6395000219345093
# Zeroing columns 16, 26, 43, 61. loss: 1.6747076511383057, class_acc: 0.6305000185966492
# Zeroing columns 11, 22, 62, 66. loss: 1.3180698156356812, class_acc: 0.6880000233650208
# Zeroing columns 9, 31, 45, 55. loss: 3.2009963989257812, class_acc: 0.47749999165534973
# Zeroing columns 14, 26, 44, 63. loss: 1.3866312503814697, class_acc: 0.6865000128746033
# Zeroing columns 0, 46, 57, 62. loss: 2.4973537921905518, class_acc: 0.546999990940094
# Zeroing columns 2, 23, 57, 59. loss: 1.1528480052947998, class_acc: 0.718999981880188
# Zeroing columns 11, 37, 61, 64. loss: 1.447401523590088, class_acc: 0.6710000038146973

# %% [markdown]
# # Training with CFG + Call graphs

# %%
# Configuration information about training
config = {
    'input_data': './data/generated2.cfgcs_20000samples_150x150.npz',   # Name of the file with samples
    'data_dir_tag': 'generated2.control.call',    # Tag for directory name
    'n_nodes': 150,       # Number of nodes in graphs
    'n_features': 67,     # Original feature dimensionality
    'n_classes': 4,       # Number of output classes
    'epochs': 200,        # Number of training epochs
    'batch_size': 16,     # Number of samples per batch
    'learning_rate': 1e-2,# Training learning rate
    'test_size': 0.10,    # Percentage of samples to be used in test set (in relation to total number of samples)
    'validation_size': 0.10,    # Percentage of samples to be used in validation set (in relation to number of training samples)
    'samples': 20000,     # Number of samples in dataset (OPTIONAL)
}

# Create directory and write configuration information
data_dir = f"./model_data/GNN_{config['data_dir_tag']}_{config['n_nodes']}x{config['n_nodes']}_{time.time()}"
dump_info(data_dir, 'info.yaml', config)

print('Loading inputs and split into train and test sets')
# Load inputs and create train and and test sets
graphs_train, graphs_test, features_train, features_test, y_train, y_test = get_inputs(config['input_data'], test_size=config['test_size'])
print("Inputs loaded!")

# Create GNN model
model = create_model(config['n_nodes'], config['n_features'], config['n_classes'], config['learning_rate'])
print('Model created!')
model.summary()

# -----------------------------------------------
# ----------------- Train model -----------------
# -----------------------------------------------
print('Start training')
start_time = time.time()
history = model.fit([features_train[:,0,:,:], graphs_train[:,0,:,:], features_train[:,1,:,:], graphs_train[:,1,:,:]], [y_train[:,0:4], y_train[:,4]],
          batch_size=config['batch_size'], validation_split=config['validation_size'], epochs=config['epochs'], verbose=1)
end_time = time.time()
print(f'Training took {end_time-start_time} seconds..')

# Dump training information to files
dump_info(data_dir, 'training_history.yaml', history.history)
dump_info(data_dir, 'training_time.yaml', {'time': end_time-start_time})
# Save model and weights to files
save_model(data_dir, model)

# Plot accuracy per epoch in train and validation sets
plt.plot(np.array(history.history['class_acc']))
plt.plot(np.array(history.history['val_class_acc']))
plt.title('model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
figure_file = os.path.join(data_dir, "model_accuracy.pdf")
plt.savefig(figure_file)
print(f"Accuracy per epoch figure saved to {figure_file}")


# --------------------------------------------------
# ----------------- Evaluate model -----------------
# --------------------------------------------------
print('Evaluating model.')
eval_results = model.evaluate([features_test[:,0,:,:], graphs_test[:,0,:,:], features_test[:,1,:,:], graphs_test[:,1,:,:]], [y_test[:,0:4],y_test[:,4]],
                              batch_size=config['batch_size'])
print('Done. Test loss: {:.4f}. Test acc: {:.2f}'.format(*eval_results))

# Dump evaluation information to files
dump_info(data_dir, 'evaluation.yaml', {'test_loss': eval_results[0], 'test_accuracy': eval_results[1]})

# Printing confusion matrix
print("Confusion matrix:")
pred_vals = model.predict([features_test[:,0,:,:], graphs_test[:,0,:,:], features_test[:,1,:,:], graphs_test[:,1,:,:]])
pred_vals = np.argmax(pred_vals[0], axis=-1)
test_vals = np.argmax(y_test[:,0:4], axis=-1)
cm=confusion_matrix(pred_vals,test_vals)
print(cm)

# Plot confusion matrix
labels = ['High Slowdown', 'Low Slowdown', 'Not Significant', 'High Speedup']
plt.figure(figsize = (10,7))
sn.set(font_scale=1.4)
ax = sn.heatmap(cm, cmap="Blues", annot=True, annot_kws={"size": 16}, xticklabels=labels, yticklabels=labels)
for label in ax.get_xticklabels():
    label.set_ha("right")
    label.set_rotation(45)

ax.set_xlabel('Truth Category')
ax.set_ylabel('Predicted Category')

# Save confusion matrix
figure_file = os.path.join(data_dir, "confusion_matrix.pdf")
plt.savefig(figure_file)
print(f"Confusion matrix figure saved to {figure_file}")

# Cleanup
gc.collect()
# Out:
# Information saved to ./model_data/GNN_generated2.control.call_150x150_1619123314.6275222/info.yaml
# Loading inputs and split into train and test sets
# Data loaded from ./data/generated2.cfgcs_20000samples_150x150.npz
# Speedup classes generated from data. Number of elements
#         Class A: 5005,
#         Class B: 4997,
#         Class C: 4998,
#         Class D: 5000,
#
# Datas:
#         Graphs shape:   (20000, 2, 150, 150)
#         Features shape: (20000, 2, 150, 67)
#         Speedups shape: (20000, 5)
#
# Graphs preprocessed!
# Dataset splitted!
# Inputs loaded!
# Model created!
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_5 (InputLayer)            [(None, 150, 67)]    0
# __________________________________________________________________________________________________
# input_6 (InputLayer)            [(None, 150, 150)]   0
# __________________________________________________________________________________________________
# input_7 (InputLayer)            [(None, 150, 67)]    0
# __________________________________________________________________________________________________
# input_8 (InputLayer)            [(None, 150, 150)]   0
# __________________________________________________________________________________________________
# graph_conv_2 (GraphConv)        (None, 150, 45)      3015        input_5[0][0]
#                                                                  input_6[0][0]
#                                                                  input_7[0][0]
#                                                                  input_8[0][0]
# __________________________________________________________________________________________________
# min_cut_pool_1 (MinCutPool)     [(None, 75, 45), (No 3450        graph_conv_2[0][0]
#                                                                  input_6[0][0]
#                                                                  graph_conv_2[1][0]
#                                                                  input_8[0][0]
# __________________________________________________________________________________________________
# graph_conv_3 (GraphConv)        (None, 75, 55)       2475        min_cut_pool_1[0][0]
#                                                                  min_cut_pool_1[0][1]
#                                                                  min_cut_pool_1[1][0]
#                                                                  min_cut_pool_1[1][1]
# __________________________________________________________________________________________________
# global_attn_sum_pool_1 (GlobalA (None, 55)           55          graph_conv_3[0][0]
#                                                                  graph_conv_3[1][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 200)          11200       global_attn_sum_pool_1[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 200)          11200       global_attn_sum_pool_1[1][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 400)          0           dense_4[0][0]
#                                                                  dense_5[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 800)          320800      concatenate_1[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 32)           25632       dense_6[0][0]
# __________________________________________________________________________________________________
# class (Dense)                   (None, 4)            132         dense_7[0][0]
# __________________________________________________________________________________________________
# speddup (Dense)                 (None, 1)            33          dense_7[0][0]
# ==================================================================================================
# Total params: 377,992
# Trainable params: 377,992
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Start training
# Epoch 1/200
# 1013/1013 [==============================] - 7s 6ms/step - loss: 3.1914 - class_loss: 1.2588 - speddup_loss: 27441.8038 - class_acc: 0.3890 - speddup_acc: 2.5282e-04 - val_loss: 2.5669 - val_class_loss: 1.0476 - val_speddup_loss: 22012.1191 - val_class_acc: 0.5306 - val_speddup_acc: 0.0000e+00
# Epoch 2/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 2.7181 - class_loss: 1.0255 - speddup_loss: 25587.3063 - class_acc: 0.5484 - speddup_acc: 0.0000e+00 - val_loss: 2.4967 - val_class_loss: 0.9842 - val_speddup_loss: 21862.5547 - val_class_acc: 0.5561 - val_speddup_acc: 0.0000e+00
# Epoch 3/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 2.1259 - class_loss: 0.9718 - speddup_loss: 14931.6461 - class_acc: 0.5753 - speddup_acc: 0.0000e+00 - val_loss: 2.4445 - val_class_loss: 0.9574 - val_speddup_loss: 21734.0547 - val_class_acc: 0.5817 - val_speddup_acc: 0.0000e+00
# Epoch 4/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 2.2329 - class_loss: 0.9107 - speddup_loss: 18379.4461 - class_acc: 0.5959 - speddup_acc: 0.0000e+00 - val_loss: 2.3321 - val_class_loss: 0.8495 - val_speddup_loss: 21528.5000 - val_class_acc: 0.6206 - val_speddup_acc: 0.0000e+00
# Epoch 5/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 2.6202 - class_loss: 0.8760 - speddup_loss: 26670.1136 - class_acc: 0.6202 - speddup_acc: 0.0000e+00 - val_loss: 2.3378 - val_class_loss: 0.8719 - val_speddup_loss: 21271.1992 - val_class_acc: 0.6200 - val_speddup_acc: 0.0000e+00
# Epoch 6/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 2.3458 - class_loss: 0.8534 - speddup_loss: 21557.2228 - class_acc: 0.6240 - speddup_acc: 0.0000e+00 - val_loss: 2.2874 - val_class_loss: 0.8495 - val_speddup_loss: 20488.7090 - val_class_acc: 0.6261 - val_speddup_acc: 0.0000e+00
# Epoch 7/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 2.4760 - class_loss: 0.8179 - speddup_loss: 24987.5589 - class_acc: 0.6412 - speddup_acc: 0.0000e+00 - val_loss: 2.1214 - val_class_loss: 0.8087 - val_speddup_loss: 18000.5352 - val_class_acc: 0.6350 - val_speddup_acc: 0.0000e+00
# Epoch 8/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 2.2572 - class_loss: 0.8220 - speddup_loss: 20470.3445 - class_acc: 0.6398 - speddup_acc: 0.0000e+00 - val_loss: 1.5930 - val_class_loss: 0.8673 - val_speddup_loss: 5739.4634 - val_class_acc: 0.6250 - val_speddup_acc: 0.0000e+00
# Epoch 9/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.8925 - class_loss: 0.8356 - speddup_loss: 12614.3358 - class_acc: 0.6309 - speddup_acc: 0.0000e+00 - val_loss: 1.9526 - val_class_loss: 0.7931 - val_speddup_loss: 14934.5234 - val_class_acc: 0.6550 - val_speddup_acc: 0.0000e+00
# Epoch 10/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 2.4269 - class_loss: 0.8069 - speddup_loss: 24018.2007 - class_acc: 0.6365 - speddup_acc: 0.0000e+00 - val_loss: 2.1230 - val_class_loss: 0.9526 - val_speddup_loss: 12548.0381 - val_class_acc: 0.6261 - val_speddup_acc: 0.0000e+00
# Epoch 11/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.9258 - class_loss: 0.7974 - speddup_loss: 13527.5226 - class_acc: 0.6487 - speddup_acc: 0.0000e+00 - val_loss: 1.5037 - val_class_loss: 0.7736 - val_speddup_loss: 6170.5146 - val_class_acc: 0.6628 - val_speddup_acc: 0.0000e+00
# Epoch 12/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 2.6361 - class_loss: 0.8206 - speddup_loss: 27867.8419 - class_acc: 0.6532 - speddup_acc: 8.8722e-05 - val_loss: 17.8507 - val_class_loss: 4.4097 - val_speddup_loss: 260028.2031 - val_class_acc: 0.6411 - val_speddup_acc: 0.0000e+00
# Epoch 13/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 3.1449 - class_loss: 1.0579 - speddup_loss: 31005.5528 - class_acc: 0.5961 - speddup_acc: 0.0000e+00 - val_loss: 1.5573 - val_class_loss: 0.9407 - val_speddup_loss: 2275.5791 - val_class_acc: 0.6156 - val_speddup_acc: 0.0000e+00
# Epoch 14/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 2.5842 - class_loss: 0.8098 - speddup_loss: 25808.6790 - class_acc: 0.6392 - speddup_acc: 0.0000e+00 - val_loss: 1.7158 - val_class_loss: 0.7441 - val_speddup_loss: 10593.8535 - val_class_acc: 0.6717 - val_speddup_acc: 0.0000e+00
# Epoch 15/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 2.9665 - class_loss: 0.7542 - speddup_loss: 35476.3212 - class_acc: 0.6678 - speddup_acc: 0.0000e+00 - val_loss: 1.2788 - val_class_loss: 0.7379 - val_speddup_loss: 2282.7544 - val_class_acc: 0.6683 - val_speddup_acc: 0.0000e+00
# Epoch 16/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 2.2579 - class_loss: 0.7656 - speddup_loss: 21215.3792 - class_acc: 0.6653 - speddup_acc: 0.0000e+00 - val_loss: 1.4021 - val_class_loss: 0.7518 - val_speddup_loss: 4412.3037 - val_class_acc: 0.6700 - val_speddup_acc: 0.0000e+00
# Epoch 17/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.9464 - class_loss: 0.7505 - speddup_loss: 15474.4119 - class_acc: 0.6686 - speddup_acc: 0.0000e+00 - val_loss: 2.1437 - val_class_loss: 0.7782 - val_speddup_loss: 18677.4707 - val_class_acc: 0.6567 - val_speddup_acc: 0.0000e+00
# Epoch 18/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 2.3914 - class_loss: 0.7598 - speddup_loss: 24049.6010 - class_acc: 0.6667 - speddup_acc: 0.0000e+00 - val_loss: 1.4881 - val_class_loss: 0.7367 - val_speddup_loss: 6718.0039 - val_class_acc: 0.6744 - val_speddup_acc: 0.0000e+00
# Epoch 19/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 2.4297 - class_loss: 0.7362 - speddup_loss: 25603.2921 - class_acc: 0.6753 - speddup_acc: 0.0000e+00 - val_loss: 1.3185 - val_class_loss: 0.7665 - val_speddup_loss: 2290.5894 - val_class_acc: 0.6544 - val_speddup_acc: 0.0000e+00
# Epoch 20/200
# 1013/1013 [==============================] - 6s 5ms/step - loss: 2.6016 - class_loss: 0.7599 - speddup_loss: 28255.6683 - class_acc: 0.6622 - speddup_acc: 0.0000e+00 - val_loss: 1.8196 - val_class_loss: 0.7244 - val_speddup_loss: 13579.1182 - val_class_acc: 0.6739 - val_speddup_acc: 0.0000e+00
# Epoch 21/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 2.2170 - class_loss: 0.8521 - speddup_loss: 18583.0307 - class_acc: 0.6329 - speddup_acc: 0.0000e+00 - val_loss: 2.8135 - val_class_loss: 1.1633 - val_speddup_loss: 22736.4199 - val_class_acc: 0.4767 - val_speddup_acc: 0.0000e+00
# Epoch 22/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 2.4011 - class_loss: 0.9595 - speddup_loss: 19669.5924 - class_acc: 0.5704 - speddup_acc: 0.0000e+00 - val_loss: 1.5973 - val_class_loss: 0.8485 - val_speddup_loss: 5956.0640 - val_class_acc: 0.6267 - val_speddup_acc: 0.0000e+00
# Epoch 23/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 2.0383 - class_loss: 0.8085 - speddup_loss: 16010.2119 - class_acc: 0.6356 - speddup_acc: 3.4304e-05 - val_loss: 1.7504 - val_class_loss: 0.8048 - val_speddup_loss: 9304.9209 - val_class_acc: 0.6300 - val_speddup_acc: 0.0000e+00
# Epoch 24/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 2.0588 - class_loss: 0.7988 - speddup_loss: 16085.9231 - class_acc: 0.6442 - speddup_acc: 0.0000e+00 - val_loss: 1.3551 - val_class_loss: 0.7195 - val_speddup_loss: 4112.5405 - val_class_acc: 0.6733 - val_speddup_acc: 0.0000e+00
# Epoch 25/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 2.6504 - class_loss: 0.7749 - speddup_loss: 28736.5394 - class_acc: 0.6650 - speddup_acc: 0.0000e+00 - val_loss: 1.5393 - val_class_loss: 0.7554 - val_speddup_loss: 6962.6562 - val_class_acc: 0.6583 - val_speddup_acc: 0.0000e+00
# Epoch 26/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.7221 - class_loss: 0.8066 - speddup_loss: 9389.7983 - class_acc: 0.6532 - speddup_acc: 0.0000e+00 - val_loss: 1.4058 - val_class_loss: 0.8305 - val_speddup_loss: 1993.5586 - val_class_acc: 0.6250 - val_speddup_acc: 0.0000e+00
# Epoch 27/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 17.2499 - class_loss: 0.8026 - speddup_loss: 319471.0246 - class_acc: 0.6530 - speddup_acc: 0.0000e+00 - val_loss: 2.6735 - val_class_loss: 0.9711 - val_speddup_loss: 19800.9551 - val_class_acc: 0.5733 - val_speddup_acc: 0.0000e+00
# Epoch 28/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 2.3887 - class_loss: 0.9566 - speddup_loss: 14408.1848 - class_acc: 0.5854 - speddup_acc: 0.0000e+00 - val_loss: 1.9370 - val_class_loss: 0.8540 - val_speddup_loss: 7531.6343 - val_class_acc: 0.6294 - val_speddup_acc: 0.0000e+00
# Epoch 29/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 2.2350 - class_loss: 0.8559 - speddup_loss: 13422.4217 - class_acc: 0.6296 - speddup_acc: 0.0000e+00 - val_loss: 1.8948 - val_class_loss: 0.8650 - val_speddup_loss: 6469.0376 - val_class_acc: 0.6250 - val_speddup_acc: 0.0000e+00
# Epoch 30/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 2.3400 - class_loss: 0.8344 - speddup_loss: 16087.4515 - class_acc: 0.6352 - speddup_acc: 0.0000e+00 - val_loss: 1.8475 - val_class_loss: 0.8520 - val_speddup_loss: 5919.7065 - val_class_acc: 0.6422 - val_speddup_acc: 0.0000e+00
# Epoch 31/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 2.1513 - class_loss: 0.8197 - speddup_loss: 12644.3470 - class_acc: 0.6395 - speddup_acc: 0.0000e+00 - val_loss: 1.7245 - val_class_loss: 0.7869 - val_speddup_loss: 4792.7578 - val_class_acc: 0.6506 - val_speddup_acc: 0.0000e+00
# Epoch 32/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.8452 - class_loss: 0.7794 - speddup_loss: 7409.3705 - class_acc: 0.6535 - speddup_acc: 5.1420e-05 - val_loss: 1.6459 - val_class_loss: 0.7818 - val_speddup_loss: 3553.6306 - val_class_acc: 0.6561 - val_speddup_acc: 0.0000e+00
# Epoch 33/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 2.2710 - class_loss: 0.7729 - speddup_loss: 16203.7638 - class_acc: 0.6651 - speddup_acc: 0.0000e+00 - val_loss: 1.6800 - val_class_loss: 0.7943 - val_speddup_loss: 4086.8142 - val_class_acc: 0.6600 - val_speddup_acc: 0.0000e+00
# Epoch 34/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 2.3951 - class_loss: 0.7888 - speddup_loss: 18487.8796 - class_acc: 0.6622 - speddup_acc: 0.0000e+00 - val_loss: 1.7026 - val_class_loss: 0.8262 - val_speddup_loss: 3655.4114 - val_class_acc: 0.6400 - val_speddup_acc: 0.0000e+00
# Epoch 35/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.9949 - class_loss: 0.7882 - speddup_loss: 10316.6794 - class_acc: 0.6640 - speddup_acc: 0.0000e+00 - val_loss: 2.0063 - val_class_loss: 0.7913 - val_speddup_loss: 10511.5059 - val_class_acc: 0.6517 - val_speddup_acc: 0.0000e+00
# Epoch 36/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 2.5190 - class_loss: 0.7387 - speddup_loss: 21821.2874 - class_acc: 0.6703 - speddup_acc: 0.0000e+00 - val_loss: 1.5602 - val_class_loss: 0.8086 - val_speddup_loss: 1283.0962 - val_class_acc: 0.6367 - val_speddup_acc: 0.0000e+00
# Epoch 37/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 2.0397 - class_loss: 0.7422 - speddup_loss: 12199.4155 - class_acc: 0.6759 - speddup_acc: 0.0000e+00 - val_loss: 1.6650 - val_class_loss: 0.7604 - val_speddup_loss: 4511.0093 - val_class_acc: 0.6611 - val_speddup_acc: 0.0000e+00
# Epoch 38/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.8592 - class_loss: 0.7271 - speddup_loss: 9080.3860 - class_acc: 0.6738 - speddup_acc: 0.0000e+00 - val_loss: 1.6146 - val_class_loss: 0.8317 - val_speddup_loss: 2183.8752 - val_class_acc: 0.6383 - val_speddup_acc: 0.0000e+00
# Epoch 39/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 2.5824 - class_loss: 0.7326 - speddup_loss: 23555.3728 - class_acc: 0.6736 - speddup_acc: 0.0000e+00 - val_loss: 1.7285 - val_class_loss: 0.7554 - val_speddup_loss: 6020.4746 - val_class_acc: 0.6672 - val_speddup_acc: 0.0000e+00
# Epoch 40/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 2.6331 - class_loss: 0.7200 - speddup_loss: 24821.2402 - class_acc: 0.6816 - speddup_acc: 0.0000e+00 - val_loss: 1.6730 - val_class_loss: 0.7250 - val_speddup_loss: 5652.1045 - val_class_acc: 0.6811 - val_speddup_acc: 0.0000e+00
# Epoch 41/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 2.3642 - class_loss: 0.6977 - speddup_loss: 20018.9836 - class_acc: 0.6874 - speddup_acc: 0.0000e+00 - val_loss: 1.5202 - val_class_loss: 0.7342 - val_speddup_loss: 2416.2085 - val_class_acc: 0.6678 - val_speddup_acc: 0.0000e+00
# Epoch 42/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 2.2126 - class_loss: 0.7573 - speddup_loss: 15878.6224 - class_acc: 0.6771 - speddup_acc: 0.0000e+00 - val_loss: 1.8019 - val_class_loss: 0.7355 - val_speddup_loss: 8238.1885 - val_class_acc: 0.6778 - val_speddup_acc: 0.0000e+00
# Epoch 43/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 2.8524 - class_loss: 0.8516 - speddup_loss: 26742.7845 - class_acc: 0.6615 - speddup_acc: 0.0000e+00 - val_loss: 1.6654 - val_class_loss: 0.7832 - val_speddup_loss: 3515.4663 - val_class_acc: 0.6583 - val_speddup_acc: 0.0000e+00
# Epoch 44/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 2.5794 - class_loss: 0.7549 - speddup_loss: 23033.5452 - class_acc: 0.6646 - speddup_acc: 0.0000e+00 - val_loss: 1.4568 - val_class_loss: 0.7605 - val_speddup_loss: 846.9182 - val_class_acc: 0.6606 - val_speddup_acc: 0.0000e+00
# Epoch 45/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 2.0179 - class_loss: 0.7277 - speddup_loss: 12861.0814 - class_acc: 0.6807 - speddup_acc: 0.0000e+00 - val_loss: 1.7518 - val_class_loss: 0.7461 - val_speddup_loss: 7699.6133 - val_class_acc: 0.6700 - val_speddup_acc: 0.0000e+00
# Epoch 46/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 3.2261 - class_loss: 0.7116 - speddup_loss: 37917.9925 - class_acc: 0.6830 - speddup_acc: 0.0000e+00 - val_loss: 1.4747 - val_class_loss: 0.7421 - val_speddup_loss: 2312.0559 - val_class_acc: 0.6733 - val_speddup_acc: 0.0000e+00
# Epoch 47/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 2.3176 - class_loss: 0.6967 - speddup_loss: 20096.2866 - class_acc: 0.6923 - speddup_acc: 0.0000e+00 - val_loss: 5.5735 - val_class_loss: 0.7257 - val_speddup_loss: 84665.7422 - val_class_acc: 0.6839 - val_speddup_acc: 0.0000e+00
# Epoch 48/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 3.1419 - class_loss: 0.7595 - speddup_loss: 35364.7267 - class_acc: 0.6632 - speddup_acc: 0.0000e+00 - val_loss: 1.5417 - val_class_loss: 0.7199 - val_speddup_loss: 4188.1011 - val_class_acc: 0.6856 - val_speddup_acc: 0.0000e+00
# Epoch 49/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 2.6498 - class_loss: 0.6773 - speddup_loss: 27192.4719 - class_acc: 0.6972 - speddup_acc: 0.0000e+00 - val_loss: 1.4278 - val_class_loss: 0.7101 - val_speddup_loss: 2104.4277 - val_class_acc: 0.7000 - val_speddup_acc: 0.0000e+00
# Epoch 50/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 2.5493 - class_loss: 0.6720 - speddup_loss: 25273.9792 - class_acc: 0.7032 - speddup_acc: 0.0000e+00 - val_loss: 1.4391 - val_class_loss: 0.7211 - val_speddup_loss: 2055.7246 - val_class_acc: 0.6733 - val_speddup_acc: 0.0000e+00
# Epoch 51/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 2.6387 - class_loss: 0.6580 - speddup_loss: 27331.9494 - class_acc: 0.7071 - speddup_acc: 0.0000e+00 - val_loss: 1.5493 - val_class_loss: 0.7125 - val_speddup_loss: 4445.1992 - val_class_acc: 0.6861 - val_speddup_acc: 0.0000e+00
# Epoch 52/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 2.1053 - class_loss: 0.6630 - speddup_loss: 16518.7199 - class_acc: 0.7089 - speddup_acc: 0.0000e+00 - val_loss: 1.3646 - val_class_loss: 0.6930 - val_speddup_loss: 1108.5592 - val_class_acc: 0.6844 - val_speddup_acc: 0.0000e+00
# Epoch 53/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 2.9994 - class_loss: 0.6491 - speddup_loss: 34693.4328 - class_acc: 0.7073 - speddup_acc: 0.0000e+00 - val_loss: 1.4966 - val_class_loss: 0.6893 - val_speddup_loss: 3854.0015 - val_class_acc: 0.6928 - val_speddup_acc: 0.0000e+00
# Epoch 54/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.9992 - class_loss: 0.6512 - speddup_loss: 14668.8177 - class_acc: 0.7150 - speddup_acc: 0.0000e+00 - val_loss: 1.5388 - val_class_loss: 0.7003 - val_speddup_loss: 4514.8213 - val_class_acc: 0.6878 - val_speddup_acc: 0.0000e+00
# Epoch 55/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 2.5427 - class_loss: 0.6453 - speddup_loss: 25672.9849 - class_acc: 0.7118 - speddup_acc: 0.0000e+00 - val_loss: 1.4729 - val_class_loss: 0.7200 - val_speddup_loss: 2781.5945 - val_class_acc: 0.6850 - val_speddup_acc: 0.0000e+00
# Epoch 56/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 2.7074 - class_loss: 0.6475 - speddup_loss: 28904.1873 - class_acc: 0.7144 - speddup_acc: 0.0000e+00 - val_loss: 1.4205 - val_class_loss: 0.6631 - val_speddup_loss: 2891.1772 - val_class_acc: 0.7017 - val_speddup_acc: 0.0000e+00
# Epoch 57/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 2.1532 - class_loss: 0.6033 - speddup_loss: 18764.8022 - class_acc: 0.7352 - speddup_acc: 0.0000e+00 - val_loss: 1.3793 - val_class_loss: 0.6967 - val_speddup_loss: 1484.8298 - val_class_acc: 0.7000 - val_speddup_acc: 0.0000e+00
# Epoch 58/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.6079 - class_loss: 0.6301 - speddup_loss: 7335.7712 - class_acc: 0.7211 - speddup_acc: 0.0000e+00 - val_loss: 1.4997 - val_class_loss: 0.7221 - val_speddup_loss: 3172.7297 - val_class_acc: 0.6756 - val_speddup_acc: 0.0000e+00
# Epoch 59/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.9846 - class_loss: 0.6320 - speddup_loss: 14739.7354 - class_acc: 0.7212 - speddup_acc: 4.1849e-05 - val_loss: 1.6407 - val_class_loss: 0.7111 - val_speddup_loss: 6362.0928 - val_class_acc: 0.6883 - val_speddup_acc: 0.0000e+00
# Epoch 60/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 2.4448 - class_loss: 0.6176 - speddup_loss: 24331.9398 - class_acc: 0.7251 - speddup_acc: 8.1742e-06 - val_loss: 1.6599 - val_class_loss: 0.6624 - val_speddup_loss: 7762.7573 - val_class_acc: 0.7172 - val_speddup_acc: 0.0000e+00
# Epoch 61/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.9898 - class_loss: 0.6114 - speddup_loss: 15370.7236 - class_acc: 0.7300 - speddup_acc: 7.0448e-05 - val_loss: 1.3874 - val_class_loss: 0.6664 - val_speddup_loss: 2248.7466 - val_class_acc: 0.7033 - val_speddup_acc: 0.0000e+00
# Epoch 62/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 2.0880 - class_loss: 0.6021 - speddup_loss: 17497.8985 - class_acc: 0.7293 - speddup_acc: 2.6452e-05 - val_loss: 1.4652 - val_class_loss: 0.7001 - val_speddup_loss: 2974.5234 - val_class_acc: 0.6922 - val_speddup_acc: 0.0000e+00
# Epoch 63/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 2.0383 - class_loss: 0.6101 - speddup_loss: 16271.7183 - class_acc: 0.7328 - speddup_acc: 0.0000e+00 - val_loss: 1.3992 - val_class_loss: 0.6873 - val_speddup_loss: 1972.8549 - val_class_acc: 0.7156 - val_speddup_acc: 0.0000e+00
# Epoch 64/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 2.1326 - class_loss: 0.6092 - speddup_loss: 18203.3373 - class_acc: 0.7258 - speddup_acc: 0.0000e+00 - val_loss: 1.6325 - val_class_loss: 0.7209 - val_speddup_loss: 6028.4502 - val_class_acc: 0.6817 - val_speddup_acc: 0.0000e+00
# Epoch 65/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 2.1859 - class_loss: 0.6289 - speddup_loss: 18920.3150 - class_acc: 0.7132 - speddup_acc: 2.2950e-04 - val_loss: 1.4609 - val_class_loss: 0.7199 - val_speddup_loss: 2646.2612 - val_class_acc: 0.6889 - val_speddup_acc: 0.0000e+00
# Epoch 66/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 2.0184 - class_loss: 0.6101 - speddup_loss: 15983.7491 - class_acc: 0.7301 - speddup_acc: 0.0000e+00 - val_loss: 4.4739 - val_class_loss: 3.2653 - val_speddup_loss: 11977.2422 - val_class_acc: 0.6856 - val_speddup_acc: 0.0000e+00
# Epoch 67/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 3.6710 - class_loss: 1.5801 - speddup_loss: 27496.1318 - class_acc: 0.6816 - speddup_acc: 0.0000e+00 - val_loss: 1.8743 - val_class_loss: 0.7168 - val_speddup_loss: 9484.1826 - val_class_acc: 0.6917 - val_speddup_acc: 0.0000e+00
# Epoch 68/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.8212 - class_loss: 0.6122 - speddup_loss: 10925.7406 - class_acc: 0.7274 - speddup_acc: 0.0000e+00 - val_loss: 1.3490 - val_class_loss: 0.6761 - val_speddup_loss: 847.7990 - val_class_acc: 0.6994 - val_speddup_acc: 0.0000e+00
# Epoch 69/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.6568 - class_loss: 0.5850 - speddup_loss: 8949.7134 - class_acc: 0.7353 - speddup_acc: 0.0000e+00 - val_loss: 1.3534 - val_class_loss: 0.6721 - val_speddup_loss: 1310.2600 - val_class_acc: 0.7061 - val_speddup_acc: 0.0000e+00
# Epoch 70/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 2.2727 - class_loss: 0.5893 - speddup_loss: 21380.4898 - class_acc: 0.7376 - speddup_acc: 0.0000e+00 - val_loss: 1.4176 - val_class_loss: 0.6317 - val_speddup_loss: 3517.4563 - val_class_acc: 0.7206 - val_speddup_acc: 0.0000e+00
# Epoch 71/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.8225 - class_loss: 0.5718 - speddup_loss: 12811.5309 - class_acc: 0.7419 - speddup_acc: 0.0000e+00 - val_loss: 1.5825 - val_class_loss: 0.6981 - val_speddup_loss: 5502.7793 - val_class_acc: 0.6906 - val_speddup_acc: 0.0000e+00
# Epoch 72/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.6468 - class_loss: 0.5810 - speddup_loss: 9126.8284 - class_acc: 0.7451 - speddup_acc: 0.0000e+00 - val_loss: 1.3165 - val_class_loss: 0.6667 - val_speddup_loss: 826.1075 - val_class_acc: 0.7150 - val_speddup_acc: 0.0000e+00
# Epoch 73/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.9076 - class_loss: 0.5650 - speddup_loss: 14682.6923 - class_acc: 0.7440 - speddup_acc: 0.0000e+00 - val_loss: 1.4922 - val_class_loss: 0.6478 - val_speddup_loss: 4741.9165 - val_class_acc: 0.7178 - val_speddup_acc: 0.0000e+00
# Epoch 74/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.8902 - class_loss: 0.5681 - speddup_loss: 14296.9428 - class_acc: 0.7435 - speddup_acc: 0.0000e+00 - val_loss: 1.3307 - val_class_loss: 0.6394 - val_speddup_loss: 1704.4386 - val_class_acc: 0.7300 - val_speddup_acc: 0.0000e+00
# Epoch 75/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.4798 - class_loss: 0.5636 - speddup_loss: 6164.9641 - class_acc: 0.7501 - speddup_acc: 2.6968e-04 - val_loss: 1.4016 - val_class_loss: 0.6335 - val_speddup_loss: 3221.4177 - val_class_acc: 0.7200 - val_speddup_acc: 0.0000e+00
# Epoch 76/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.9601 - class_loss: 0.5669 - speddup_loss: 15672.2762 - class_acc: 0.7456 - speddup_acc: 0.0000e+00 - val_loss: 1.3296 - val_class_loss: 0.6211 - val_speddup_loss: 2015.0768 - val_class_acc: 0.7211 - val_speddup_acc: 0.0000e+00
# Epoch 77/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.7896 - class_loss: 0.5487 - speddup_loss: 12651.6585 - class_acc: 0.7489 - speddup_acc: 0.0000e+00 - val_loss: 1.3305 - val_class_loss: 0.6355 - val_speddup_loss: 1695.6730 - val_class_acc: 0.7167 - val_speddup_acc: 0.0000e+00
# Epoch 78/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.5513 - class_loss: 0.5515 - speddup_loss: 7811.1428 - class_acc: 0.7538 - speddup_acc: 0.0000e+00 - val_loss: 1.4341 - val_class_loss: 0.6395 - val_speddup_loss: 3681.6414 - val_class_acc: 0.7106 - val_speddup_acc: 0.0000e+00
# Epoch 79/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.6941 - class_loss: 0.5603 - speddup_loss: 10498.2924 - class_acc: 0.7512 - speddup_acc: 0.0000e+00 - val_loss: 1.4235 - val_class_loss: 0.6504 - val_speddup_loss: 3269.4570 - val_class_acc: 0.7172 - val_speddup_acc: 0.0000e+00
# Epoch 80/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 2.3473 - class_loss: 0.5531 - speddup_loss: 23688.7979 - class_acc: 0.7571 - speddup_acc: 0.0000e+00 - val_loss: 1.3527 - val_class_loss: 0.6845 - val_speddup_loss: 1029.2118 - val_class_acc: 0.7056 - val_speddup_acc: 0.0000e+00
# Epoch 81/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 2.0692 - class_loss: 0.5426 - speddup_loss: 18363.7499 - class_acc: 0.7594 - speddup_acc: 0.0000e+00 - val_loss: 1.4842 - val_class_loss: 0.6481 - val_speddup_loss: 4615.4741 - val_class_acc: 0.7089 - val_speddup_acc: 0.0000e+00
# Epoch 82/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 2.1435 - class_loss: 0.5640 - speddup_loss: 19426.9048 - class_acc: 0.7440 - speddup_acc: 0.0000e+00 - val_loss: 1.4729 - val_class_loss: 0.6508 - val_speddup_loss: 4294.4814 - val_class_acc: 0.7261 - val_speddup_acc: 0.0000e+00
# Epoch 83/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 2.8459 - class_loss: 0.5415 - speddup_loss: 33956.7424 - class_acc: 0.7568 - speddup_acc: 0.0000e+00 - val_loss: 1.3589 - val_class_loss: 0.6190 - val_speddup_loss: 2699.2844 - val_class_acc: 0.7306 - val_speddup_acc: 0.0000e+00
# Epoch 84/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.3915 - class_loss: 0.5301 - speddup_loss: 5082.7456 - class_acc: 0.7621 - speddup_acc: 0.0000e+00 - val_loss: 1.8249 - val_class_loss: 0.6848 - val_speddup_loss: 10671.6201 - val_class_acc: 0.7128 - val_speddup_acc: 0.0000e+00
# Epoch 85/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 2.3700 - class_loss: 0.5417 - speddup_loss: 24395.2976 - class_acc: 0.7659 - speddup_acc: 0.0000e+00 - val_loss: 1.4645 - val_class_loss: 0.6444 - val_speddup_loss: 4202.6821 - val_class_acc: 0.7250 - val_speddup_acc: 0.0000e+00
# Epoch 86/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.7729 - class_loss: 0.5349 - speddup_loss: 12581.3995 - class_acc: 0.7602 - speddup_acc: 0.0000e+00 - val_loss: 1.4458 - val_class_loss: 0.6423 - val_speddup_loss: 3898.9692 - val_class_acc: 0.7272 - val_speddup_acc: 0.0000e+00
# Epoch 87/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 2.4363 - class_loss: 0.5274 - speddup_loss: 25981.2243 - class_acc: 0.7648 - speddup_acc: 0.0000e+00 - val_loss: 1.3225 - val_class_loss: 0.6547 - val_speddup_loss: 1114.8953 - val_class_acc: 0.7244 - val_speddup_acc: 0.0000e+00
# Epoch 88/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 2.3704 - class_loss: 0.5491 - speddup_loss: 24167.4614 - class_acc: 0.7532 - speddup_acc: 1.0388e-04 - val_loss: 1.4031 - val_class_loss: 0.6941 - val_speddup_loss: 1944.9937 - val_class_acc: 0.7011 - val_speddup_acc: 0.0000e+00
# Epoch 89/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 2.0872 - class_loss: 0.5269 - speddup_loss: 19002.1123 - class_acc: 0.7718 - speddup_acc: 0.0000e+00 - val_loss: 1.3240 - val_class_loss: 0.6547 - val_speddup_loss: 1218.2892 - val_class_acc: 0.7206 - val_speddup_acc: 0.0000e+00
# Epoch 90/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 2.2008 - class_loss: 0.5450 - speddup_loss: 20954.4237 - class_acc: 0.7577 - speddup_acc: 8.7702e-05 - val_loss: 1.3694 - val_class_loss: 0.6438 - val_speddup_loss: 2334.0632 - val_class_acc: 0.7206 - val_speddup_acc: 0.0000e+00
# Epoch 91/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.9990 - class_loss: 0.5271 - speddup_loss: 17234.5305 - class_acc: 0.7615 - speddup_acc: 1.4625e-04 - val_loss: 1.6177 - val_class_loss: 0.6918 - val_speddup_loss: 6321.0679 - val_class_acc: 0.7094 - val_speddup_acc: 0.0000e+00
# Epoch 92/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.5384 - class_loss: 0.5264 - speddup_loss: 8038.8813 - class_acc: 0.7634 - speddup_acc: 6.2756e-05 - val_loss: 1.3724 - val_class_loss: 0.6497 - val_speddup_loss: 2234.0085 - val_class_acc: 0.7372 - val_speddup_acc: 0.0000e+00
# Epoch 93/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.7113 - class_loss: 0.5155 - speddup_loss: 11693.5192 - class_acc: 0.7702 - speddup_acc: 0.0000e+00 - val_loss: 1.5629 - val_class_loss: 0.6235 - val_speddup_loss: 6616.1787 - val_class_acc: 0.7278 - val_speddup_acc: 0.0000e+00
# Epoch 94/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 2.0588 - class_loss: 0.5166 - speddup_loss: 18678.1204 - class_acc: 0.7690 - speddup_acc: 0.0000e+00 - val_loss: 1.3280 - val_class_loss: 0.6418 - val_speddup_loss: 1544.6300 - val_class_acc: 0.7167 - val_speddup_acc: 0.0000e+00
# Epoch 95/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 2.1311 - class_loss: 0.5170 - speddup_loss: 20099.1528 - class_acc: 0.7667 - speddup_acc: 0.0000e+00 - val_loss: 1.3034 - val_class_loss: 0.6045 - val_speddup_loss: 1842.8562 - val_class_acc: 0.7311 - val_speddup_acc: 0.0000e+00
# Epoch 96/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 2.2664 - class_loss: 0.5133 - speddup_loss: 22928.9724 - class_acc: 0.7727 - speddup_acc: 0.0000e+00 - val_loss: 1.5287 - val_class_loss: 0.6109 - val_speddup_loss: 6220.1177 - val_class_acc: 0.7294 - val_speddup_acc: 0.0000e+00
# Epoch 97/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 2.2447 - class_loss: 0.5227 - speddup_loss: 22262.0843 - class_acc: 0.7652 - speddup_acc: 0.0000e+00 - val_loss: 1.4246 - val_class_loss: 0.6425 - val_speddup_loss: 3422.9221 - val_class_acc: 0.7250 - val_speddup_acc: 0.0000e+00
# Epoch 98/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 2.1464 - class_loss: 0.5368 - speddup_loss: 19978.0582 - class_acc: 0.7647 - speddup_acc: 5.3123e-05 - val_loss: 1.3101 - val_class_loss: 0.6442 - val_speddup_loss: 1198.7672 - val_class_acc: 0.7372 - val_speddup_acc: 0.0000e+00
# Epoch 99/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.6368 - class_loss: 0.5112 - speddup_loss: 10365.5966 - class_acc: 0.7678 - speddup_acc: 0.0000e+00 - val_loss: 1.5088 - val_class_loss: 0.6216 - val_speddup_loss: 5619.5522 - val_class_acc: 0.7161 - val_speddup_acc: 0.0000e+00
# Epoch 100/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.5084 - class_loss: 0.5010 - speddup_loss: 8009.9766 - class_acc: 0.7724 - speddup_acc: 0.0000e+00 - val_loss: 1.3477 - val_class_loss: 0.6195 - val_speddup_loss: 2403.6746 - val_class_acc: 0.7350 - val_speddup_acc: 0.0000e+00
# Epoch 101/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.6874 - class_loss: 0.4999 - speddup_loss: 11579.0936 - class_acc: 0.7746 - speddup_acc: 0.0000e+00 - val_loss: 1.3313 - val_class_loss: 0.6311 - val_speddup_loss: 1842.2476 - val_class_acc: 0.7328 - val_speddup_acc: 0.0000e+00
# Epoch 102/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.7249 - class_loss: 0.4901 - speddup_loss: 12554.2457 - class_acc: 0.7754 - speddup_acc: 0.0000e+00 - val_loss: 1.3572 - val_class_loss: 0.6703 - val_speddup_loss: 1611.3354 - val_class_acc: 0.7006 - val_speddup_acc: 0.0000e+00
# Epoch 103/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 2.2144 - class_loss: 0.4977 - speddup_loss: 22179.4469 - class_acc: 0.7786 - speddup_acc: 0.0000e+00 - val_loss: 1.5679 - val_class_loss: 0.6428 - val_speddup_loss: 6375.5195 - val_class_acc: 0.7239 - val_speddup_acc: 0.0000e+00
# Epoch 104/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 2.3408 - class_loss: 0.5454 - speddup_loss: 23706.3539 - class_acc: 0.7578 - speddup_acc: 7.6675e-05 - val_loss: 1.2967 - val_class_loss: 0.6306 - val_speddup_loss: 1180.7262 - val_class_acc: 0.7278 - val_speddup_acc: 0.0000e+00
# Epoch 105/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 2.6540 - class_loss: 0.5023 - speddup_loss: 30868.1359 - class_acc: 0.7680 - speddup_acc: 3.6672e-04 - val_loss: 1.4097 - val_class_loss: 0.6189 - val_speddup_loss: 3679.0522 - val_class_acc: 0.7222 - val_speddup_acc: 0.0000e+00
# Epoch 106/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.6003 - class_loss: 0.4845 - speddup_loss: 10173.1036 - class_acc: 0.7813 - speddup_acc: 1.4695e-04 - val_loss: 1.3461 - val_class_loss: 0.6333 - val_speddup_loss: 2116.3381 - val_class_acc: 0.7406 - val_speddup_acc: 0.0000e+00
# Epoch 107/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.6960 - class_loss: 0.4710 - speddup_loss: 12352.0885 - class_acc: 0.7804 - speddup_acc: 3.1627e-04 - val_loss: 1.3732 - val_class_loss: 0.6579 - val_speddup_loss: 1900.7119 - val_class_acc: 0.7267 - val_speddup_acc: 0.0000e+00
# Epoch 108/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 2.1077 - class_loss: 0.5087 - speddup_loss: 19813.7450 - class_acc: 0.7769 - speddup_acc: 0.0000e+00 - val_loss: 1.3476 - val_class_loss: 0.6562 - val_speddup_loss: 1678.2338 - val_class_acc: 0.7267 - val_speddup_acc: 0.0000e+00
# Epoch 109/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.5081 - class_loss: 0.4779 - speddup_loss: 8434.1098 - class_acc: 0.7855 - speddup_acc: 0.0000e+00 - val_loss: 1.4015 - val_class_loss: 0.6875 - val_speddup_loss: 2109.3232 - val_class_acc: 0.7044 - val_speddup_acc: 0.0000e+00
# Epoch 110/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.7223 - class_loss: 0.4909 - speddup_loss: 12478.4719 - class_acc: 0.7760 - speddup_acc: 0.0000e+00 - val_loss: 1.5275 - val_class_loss: 0.6523 - val_speddup_loss: 5382.3652 - val_class_acc: 0.7250 - val_speddup_acc: 0.0000e+00
# Epoch 111/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 2.2342 - class_loss: 0.4868 - speddup_loss: 22807.2098 - class_acc: 0.7836 - speddup_acc: 0.0000e+00 - val_loss: 1.3659 - val_class_loss: 0.7019 - val_speddup_loss: 1148.2806 - val_class_acc: 0.7128 - val_speddup_acc: 0.0000e+00
# Epoch 112/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.6963 - class_loss: 0.5047 - speddup_loss: 11673.6490 - class_acc: 0.7718 - speddup_acc: 0.0000e+00 - val_loss: 1.4480 - val_class_loss: 0.6768 - val_speddup_loss: 3247.8289 - val_class_acc: 0.7244 - val_speddup_acc: 0.0000e+00
# Epoch 113/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 2.0904 - class_loss: 0.4793 - speddup_loss: 20037.3212 - class_acc: 0.7837 - speddup_acc: 0.0000e+00 - val_loss: 1.3277 - val_class_loss: 0.6463 - val_speddup_loss: 1463.4192 - val_class_acc: 0.7278 - val_speddup_acc: 0.0000e+00
# Epoch 114/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.8685 - class_loss: 0.4835 - speddup_loss: 15547.1097 - class_acc: 0.7819 - speddup_acc: 0.0000e+00 - val_loss: 1.3108 - val_class_loss: 0.6213 - val_speddup_loss: 1430.7587 - val_class_acc: 0.7400 - val_speddup_acc: 0.0000e+00
# Epoch 115/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 2.5739 - class_loss: 0.4779 - speddup_loss: 29743.4580 - class_acc: 0.7900 - speddup_acc: 5.9641e-05 - val_loss: 1.3431 - val_class_loss: 0.5926 - val_speddup_loss: 2850.1829 - val_class_acc: 0.7289 - val_speddup_acc: 0.0000e+00
# Epoch 116/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 2.0644 - class_loss: 0.4823 - speddup_loss: 19471.7920 - class_acc: 0.7829 - speddup_acc: 1.0945e-04 - val_loss: 1.3643 - val_class_loss: 0.6910 - val_speddup_loss: 1318.8912 - val_class_acc: 0.7239 - val_speddup_acc: 0.0000e+00
# Epoch 117/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 2.1460 - class_loss: 0.4862 - speddup_loss: 21034.3772 - class_acc: 0.7814 - speddup_acc: 1.8201e-04 - val_loss: 1.3448 - val_class_loss: 0.6612 - val_speddup_loss: 1515.6721 - val_class_acc: 0.7089 - val_speddup_acc: 0.0000e+00
# Epoch 118/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.7655 - class_loss: 0.4687 - speddup_loss: 13783.4112 - class_acc: 0.7887 - speddup_acc: 0.0000e+00 - val_loss: 1.2899 - val_class_loss: 0.6261 - val_speddup_loss: 1123.3179 - val_class_acc: 0.7328 - val_speddup_acc: 0.0000e+00
# Epoch 119/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.4039 - class_loss: 0.4728 - speddup_loss: 6449.0716 - class_acc: 0.7889 - speddup_acc: 0.0000e+00 - val_loss: 1.3300 - val_class_loss: 0.6265 - val_speddup_loss: 1916.6074 - val_class_acc: 0.7367 - val_speddup_acc: 0.0000e+00
# Epoch 120/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 2.3037 - class_loss: 0.4593 - speddup_loss: 24720.8748 - class_acc: 0.7958 - speddup_acc: 0.0000e+00 - val_loss: 1.2930 - val_class_loss: 0.6282 - val_speddup_loss: 1067.4054 - val_class_acc: 0.7361 - val_speddup_acc: 0.0000e+00
# Epoch 121/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.6842 - class_loss: 0.4767 - speddup_loss: 11996.1834 - class_acc: 0.7900 - speddup_acc: 0.0000e+00 - val_loss: 1.3769 - val_class_loss: 0.6559 - val_speddup_loss: 2245.0703 - val_class_acc: 0.7339 - val_speddup_acc: 0.0000e+00
# Epoch 122/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.5109 - class_loss: 0.4735 - speddup_loss: 8568.1967 - class_acc: 0.7914 - speddup_acc: 0.0000e+00 - val_loss: 1.5650 - val_class_loss: 0.6223 - val_speddup_loss: 6656.6890 - val_class_acc: 0.7322 - val_speddup_acc: 0.0000e+00
# Epoch 123/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.9330 - class_loss: 0.4625 - speddup_loss: 17214.9936 - class_acc: 0.7897 - speddup_acc: 0.0000e+00 - val_loss: 1.3442 - val_class_loss: 0.6604 - val_speddup_loss: 1508.5544 - val_class_acc: 0.7406 - val_speddup_acc: 0.0000e+00
# Epoch 124/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 2.0579 - class_loss: 0.4606 - speddup_loss: 19753.6721 - class_acc: 0.7977 - speddup_acc: 0.0000e+00 - val_loss: 1.3804 - val_class_loss: 0.6275 - val_speddup_loss: 2889.6887 - val_class_acc: 0.7417 - val_speddup_acc: 0.0000e+00
# Epoch 125/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.4591 - class_loss: 0.4517 - speddup_loss: 7962.6161 - class_acc: 0.7933 - speddup_acc: 0.0000e+00 - val_loss: 1.3144 - val_class_loss: 0.6420 - val_speddup_loss: 1226.7180 - val_class_acc: 0.7406 - val_speddup_acc: 0.0000e+00
# Epoch 126/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.9109 - class_loss: 0.4651 - speddup_loss: 16711.6021 - class_acc: 0.7916 - speddup_acc: 0.0000e+00 - val_loss: 1.3770 - val_class_loss: 0.6462 - val_speddup_loss: 2439.3691 - val_class_acc: 0.7367 - val_speddup_acc: 0.0000e+00
# Epoch 127/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.9786 - class_loss: 0.4441 - speddup_loss: 18502.8295 - class_acc: 0.7978 - speddup_acc: 0.0000e+00 - val_loss: 1.4306 - val_class_loss: 0.6549 - val_speddup_loss: 3333.9487 - val_class_acc: 0.7306 - val_speddup_acc: 0.0000e+00
# Epoch 128/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 2.3626 - class_loss: 0.4504 - speddup_loss: 26057.4673 - class_acc: 0.8000 - speddup_acc: 0.0000e+00 - val_loss: 1.4044 - val_class_loss: 0.6675 - val_speddup_loss: 2551.6873 - val_class_acc: 0.7244 - val_speddup_acc: 0.0000e+00
# Epoch 129/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 2.5620 - class_loss: 0.4665 - speddup_loss: 29741.7350 - class_acc: 0.7904 - speddup_acc: 0.0000e+00 - val_loss: 1.3391 - val_class_loss: 0.6373 - val_speddup_loss: 1884.7487 - val_class_acc: 0.7311 - val_speddup_acc: 0.0000e+00
# Epoch 130/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 2.5071 - class_loss: 0.4514 - speddup_loss: 28944.6257 - class_acc: 0.7985 - speddup_acc: 0.0000e+00 - val_loss: 1.4109 - val_class_loss: 0.6693 - val_speddup_loss: 2678.6511 - val_class_acc: 0.7433 - val_speddup_acc: 0.0000e+00
# Epoch 131/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.7718 - class_loss: 0.4556 - speddup_loss: 14136.7547 - class_acc: 0.7922 - speddup_acc: 0.0000e+00 - val_loss: 1.4365 - val_class_loss: 0.6319 - val_speddup_loss: 3944.1445 - val_class_acc: 0.7278 - val_speddup_acc: 0.0000e+00
# Epoch 132/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.4832 - class_loss: 0.4589 - speddup_loss: 8299.7414 - class_acc: 0.7943 - speddup_acc: 0.0000e+00 - val_loss: 1.5081 - val_class_loss: 0.5893 - val_speddup_loss: 6242.3452 - val_class_acc: 0.7400 - val_speddup_acc: 0.0000e+00
# Epoch 133/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.9936 - class_loss: 0.4434 - speddup_loss: 18845.7649 - class_acc: 0.8043 - speddup_acc: 0.0000e+00 - val_loss: 1.3633 - val_class_loss: 0.6441 - val_speddup_loss: 2254.1111 - val_class_acc: 0.7394 - val_speddup_acc: 0.0000e+00
# Epoch 134/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.6354 - class_loss: 0.4448 - speddup_loss: 11634.7979 - class_acc: 0.8046 - speddup_acc: 0.0000e+00 - val_loss: 1.3279 - val_class_loss: 0.6260 - val_speddup_loss: 1899.4180 - val_class_acc: 0.7383 - val_speddup_acc: 0.0000e+00
# Epoch 135/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 2.3818 - class_loss: 0.4722 - speddup_loss: 26031.4839 - class_acc: 0.7873 - speddup_acc: 0.0000e+00 - val_loss: 1.3897 - val_class_loss: 0.6652 - val_speddup_loss: 2141.9832 - val_class_acc: 0.7194 - val_speddup_acc: 0.0000e+00
# Epoch 136/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.7329 - class_loss: 0.4972 - speddup_loss: 12401.7400 - class_acc: 0.7798 - speddup_acc: 5.5929e-06 - val_loss: 1.3219 - val_class_loss: 0.6579 - val_speddup_loss: 1078.7260 - val_class_acc: 0.7322 - val_speddup_acc: 0.0000e+00
# Epoch 137/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 2.1220 - class_loss: 0.4590 - speddup_loss: 21069.6882 - class_acc: 0.7987 - speddup_acc: 1.0358e-04 - val_loss: 1.4103 - val_class_loss: 0.6559 - val_speddup_loss: 2919.5085 - val_class_acc: 0.7333 - val_speddup_acc: 0.0000e+00
# Epoch 138/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.9086 - class_loss: 0.4429 - speddup_loss: 17127.2449 - class_acc: 0.8043 - speddup_acc: 7.6868e-05 - val_loss: 1.3064 - val_class_loss: 0.6247 - val_speddup_loss: 1448.8264 - val_class_acc: 0.7456 - val_speddup_acc: 0.0000e+00
# Epoch 139/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.5498 - class_loss: 0.4405 - speddup_loss: 10027.6043 - class_acc: 0.8059 - speddup_acc: 4.6650e-05 - val_loss: 1.3752 - val_class_loss: 0.6118 - val_speddup_loss: 3129.8442 - val_class_acc: 0.7367 - val_speddup_acc: 0.0000e+00
# Epoch 140/200
# ...
# Epoch 153/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 2.2337 - class_loss: 0.4704 - speddup_loss: 22870.1721 - class_acc: 0.7913 - speddup_acc: 4.1969e-05 - val_loss: 1.4690 - val_class_loss: 0.6819 - val_speddup_loss: 3377.1213 - val_class_acc: 0.7328 - val_speddup_acc: 0.0000e+00
# Epoch 154/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.8618 - class_loss: 0.4704 - speddup_loss: 15461.9064 - class_acc: 0.7927 - speddup_acc: 3.4187e-04 - val_loss: 1.4417 - val_class_loss: 0.6392 - val_speddup_loss: 3714.9263 - val_class_acc: 0.7367 - val_speddup_acc: 0.0000e+00
# Epoch 155/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.6597 - class_loss: 0.4568 - speddup_loss: 11738.8714 - class_acc: 0.7912 - speddup_acc: 6.4866e-05 - val_loss: 1.4223 - val_class_loss: 0.6468 - val_speddup_loss: 3202.1289 - val_class_acc: 0.7406 - val_speddup_acc: 0.0000e+00
# Epoch 156/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.9792 - class_loss: 0.4580 - speddup_loss: 18124.7350 - class_acc: 0.7957 - speddup_acc: 0.0000e+00 - val_loss: 1.3076 - val_class_loss: 0.6263 - val_speddup_loss: 1363.9248 - val_class_acc: 0.7400 - val_speddup_acc: 0.0000e+00
# Epoch 157/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.6775 - class_loss: 0.4416 - speddup_loss: 12448.2457 - class_acc: 0.8010 - speddup_acc: 0.0000e+00 - val_loss: 1.3528 - val_class_loss: 0.6803 - val_speddup_loss: 1204.5022 - val_class_acc: 0.7289 - val_speddup_acc: 0.0000e+00
# Epoch 158/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.8557 - class_loss: 0.4660 - speddup_loss: 15535.7519 - class_acc: 0.7883 - speddup_acc: 2.2344e-04 - val_loss: 1.5363 - val_class_loss: 0.6696 - val_speddup_loss: 5079.1006 - val_class_acc: 0.7261 - val_speddup_acc: 0.0000e+00
# Epoch 159/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 2.1829 - class_loss: 0.4507 - speddup_loss: 22386.3071 - class_acc: 0.7980 - speddup_acc: 2.5004e-04 - val_loss: 1.6588 - val_class_loss: 0.6463 - val_speddup_loss: 7971.3018 - val_class_acc: 0.7378 - val_speddup_acc: 0.0000e+00
# Epoch 160/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.8082 - class_loss: 0.4445 - speddup_loss: 15013.8608 - class_acc: 0.7998 - speddup_acc: 1.6900e-05 - val_loss: 1.5246 - val_class_loss: 0.6505 - val_speddup_loss: 5239.5000 - val_class_acc: 0.7417 - val_speddup_acc: 0.0000e+00
# Epoch 161/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.3955 - class_loss: 0.4402 - speddup_loss: 6849.6566 - class_acc: 0.7974 - speddup_acc: 0.0000e+00 - val_loss: 1.3418 - val_class_loss: 0.6745 - val_speddup_loss: 1091.9146 - val_class_acc: 0.7283 - val_speddup_acc: 0.0000e+00
# Epoch 162/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 2.0497 - class_loss: 0.4532 - speddup_loss: 19695.4621 - class_acc: 0.7989 - speddup_acc: 0.0000e+00 - val_loss: 1.3895 - val_class_loss: 0.6578 - val_speddup_loss: 2439.9534 - val_class_acc: 0.7361 - val_speddup_acc: 0.0000e+00
# Epoch 163/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 2.6916 - class_loss: 0.4530 - speddup_loss: 32568.2809 - class_acc: 0.8005 - speddup_acc: 0.0000e+00 - val_loss: 1.3136 - val_class_loss: 0.5730 - val_speddup_loss: 2608.8335 - val_class_acc: 0.7428 - val_speddup_acc: 0.0000e+00
# Epoch 164/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.9478 - class_loss: 0.4185 - speddup_loss: 18384.7983 - class_acc: 0.8097 - speddup_acc: 0.0000e+00 - val_loss: 1.3831 - val_class_loss: 0.6036 - val_speddup_loss: 3389.2534 - val_class_acc: 0.7333 - val_speddup_acc: 0.0000e+00
# Epoch 165/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.8663 - class_loss: 0.4452 - speddup_loss: 16200.3233 - class_acc: 0.8026 - speddup_acc: 0.0000e+00 - val_loss: 1.6994 - val_class_loss: 0.6310 - val_speddup_loss: 9196.6943 - val_class_acc: 0.7350 - val_speddup_acc: 0.0000e+00
# Epoch 166/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.8466 - class_loss: 0.4318 - speddup_loss: 16100.6735 - class_acc: 0.8094 - speddup_acc: 0.0000e+00 - val_loss: 1.4269 - val_class_loss: 0.6488 - val_speddup_loss: 3405.8784 - val_class_acc: 0.7428 - val_speddup_acc: 0.0000e+00
# Epoch 167/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.9594 - class_loss: 0.4314 - speddup_loss: 18374.6211 - class_acc: 0.8060 - speddup_acc: 0.0000e+00 - val_loss: 1.4130 - val_class_loss: 0.6507 - val_speddup_loss: 3097.2114 - val_class_acc: 0.7444 - val_speddup_acc: 0.0000e+00
# Epoch 168/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 2.1004 - class_loss: 0.4285 - speddup_loss: 21227.9052 - class_acc: 0.8078 - speddup_acc: 0.0000e+00 - val_loss: 1.4506 - val_class_loss: 0.6223 - val_speddup_loss: 4378.9438 - val_class_acc: 0.7456 - val_speddup_acc: 0.0000e+00
# Epoch 169/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.7965 - class_loss: 0.4318 - speddup_loss: 15096.1486 - class_acc: 0.8108 - speddup_acc: 7.8463e-06 - val_loss: 1.4129 - val_class_loss: 0.6492 - val_speddup_loss: 3053.9487 - val_class_acc: 0.7372 - val_speddup_acc: 0.0000e+00
# Epoch 170/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 2.2512 - class_loss: 0.4143 - speddup_loss: 24519.3558 - class_acc: 0.8148 - speddup_acc: 0.0000e+00 - val_loss: 1.5040 - val_class_loss: 0.6884 - val_speddup_loss: 4090.4661 - val_class_acc: 0.7433 - val_speddup_acc: 0.0000e+00
# Epoch 171/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.8284 - class_loss: 0.4262 - speddup_loss: 15817.7016 - class_acc: 0.8065 - speddup_acc: 0.0000e+00 - val_loss: 1.5072 - val_class_loss: 0.6447 - val_speddup_loss: 5065.9800 - val_class_acc: 0.7467 - val_speddup_acc: 0.0000e+00
# Epoch 172/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 2.4268 - class_loss: 0.4240 - speddup_loss: 27859.0736 - class_acc: 0.8104 - speddup_acc: 0.0000e+00 - val_loss: 1.6829 - val_class_loss: 0.8904 - val_speddup_loss: 2659.1555 - val_class_acc: 0.6489 - val_speddup_acc: 0.0000e+00
# Epoch 173/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 2.0498 - class_loss: 0.6929 - speddup_loss: 14052.8846 - class_acc: 0.7144 - speddup_acc: 0.0000e+00 - val_loss: 1.3435 - val_class_loss: 0.6428 - val_speddup_loss: 1125.5062 - val_class_acc: 0.7144 - val_speddup_acc: 0.0000e+00
# Epoch 174/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 16.5238 - class_loss: 8.6067 - speddup_loss: 144951.7652 - class_acc: 0.7156 - speddup_acc: 0.0000e+00 - val_loss: 1.7172 - val_class_loss: 0.7140 - val_speddup_loss: 6299.4805 - val_class_acc: 0.7056 - val_speddup_acc: 0.0000e+00
# Epoch 175/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 3.2925 - class_loss: 0.6396 - speddup_loss: 39329.2528 - class_acc: 0.7289 - speddup_acc: 0.0000e+00 - val_loss: 1.3918 - val_class_loss: 0.6955 - val_speddup_loss: 819.2316 - val_class_acc: 0.7000 - val_speddup_acc: 0.0000e+00
# Epoch 176/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.8661 - class_loss: 0.5929 - speddup_loss: 12308.6260 - class_acc: 0.7402 - speddup_acc: 0.0000e+00 - val_loss: 1.5565 - val_class_loss: 0.6711 - val_speddup_loss: 4629.9453 - val_class_acc: 0.7111 - val_speddup_acc: 0.0000e+00
# Epoch 177/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 2.1918 - class_loss: 0.5621 - speddup_loss: 19502.9768 - class_acc: 0.7646 - speddup_acc: 0.0000e+00 - val_loss: 2.4327 - val_class_loss: 1.2724 - val_speddup_loss: 10125.7822 - val_class_acc: 0.6978 - val_speddup_acc: 0.0000e+00
# Epoch 178/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.5395 - class_loss: 0.6112 - speddup_loss: 5483.0934 - class_acc: 0.7528 - speddup_acc: 1.3308e-05 - val_loss: 1.5130 - val_class_loss: 0.6980 - val_speddup_loss: 3246.4121 - val_class_acc: 0.6922 - val_speddup_acc: 0.0000e+00
# Epoch 179/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.2721 - class_loss: 0.5386 - speddup_loss: 1594.2458 - class_acc: 0.7622 - speddup_acc: 0.0000e+00 - val_loss: 1.5973 - val_class_loss: 0.8624 - val_speddup_loss: 1443.6298 - val_class_acc: 0.6472 - val_speddup_acc: 0.0000e+00
# Epoch 180/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 2.4117 - class_loss: 0.7239 - speddup_loss: 20448.2081 - class_acc: 0.6844 - speddup_acc: 0.0000e+00 - val_loss: 1.4652 - val_class_loss: 0.7170 - val_speddup_loss: 1512.9147 - val_class_acc: 0.6922 - val_speddup_acc: 0.0000e+00
# Epoch 181/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 2.2772 - class_loss: 0.5877 - speddup_loss: 20278.6034 - class_acc: 0.7395 - speddup_acc: 0.0000e+00 - val_loss: 1.4228 - val_class_loss: 0.6710 - val_speddup_loss: 1578.4519 - val_class_acc: 0.7106 - val_speddup_acc: 0.0000e+00
# Epoch 182/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 2.4847 - class_loss: 0.5678 - speddup_loss: 24843.1952 - class_acc: 0.7439 - speddup_acc: 0.0000e+00 - val_loss: 1.5462 - val_class_loss: 0.6526 - val_speddup_loss: 4608.2598 - val_class_acc: 0.7133 - val_speddup_acc: 0.0000e+00
# Epoch 183/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 2.2918 - class_loss: 0.5421 - speddup_loss: 21768.2893 - class_acc: 0.7615 - speddup_acc: 9.0945e-05 - val_loss: 1.3585 - val_class_loss: 0.6487 - val_speddup_loss: 955.6468 - val_class_acc: 0.7156 - val_speddup_acc: 0.0000e+00
# Epoch 184/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 3.4511 - class_loss: 0.5236 - speddup_loss: 45332.8491 - class_acc: 0.7688 - speddup_acc: 9.0319e-05 - val_loss: 1.4756 - val_class_loss: 0.6599 - val_speddup_loss: 3222.7432 - val_class_acc: 0.7306 - val_speddup_acc: 0.0000e+00
# Epoch 185/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.6559 - class_loss: 0.5088 - speddup_loss: 9825.2486 - class_acc: 0.7796 - speddup_acc: 1.0907e-04 - val_loss: 1.4857 - val_class_loss: 0.6353 - val_speddup_loss: 3920.2966 - val_class_acc: 0.7344 - val_speddup_acc: 0.0000e+00
# Epoch 186/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 2.5512 - class_loss: 0.5069 - speddup_loss: 27771.9042 - class_acc: 0.7769 - speddup_acc: 3.3264e-04 - val_loss: 1.3647 - val_class_loss: 0.6555 - val_speddup_loss: 1041.3444 - val_class_acc: 0.7283 - val_speddup_acc: 0.0000e+00
# Epoch 187/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.7210 - class_loss: 0.5250 - speddup_loss: 10737.0026 - class_acc: 0.7714 - speddup_acc: 7.0338e-05 - val_loss: 1.5467 - val_class_loss: 0.7020 - val_speddup_loss: 3845.8340 - val_class_acc: 0.7222 - val_speddup_acc: 0.0000e+00
# Epoch 188/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.7767 - class_loss: 0.5236 - speddup_loss: 11985.5100 - class_acc: 0.7784 - speddup_acc: 3.3608e-04 - val_loss: 1.6185 - val_class_loss: 0.6538 - val_speddup_loss: 6193.6104 - val_class_acc: 0.7139 - val_speddup_acc: 0.0000e+00
# Epoch 189/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.8466 - class_loss: 0.5921 - speddup_loss: 12020.1321 - class_acc: 0.7537 - speddup_acc: 2.5618e-05 - val_loss: 1.7189 - val_class_loss: 0.6695 - val_speddup_loss: 8284.7188 - val_class_acc: 0.7161 - val_speddup_acc: 0.0000e+00
# Epoch 190/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.8235 - class_loss: 0.6514 - speddup_loss: 10880.9098 - class_acc: 0.7431 - speddup_acc: 0.0000e+00 - val_loss: 1.3969 - val_class_loss: 0.6861 - val_speddup_loss: 1914.5288 - val_class_acc: 0.7044 - val_speddup_acc: 0.0000e+00
# Epoch 191/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.6637 - class_loss: 0.5747 - speddup_loss: 9444.5647 - class_acc: 0.7589 - speddup_acc: 1.3096e-04 - val_loss: 1.3678 - val_class_loss: 0.6525 - val_speddup_loss: 1919.1337 - val_class_acc: 0.7211 - val_speddup_acc: 0.0000e+00
# Epoch 192/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.4919 - class_loss: 0.5517 - speddup_loss: 6441.0937 - class_acc: 0.7622 - speddup_acc: 1.6205e-04 - val_loss: 1.3460 - val_class_loss: 0.6838 - val_speddup_loss: 940.9505 - val_class_acc: 0.7067 - val_speddup_acc: 0.0000e+00
# Epoch 193/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.6903 - class_loss: 0.5303 - speddup_loss: 10901.8948 - class_acc: 0.7600 - speddup_acc: 2.4492e-04 - val_loss: 1.3870 - val_class_loss: 0.6435 - val_speddup_loss: 2609.9207 - val_class_acc: 0.7278 - val_speddup_acc: 0.0000e+00
# Epoch 194/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 2.3215 - class_loss: 0.4930 - speddup_loss: 24299.9160 - class_acc: 0.7860 - speddup_acc: 2.8059e-05 - val_loss: 1.3758 - val_class_loss: 0.6557 - val_speddup_loss: 2115.4319 - val_class_acc: 0.7400 - val_speddup_acc: 0.0000e+00
# Epoch 195/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.7240 - class_loss: 0.5490 - speddup_loss: 11148.5415 - class_acc: 0.7702 - speddup_acc: 0.0000e+00 - val_loss: 1.3710 - val_class_loss: 0.6387 - val_speddup_loss: 2289.8794 - val_class_acc: 0.7267 - val_speddup_acc: 0.0000e+00
# Epoch 196/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.3703 - class_loss: 0.5396 - speddup_loss: 4242.4670 - class_acc: 0.7736 - speddup_acc: 1.3007e-05 - val_loss: 1.4403 - val_class_loss: 0.6765 - val_speddup_loss: 2870.6763 - val_class_acc: 0.7228 - val_speddup_acc: 0.0000e+00
# Epoch 197/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.3474 - class_loss: 0.5282 - speddup_loss: 3988.2941 - class_acc: 0.7735 - speddup_acc: 0.0000e+00 - val_loss: 1.4877 - val_class_loss: 0.6755 - val_speddup_loss: 3259.3855 - val_class_acc: 0.7122 - val_speddup_acc: 0.0000e+00
# Epoch 198/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.4140 - class_loss: 0.5549 - speddup_loss: 4036.9661 - class_acc: 0.7576 - speddup_acc: 0.0000e+00 - val_loss: 1.4722 - val_class_loss: 0.7287 - val_speddup_loss: 1620.0339 - val_class_acc: 0.7156 - val_speddup_acc: 0.0000e+00
# Epoch 199/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.3350 - class_loss: 0.5376 - speddup_loss: 2709.2370 - class_acc: 0.7619 - speddup_acc: 0.0000e+00 - val_loss: 1.4688 - val_class_loss: 0.6735 - val_speddup_loss: 2677.5847 - val_class_acc: 0.7244 - val_speddup_acc: 0.0000e+00
# Epoch 200/200
# 1013/1013 [==============================] - 5s 5ms/step - loss: 1.2540 - class_loss: 0.5084 - speddup_loss: 1658.6545 - class_acc: 0.7790 - speddup_acc: 0.0000e+00 - val_loss: 1.4549 - val_class_loss: 0.6841 - val_speddup_loss: 2199.8989 - val_class_acc: 0.7222 - val_speddup_acc: 0.0000e+00
# Training took 1064.6782207489014 seconds..
# Information saved to ./model_data/GNN_generated2.control.call_150x150_1619123314.6275222/training_history.yaml
# Information saved to ./model_data/GNN_generated2.control.call_150x150_1619123314.6275222/training_time.yaml
# Model saved to ./model_data/GNN_generated2.control.call_150x150_1619123314.6275222/model.yaml
# Weights saved to file ./model_data/GNN_generated2.control.call_150x150_1619123314.6275222/weights.h5
# Accuracy per epoch figure saved to ./model_data/GNN_generated2.control.call_150x150_1619123314.6275222/model_accuracy.pdf
# Evaluating model.
# 125/125 [==============================] - 1s 3ms/step - loss: 1.7478 - class_loss: 0.6811 - speddup_loss: 8093.4590 - class_acc: 0.7335 - speddup_acc: 0.0000e+00
# Done. Test loss: 1.7478. Test acc: 0.68
# Information saved to ./model_data/GNN_generated2.control.call_150x150_1619123314.6275222/evaluation.yaml
# Confusion matrix:
# [[496  51   5   5]
#  [ 34 344 144 130]
#  [  1  46 298  29]
#  [  3  25  60 329]]
# Confusion matrix figure saved to ./model_data/GNN_generated2.control.call_150x150_1619123314.6275222/confusion_matrix.pdf
# 16461

# %%
results = []
results += eval_results_zeroing_llvm(model, [], features_test, graphs_test, y_test, description='Zeroing Nothing')
results += eval_results_zeroing_llvm(model, get_terminators(), features_test, graphs_test, y_test, description='Zeroing terminators')
results += eval_results_zeroing_llvm(model, get_unary(), features_test, graphs_test, y_test, description='Zeroing unaries')
results += eval_results_zeroing_llvm(model, get_binary(), features_test, graphs_test, y_test, description='Zeroing binaries')
results += eval_results_zeroing_llvm(model, get_memory(), features_test, graphs_test, y_test, description='Zeroing memories')
results += eval_results_zeroing_llvm(model, get_casts(), features_test, graphs_test, y_test, description='Zeroing casts')
results += eval_results_zeroing_llvm(model, get_others(), features_test, graphs_test, y_test, description='Zeroing others')
for i in range (0, 50):
    results += eval_results_zeroing_llvm_random(model, 2, features_test, graphs_test, y_test)
for i in range (0, 50):
    results += eval_results_zeroing_llvm_random(model, 3, features_test, graphs_test, y_test)
for i in range (0, 50):
    results += eval_results_zeroing_llvm_random(model, 4, features_test, graphs_test, y_test)
# Out:
# Zeroing Nothing. loss: 1.747820258140564, class_acc: 0.7335000038146973
# Zeroing terminators. loss: 8.81434154510498, class_acc: 0.43299999833106995
# Zeroing unaries. loss: 1.7709546089172363, class_acc: 0.7250000238418579
# Zeroing binaries. loss: 5.341602802276611, class_acc: 0.5109999775886536
# Zeroing memories. loss: 5.326013565063477, class_acc: 0.46700000762939453
# Zeroing casts. loss: 3.3044326305389404, class_acc: 0.6414999961853027
# Zeroing others. loss: 4.686763763427734, class_acc: 0.4959999918937683
# Zeroing columns 29, 39. loss: 1.9088037014007568, class_acc: 0.6759999990463257
# Zeroing columns 40, 60. loss: 1.8676027059555054, class_acc: 0.7110000252723694
# Zeroing columns 34, 57. loss: 1.747820258140564, class_acc: 0.7335000038146973
# Zeroing columns 48, 57. loss: 1.7998878955841064, class_acc: 0.7269999980926514
# Zeroing columns 8, 65. loss: 1.747820258140564, class_acc: 0.7335000038146973
# Zeroing columns 13, 55. loss: 3.772683620452881, class_acc: 0.5979999899864197
# Zeroing columns 14, 57. loss: 2.252323865890503, class_acc: 0.7235000133514404
# Zeroing columns 30, 62. loss: 1.9725227355957031, class_acc: 0.6899999976158142
# Zeroing columns 3, 29. loss: 2.0949952602386475, class_acc: 0.7070000171661377
# Zeroing columns 36, 65. loss: 1.747820258140564, class_acc: 0.7335000038146973
# Zeroing columns 13, 15. loss: 1.8307796716690063, class_acc: 0.7095000147819519
# Zeroing columns 44, 45. loss: 1.7577483654022217, class_acc: 0.7315000295639038
# Zeroing columns 41, 45. loss: 1.7655845880508423, class_acc: 0.7275000214576721
# Zeroing columns 33, 37. loss: 3.662062168121338, class_acc: 0.6190000176429749
# Zeroing columns 8, 44. loss: 1.7488142251968384, class_acc: 0.734499990940094
# Zeroing columns 55, 59. loss: 3.682187795639038, class_acc: 0.6150000095367432
# Zeroing columns 11, 18. loss: 1.7718325853347778, class_acc: 0.7229999899864197
# Zeroing columns 23, 40. loss: 1.748633623123169, class_acc: 0.7335000038146973
# Zeroing columns 0, 28. loss: 2.8232405185699463, class_acc: 0.6014999747276306
# Zeroing columns 28, 49. loss: 1.7874561548233032, class_acc: 0.7245000004768372
# Zeroing columns 11, 41. loss: 1.7711721658706665, class_acc: 0.7235000133514404
# Zeroing columns 10, 34. loss: 1.747820258140564, class_acc: 0.7335000038146973
# Zeroing columns 21, 50. loss: 1.932985544204712, class_acc: 0.7095000147819519
# Zeroing columns 62, 64. loss: 1.7593014240264893, class_acc: 0.7310000061988831
# Zeroing columns 17, 57. loss: 1.9858832359313965, class_acc: 0.7024999856948853
# Zeroing columns 1, 7. loss: 7.120591640472412, class_acc: 0.47699999809265137
# Zeroing columns 23, 30. loss: 1.9725871086120605, class_acc: 0.6919999718666077
# Zeroing columns 6, 48. loss: 3.39837646484375, class_acc: 0.6725000143051147
# Zeroing columns 29, 43. loss: 2.1833724975585938, class_acc: 0.6830000281333923
# Zeroing columns 23, 58. loss: 1.747820258140564, class_acc: 0.7335000038146973
# Zeroing columns 0, 29. loss: 3.1276893615722656, class_acc: 0.5889999866485596
# Zeroing columns 43, 57. loss: 1.8199329376220703, class_acc: 0.7110000252723694
# Zeroing columns 33, 36. loss: 3.365678071975708, class_acc: 0.6340000033378601
# Zeroing columns 8, 46. loss: 1.756455421447754, class_acc: 0.7335000038146973
# Zeroing columns 25, 37. loss: 2.135589838027954, class_acc: 0.6694999933242798
# Zeroing columns 34, 42. loss: 1.746006965637207, class_acc: 0.7329999804496765
# Zeroing columns 39, 63. loss: 1.6218459606170654, class_acc: 0.6940000057220459
# Zeroing columns 41, 53. loss: 1.7877742052078247, class_acc: 0.7170000076293945
# Zeroing columns 16, 46. loss: 2.1285438537597656, class_acc: 0.7089999914169312
# Zeroing columns 27, 44. loss: 1.8422552347183228, class_acc: 0.718500018119812
# Zeroing columns 47, 48. loss: 1.8030198812484741, class_acc: 0.7260000109672546
# Zeroing columns 23, 52. loss: 3.614083766937256, class_acc: 0.6345000267028809
# Zeroing columns 38, 42. loss: 2.479672431945801, class_acc: 0.6974999904632568
# Zeroing columns 9, 19. loss: 1.821197271347046, class_acc: 0.7179999947547913
# Zeroing columns 14, 20. loss: 2.418097734451294, class_acc: 0.684499979019165
# Zeroing columns 31, 40. loss: 3.046680212020874, class_acc: 0.5874999761581421
# Zeroing columns 55, 57. loss: 3.682187795639038, class_acc: 0.6150000095367432
# Zeroing columns 5, 38. loss: 2.4768526554107666, class_acc: 0.6980000138282776
# Zeroing columns 47, 51. loss: 1.7528648376464844, class_acc: 0.7325000166893005
# Zeroing columns 13, 39. loss: 1.62623929977417, class_acc: 0.6825000047683716
# Zeroing columns 4, 12, 32. loss: 5.272739410400391, class_acc: 0.46050000190734863
# Zeroing columns 20, 33, 34. loss: 3.4751288890838623, class_acc: 0.621999979019165
# Zeroing columns 18, 40, 60. loss: 1.8723605871200562, class_acc: 0.7089999914169312
# Zeroing columns 1, 10, 44. loss: 7.119451999664307, class_acc: 0.4749999940395355
# Zeroing columns 36, 51, 52. loss: 3.614083766937256, class_acc: 0.6345000267028809
# Zeroing columns 44, 47, 51. loss: 1.753961205482483, class_acc: 0.7335000038146973
# Zeroing columns 5, 28, 35. loss: 1.7874561548233032, class_acc: 0.7245000004768372
# Zeroing columns 3, 24, 27. loss: 1.87222158908844, class_acc: 0.7024999856948853
# Zeroing columns 48, 50, 56. loss: 1.840298056602478, class_acc: 0.7114999890327454
# Zeroing columns 1, 39, 57. loss: 6.836935520172119, class_acc: 0.4620000123977661
# Zeroing columns 13, 28, 58. loss: 1.8470051288604736, class_acc: 0.7074999809265137
# Zeroing columns 28, 39, 51. loss: 1.624597430229187, class_acc: 0.6875
# Zeroing columns 11, 47, 59. loss: 1.7759113311767578, class_acc: 0.7239999771118164
# Zeroing columns 2, 39, 47. loss: 1.6244251728057861, class_acc: 0.6959999799728394
# Zeroing columns 8, 37, 44. loss: 1.9884614944458008, class_acc: 0.6884999871253967
# Zeroing columns 7, 22, 37. loss: 2.0081870555877686, class_acc: 0.6919999718666077
# Zeroing columns 30, 45, 46. loss: 2.0023603439331055, class_acc: 0.6875
# Zeroing columns 27, 40, 56. loss: 1.8640459775924683, class_acc: 0.7009999752044678
# Zeroing columns 15, 33, 52. loss: 4.099833965301514, class_acc: 0.5509999990463257
# Zeroing columns 26, 43, 61. loss: 1.91200852394104, class_acc: 0.6919999718666077
# Zeroing columns 10, 16, 29. loss: 2.487443685531616, class_acc: 0.6794999837875366
# Zeroing columns 14, 37, 60. loss: 2.92756724357605, class_acc: 0.6625000238418579
# Zeroing columns 8, 13, 14. loss: 2.298600196838379, class_acc: 0.7070000171661377
# Zeroing columns 10, 21, 50. loss: 1.932985544204712, class_acc: 0.7095000147819519
# Zeroing columns 33, 40, 53. loss: 3.4092981815338135, class_acc: 0.6230000257492065
# Zeroing columns 24, 60, 61. loss: 2.0448553562164307, class_acc: 0.6875
# Zeroing columns 19, 34, 59. loss: 1.821197271347046, class_acc: 0.7179999947547913
# Zeroing columns 52, 56, 59. loss: 3.721968173980713, class_acc: 0.6240000128746033
# Zeroing columns 12, 21, 31. loss: 5.288447856903076, class_acc: 0.4749999940395355
# Zeroing columns 0, 53, 58. loss: 2.8750100135803223, class_acc: 0.5914999842643738
# Zeroing columns 2, 13, 59. loss: 1.8034881353378296, class_acc: 0.7124999761581421
# Zeroing columns 2, 19, 23. loss: 1.8272227048873901, class_acc: 0.7164999842643738
# Zeroing columns 8, 41, 59. loss: 1.7454577684402466, class_acc: 0.7300000190734863
# Zeroing columns 20, 29, 42. loss: 2.2457902431488037, class_acc: 0.6675000190734863
# Zeroing columns 4, 49, 55. loss: 3.682187795639038, class_acc: 0.6150000095367432
# Zeroing columns 28, 29, 52. loss: 3.8260855674743652, class_acc: 0.6104999780654907
# Zeroing columns 6, 25, 39. loss: 3.7952702045440674, class_acc: 0.6495000123977661
# Zeroing columns 0, 26, 63. loss: 3.0034892559051514, class_acc: 0.5964999794960022
# Zeroing columns 34, 41, 43. loss: 1.823793888092041, class_acc: 0.7074999809265137
# Zeroing columns 29, 35, 37. loss: 2.371307134628296, class_acc: 0.671999990940094
# Zeroing columns 48, 58, 64. loss: 1.8191314935684204, class_acc: 0.7254999876022339
# Zeroing columns 13, 16, 60. loss: 2.2642662525177, class_acc: 0.6915000081062317
# Zeroing columns 1, 3, 18. loss: 7.112586975097656, class_acc: 0.47749999165534973
# Zeroing columns 28, 39, 43. loss: 1.6653310060501099, class_acc: 0.6725000143051147
# Zeroing columns 14, 22, 59. loss: 2.2801003456115723, class_acc: 0.7129999995231628
# Zeroing columns 30, 58, 59. loss: 1.9725871086120605, class_acc: 0.6919999718666077
# Zeroing columns 2, 13, 17. loss: 1.9384080171585083, class_acc: 0.7009999752044678
# Zeroing columns 24, 37, 46. loss: 2.0145533084869385, class_acc: 0.6759999990463257
# Zeroing columns 23, 58, 66. loss: 1.747820258140564, class_acc: 0.7335000038146973
# Zeroing columns 5, 21, 61. loss: 1.9604103565216064, class_acc: 0.6959999799728394
# Zeroing columns 5, 31, 51, 55. loss: 4.494649410247803, class_acc: 0.515500009059906
# Zeroing columns 0, 17, 31, 56. loss: 6.093009948730469, class_acc: 0.4424999952316284
# Zeroing columns 0, 8, 12, 42. loss: 5.52837610244751, class_acc: 0.5230000019073486
# Zeroing columns 7, 30, 56, 58. loss: 2.0128774642944336, class_acc: 0.6740000247955322
# Zeroing columns 2, 9, 29, 53. loss: 2.0773000717163086, class_acc: 0.6919999718666077
# Zeroing columns 2, 15, 37, 44. loss: 2.1323163509368896, class_acc: 0.6759999990463257
# Zeroing columns 9, 17, 23, 66. loss: 1.9858832359313965, class_acc: 0.7024999856948853
# Zeroing columns 12, 28, 44, 48. loss: 2.798063039779663, class_acc: 0.6324999928474426
# Zeroing columns 7, 14, 41, 57. loss: 2.2487423419952393, class_acc: 0.7210000157356262
# Zeroing columns 52, 58, 61, 63. loss: 3.6562252044677734, class_acc: 0.6230000257492065
# Zeroing columns 1, 3, 56, 61. loss: 7.4531989097595215, class_acc: 0.45750001072883606
# Zeroing columns 13, 30, 38, 46. loss: 2.7252323627471924, class_acc: 0.6549999713897705
# Zeroing columns 15, 17, 21, 59. loss: 2.298204183578491, class_acc: 0.671500027179718
# Zeroing columns 18, 37, 51, 54. loss: 3.0726897716522217, class_acc: 0.6200000047683716
# Zeroing columns 22, 30, 43, 48. loss: 2.1087026596069336, class_acc: 0.6744999885559082
# Zeroing columns 5, 56, 61, 62. loss: 1.8248984813690186, class_acc: 0.703499972820282
# Zeroing columns 28, 42, 50, 55. loss: 3.7086730003356934, class_acc: 0.6025000214576721
# Zeroing columns 1, 23, 36, 66. loss: 7.120591640472412, class_acc: 0.47699999809265137
# Zeroing columns 3, 11, 14, 61. loss: 2.305466651916504, class_acc: 0.7045000195503235
# Zeroing columns 14, 18, 37, 57. loss: 2.853703260421753, class_acc: 0.6790000200271606
# Zeroing columns 26, 48, 50, 59. loss: 1.8528236150741577, class_acc: 0.7170000076293945
# Zeroing columns 22, 35, 48, 65. loss: 1.833203911781311, class_acc: 0.7200000286102295
# Zeroing columns 9, 22, 29, 47. loss: 2.1100635528564453, class_acc: 0.6974999904632568
# Zeroing columns 7, 20, 33, 63. loss: 3.483187675476074, class_acc: 0.6215000152587891
# Zeroing columns 3, 18, 35, 57. loss: 1.7494429349899292, class_acc: 0.7310000061988831
# Zeroing columns 16, 37, 38, 45. loss: 2.5805795192718506, class_acc: 0.6614999771118164
# Zeroing columns 19, 25, 40, 61. loss: 2.475160837173462, class_acc: 0.6930000185966492
# Zeroing columns 29, 34, 42, 48. loss: 2.1105880737304688, class_acc: 0.6974999904632568
# Zeroing columns 4, 5, 35, 41. loss: 1.7454577684402466, class_acc: 0.7300000190734863
# Zeroing columns 47, 63, 64, 66. loss: 1.78376305103302, class_acc: 0.7275000214576721
# Zeroing columns 8, 10, 31, 44. loss: 3.023871898651123, class_acc: 0.5874999761581421
# Zeroing columns 44, 54, 55, 65. loss: 3.77119517326355, class_acc: 0.5444999933242798
# Zeroing columns 2, 24, 47, 57. loss: 1.8624025583267212, class_acc: 0.7129999995231628
# Zeroing columns 23, 31, 37, 55. loss: 96.85279083251953, class_acc: 0.5
# Zeroing columns 12, 23, 45, 53. loss: 2.8229167461395264, class_acc: 0.6395000219345093
# Zeroing columns 18, 32, 59, 61. loss: 3.800842523574829, class_acc: 0.5134999752044678
# Zeroing columns 25, 53, 54, 62. loss: 3.072516679763794, class_acc: 0.6414999961853027
# Zeroing columns 2, 42, 56, 59. loss: 1.7967004776000977, class_acc: 0.7160000205039978
# Zeroing columns 9, 23, 37, 51. loss: 1.987552523612976, class_acc: 0.6880000233650208
# Zeroing columns 6, 26, 30, 38. loss: 4.257687091827393, class_acc: 0.612500011920929
# Zeroing columns 25, 33, 41, 44. loss: 3.4382615089416504, class_acc: 0.6194999814033508
# Zeroing columns 11, 12, 34, 62. loss: 2.834185838699341, class_acc: 0.6380000114440918
# Zeroing columns 9, 36, 56, 57. loss: 1.7847691774368286, class_acc: 0.7174999713897705
# Zeroing columns 0, 10, 19, 29. loss: 3.105592966079712, class_acc: 0.5874999761581421
# Zeroing columns 21, 32, 49, 51. loss: 3.9508533477783203, class_acc: 0.5024999976158142
# Zeroing columns 21, 44, 52, 57. loss: 3.775012254714966, class_acc: 0.6175000071525574
# Zeroing columns 16, 29, 47, 63. loss: 2.5141375064849854, class_acc: 0.6759999990463257
# Zeroing columns 20, 32, 42, 43. loss: 4.124907970428467, class_acc: 0.4950000047683716
# Zeroing columns 25, 32, 36, 37. loss: 5.1476335525512695, class_acc: 0.4634999930858612
# Zeroing columns 12, 48, 62, 64. loss: 2.8028945922851562, class_acc: 0.6309999823570251

# %% [markdown]
# # Train CFG + Call + Data Graphs

# %%
# Configuration information about training
config = {
    'input_data': './data/generated.control.call.data_20000samples_150x150.npz',   # Name of the file with samples
    'data_dir_tag': 'generated2.control.call.data',    # Tag for directory name
    'n_nodes': 150,       # Number of nodes in graphs
    'n_features': 67,     # Original feature dimensionality
    'n_classes': 4,       # Number of output classes
    'epochs': 200,        # Number of training epochs
    'batch_size': 16,     # Number of samples per batch
    'learning_rate': 1e-2,# Training learning rate
    'test_size': 0.10,    # Percentage of samples to be used in test set (in relation to total number of samples)
    'validation_size': 0.10,    # Percentage of samples to be used in validation set (in relation to number of training samples)
    'samples': 20000,     # Number of samples in dataset (OPTIONAL)
}

# Create directory and write configuration information
data_dir = f"./model_data/GNN_{config['data_dir_tag']}_{config['n_nodes']}x{config['n_nodes']}_{time.time()}"
dump_info(data_dir, 'info.yaml', config)

print('Loading inputs and split into train and test sets')
# Load inputs and create train and and test sets
graphs_train, graphs_test, features_train, features_test, y_train, y_test = get_inputs(config['input_data'], test_size=config['test_size'])
print("Inputs loaded!")

# Create GNN model
model = create_model(config['n_nodes'], config['n_features'], config['n_classes'], config['learning_rate'])
print('Model created!')
model.summary()

# -----------------------------------------------
# ----------------- Train model -----------------
# -----------------------------------------------
print('Start training')
start_time = time.time()
history = model.fit([features_train[:,0,:,:], graphs_train[:,0,:,:], features_train[:,1,:,:], graphs_train[:,1,:,:]], [y_train[:,0:4], y_train[:,4]],
          batch_size=config['batch_size'], validation_split=config['validation_size'], epochs=config['epochs'], verbose=1)
end_time = time.time()
print(f'Training took {end_time-start_time} seconds..')

# Dump training information to files
dump_info(data_dir, 'training_history.yaml', history.history)
dump_info(data_dir, 'training_time.yaml', {'time': end_time-start_time})
# Save model and weights to files
save_model(data_dir, model)

# Plot accuracy per epoch in train and validation sets
plt.plot(np.array(history.history['class_acc']))
plt.plot(np.array(history.history['val_class_acc']))
plt.title('model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
figure_file = os.path.join(data_dir, "model_accuracy.pdf")
plt.savefig(figure_file)
print(f"Accuracy per epoch figure saved to {figure_file}")


# --------------------------------------------------
# ----------------- Evaluate model -----------------
# --------------------------------------------------
print('Evaluating model.')
eval_results = model.evaluate([features_test[:,0,:,:], graphs_test[:,0,:,:], features_test[:,1,:,:], graphs_test[:,1,:,:]], [y_test[:,0:4],y_test[:,4]],
                              batch_size=config['batch_size'])
print('Done. Test loss: {:.4f}. Test acc: {:.2f}'.format(*eval_results))

# Dump evaluation information to files
dump_info(data_dir, 'evaluation.yaml', {'test_loss': eval_results[0], 'test_accuracy': eval_results[1]})

# Printing confusion matrix
print("Confusion matrix:")
pred_vals = model.predict([features_test[:,0,:,:], graphs_test[:,0,:,:], features_test[:,1,:,:], graphs_test[:,1,:,:]])
pred_vals = np.argmax(pred_vals[0], axis=-1)
test_vals = np.argmax(y_test[:,0:4], axis=-1)
cm=confusion_matrix(pred_vals,test_vals)
print(cm)

# Plot confusion matrix
labels = ['High Slowdown', 'Low Slowdown', 'Not Significant', 'High Speedup']
plt.figure(figsize = (10,7))
sn.set(font_scale=1.4)
ax = sn.heatmap(cm, cmap="Blues", annot=True, annot_kws={"size": 16}, xticklabels=labels, yticklabels=labels)
for label in ax.get_xticklabels():
    label.set_ha("right")
    label.set_rotation(45)

ax.set_xlabel('Truth Category')
ax.set_ylabel('Predicted Category')

# Save confusion matrix
figure_file = os.path.join(data_dir, "confusion_matrix.pdf")
plt.savefig(figure_file)
print(f"Confusion matrix figure saved to {figure_file}")

# Cleanup
gc.collect()

# %%
results = []
results += eval_results_zeroing_llvm(model, [], features_test, graphs_test, y_test, description='Zeroing Nothing')
results += eval_results_zeroing_llvm(model, get_terminators(), features_test, graphs_test, y_test, description='Zeroing terminators')
results += eval_results_zeroing_llvm(model, get_unary(), features_test, graphs_test, y_test, description='Zeroing unaries')
results += eval_results_zeroing_llvm(model, get_binary(), features_test, graphs_test, y_test, description='Zeroing binaries')
results += eval_results_zeroing_llvm(model, get_memory(), features_test, graphs_test, y_test, description='Zeroing memories')
results += eval_results_zeroing_llvm(model, get_casts(), features_test, graphs_test, y_test, description='Zeroing casts')
results += eval_results_zeroing_llvm(model, get_others(), features_test, graphs_test, y_test, description='Zeroing others')
for i in range (0, 50):
    results += eval_results_zeroing_llvm_random(model, 2, features_test, graphs_test, y_test)
for i in range (0, 50):
    results += eval_results_zeroing_llvm_random(model, 3, features_test, graphs_test, y_test)
for i in range (0, 50):
    results += eval_results_zeroing_llvm_random(model, 4, features_test, graphs_test, y_test)
